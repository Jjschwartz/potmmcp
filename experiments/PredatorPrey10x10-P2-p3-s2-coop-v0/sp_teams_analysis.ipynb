# %% [markdown]
# # PredatorPrey10x10-P2-p3-s2-coop-v0 Experiment analysis - Single seed
#
# Notes on experiments:
#
# - Each experiment is 100 episodes or 12 hours (whichever comes first)
# - Using **PUCB** for action selection
# - Using **truncated** search

# %%
import copy
import os.path as osp

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import posggym_agents

import baposgmcp.plot as plot_utils
import baposgmcp.plot.paper as paper_utils
from baposgmcp.config import BASE_REPO_DIR

ENV_NAME = "PredatorPrey10x10-P2-p3-s2-coop-v0"
baposgmcp_results_file = osp.join(
    BASE_REPO_DIR, "experiments", ENV_NAME, "results", "sp_team_results_v0.csv"
)
figure_dir = osp.join(BASE_REPO_DIR, "experiments", ENV_NAME, "figures")
policy_results_file = osp.join(
    posggym_agents.config.BASE_DIR, 'agents', "predatorprey10x10_P2_p3_s2_coop_v0", "results", "pairwise_results.csv"
)

# %% [markdown]
# ## Define Co-Player Prior

# %%
# Uniform Prior over each self-play team of agents (minus Planning agent with default agent id 0)
policy_prior = {
    (-1, 'sp_seed0-v0'): 0.2,
    (-1, 'sp_seed1-v0'): 0.2,
    (-1, 'sp_seed2-v0'): 0.2,
    (-1, 'sp_seed3-v0'): 0.2,
    (-1, 'sp_seed4-v0'): 0.2,
}
fixed_policy_ids = [
    'sp_seed0-v0',
    'sp_seed1-v0',
    'sp_seed2-v0',
    'sp_seed3-v0',
    'sp_seed4-v0'
]
coplayer_policy_ids = fixed_policy_ids

fixed_policy_label_map = {
    'sp_seed0-v0': "S0",
    'sp_seed1-v0': "S1",
    'sp_seed2-v0': "S2",
    'sp_seed3-v0': "S3",
    'sp_seed4-v0': "S4"
}

# %% [markdown]
# # Problem size
#
# **States**
#
# ```
# = pos^(num_predators + num_prey) * caught^num_prey
# = (10*10)^(2+3) * 2^3
# = 8×10^10
# ```
#
# Note, this is a slight overestimate since since agents cannot be in the same pos at the same time.
# But you get the idea.
#
# **Actions** = 5 (do_nothing, up, down,  left, right)
#
# **Observations** = 2 cells in each direction = 5x5 grid

# %% [markdown]
# ## The Environment

# %%
fig, ax = plot_utils.plot_environment(ENV_NAME, (9, 9))
fig.savefig(osp.join(figure_dir, "env.png"))
plt.show()

# %% [markdown]
# ## Loading Heuristic Policy Data

# %%
policy_df = plot_utils.import_results(
    policy_results_file, clean_policy_id=True, add_coplayer_policy_id=True
)

policy_agent_ids = policy_df["agent_id"].unique().tolist()
policy_agent_ids.sort()
print(f"Agent IDs = {policy_agent_ids}")

all_fixed_policy_ids = policy_df["policy_id"].unique().tolist()
all_fixed_policy_ids.sort()
print("\nAll Policies")
print("------------")
for pi_id in all_fixed_policy_ids:
    print("  ", pi_id)
    
# Drop unneeded co-player policies
policy_df = policy_df[policy_df["policy_id"].isin(fixed_policy_ids)]
kept_fixed_policy_ids = policy_df["policy_id"].unique().tolist()
kept_fixed_policy_ids.sort()
print("\nFixed Policies")
print("--------------")
for pi_id in kept_fixed_policy_ids:
    print("  ", pi_id)

print("\nColumns")
print("-------")
for c in policy_df.columns:
    print("  ", c)
# Out:
# Agent IDs = [0, 1]
#
# All Policies
# ------------
#    random-v0
#    sp_seed0-v0
#    sp_seed1-v0
#    sp_seed2-v0
#    sp_seed3-v0
#    sp_seed4-v0
#
# Fixed Policies
# --------------
#    sp_seed0-v0
#    sp_seed1-v0
#    sp_seed2-v0
#    sp_seed3-v0
#    sp_seed4-v0
#
# Columns
# -------
#    exp_id
#    agent_id
#    env_id
#    policy_id
#    exp_seed
#    num_episodes
#    time_limit
#    episode_return_mean
#    episode_return_std
#    episode_return_max
#    episode_return_min
#    episode_steps_mean
#    episode_steps_std
#    episode_time_mean
#    episode_time_std
#    num_episode_done
#    num_LOSS
#    num_DRAW
#    num_WIN
#    num_NA
#    episode_return_CI
#    episode_steps_CI
#    episode_time_CI
#    prop_LOSS
#    prop_DRAW
#    prop_WIN
#    prop_NA
#    num_sims
#    truncated
#    coplayer_policy_id

# %% [markdown]
# ## Fixed policy pairwise performance
#
# This is what was used to generate the meta-policies.
#
# Here we show pairwise performance between each individual policy and co-team

# %%
fig, axs = plot_utils.plot_pairwise_comparison(
    policy_df,
    y_key="episode_return_mean", 
    policy_key="policy_id",
    coplayer_policy_key="coplayer_policy_id",
    y_err_key="episode_return_CI",
    vrange=None, 
    figsize=(6, 3), 
    valfmt="{x:.2f}",
    policies=fixed_policy_ids,
    coplayer_policies=coplayer_policy_ids,
    policy_labels=fixed_policy_label_map,
    average_duplicates=True,
    duplicate_warning=False
)
fig.savefig(osp.join(figure_dir, "fixed_policy_payoffs.png"))
# Out:
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]

# %%
# Get payofss in meta policy dictionary format (for use in experiments)
pw_values, (row_policies, col_policies) = plot_utils.get_pairwise_values(
    policy_df,
    y_key="episode_return_mean", 
    policy_key="policy_id",
    coplayer_policy_key="coplayer_policy_id",
    policies=fixed_policy_ids,
    coplayer_policies=coplayer_policy_ids,
    average_duplicates=True,
    duplicate_warning=True
)

for c, col_policy in enumerate(col_policies):
    print(f'(-1, "{col_policy}"):', "{")
    for r, row_policy in enumerate(row_policies):
        print(f'    "{row_policy}": {pw_values[r][c]:.2f},')
    print("},")
# Out:
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# (-1, "sp_seed0-v0"): {
#     "sp_seed0-v0": 0.98,
#     "sp_seed1-v0": 0.29,
#     "sp_seed2-v0": 0.47,
#     "sp_seed3-v0": 0.32,
#     "sp_seed4-v0": 0.64,
# },
# (-1, "sp_seed1-v0"): {
#     "sp_seed0-v0": 0.29,
#     "sp_seed1-v0": 0.98,
#     "sp_seed2-v0": 0.31,
#     "sp_seed3-v0": 0.30,
#     "sp_seed4-v0": 0.56,
# },
# (-1, "sp_seed2-v0"): {
#     "sp_seed0-v0": 0.47,
#     "sp_seed1-v0": 0.31,
#     "sp_seed2-v0": 0.99,
#     "sp_seed3-v0": 0.71,
#     "sp_seed4-v0": 0.37,
# },
# (-1, "sp_seed3-v0"): {
#     "sp_seed0-v0": 0.32,
#     "sp_seed1-v0": 0.30,
#     "sp_seed2-v0": 0.71,
#     "sp_seed3-v0": 0.99,
#     "sp_seed4-v0": 0.38,
# },
# (-1, "sp_seed4-v0"): {
#     "sp_seed0-v0": 0.64,
#     "sp_seed1-v0": 0.56,
#     "sp_seed2-v0": 0.37,
#     "sp_seed3-v0": 0.38,
#     "sp_seed4-v0": 0.99,
# },

# %% [markdown]
# ## Add Full-Knowledge Best-Response baseline

# %%
# Maps from Co-Team ID to best fixed policy
best_response_map = {
    'sp_seed0-v0': 'sp_seed0-v0',
    'sp_seed1-v0': 'sp_seed1-v0',
    'sp_seed2-v0': 'sp_seed2-v0',
    'sp_seed3-v0': 'sp_seed3-v0',
    'sp_seed4-v0': 'sp_seed4-v0',
}

# use results from agent 0 so it's the same as BA-POSGMCP and other baseline results
br_agent_id = 0

new_rows = []
for co_team_id, br_policy_id in best_response_map.items():
    next_exp_id = policy_df["exp_id"].max() + 1
    
    # Add BR agent row
    br_row = policy_df.loc[
        (policy_df["agent_id"] == br_agent_id)
        & (policy_df["policy_id"] == br_policy_id) 
        & (policy_df["coplayer_policy_id"] == co_team_id)
    ].copy()
    # update policy id to baseline name
    br_row["policy_id"] = "full-knowledge-br"
    # update exp ids to avoid duplicates
    old_exp_id = br_row["exp_id"]
    br_row["exp_id"] = next_exp_id
    new_rows.append(br_row)
    
    # Add Coplayer rows from same exp_id
    for co_agent_id in policy_agent_ids:
        if co_agent_id == br_agent_id:
            continue
        br_coplayer_row = policy_df.loc[
            (policy_df["agent_id"] == co_agent_id)
            & (policy_df["exp_id"].isin(old_exp_id))
        ].copy()
        br_coplayer_row["exp_id"] = next_exp_id
        new_rows.append(br_coplayer_row)

print(f"{len(policy_df)=}")
print(f"{len(new_rows)=}")
br_df = pd.concat(new_rows, axis='rows').reset_index(drop=True)
print(f"{len(br_df)=}")
policy_br_df = pd.concat([policy_df, br_df], ignore_index=True)

print(f"{len(policy_br_df)=} (i.e. all together)")
policy_br_df[policy_br_df["policy_id"] == "full-knowledge-br"]
# Out:
# len(policy_df)=35
# len(new_rows)=10
# len(br_df)=10
# len(policy_br_df)=45 (i.e. all together)
#     exp_id  agent_id                              env_id          policy_id  \
# 35      21         0  PredatorPrey10x10-P2-p3-s2-coop-v0  full-knowledge-br
# 37      21         0  PredatorPrey10x10-P2-p3-s2-coop-v0  full-knowledge-br
# 39      21         0  PredatorPrey10x10-P2-p3-s2-coop-v0  full-knowledge-br
# 41      21         0  PredatorPrey10x10-P2-p3-s2-coop-v0  full-knowledge-br
# 43      21         0  PredatorPrey10x10-P2-p3-s2-coop-v0  full-knowledge-br
#
#     exp_seed  num_episodes time_limit  episode_return_mean  \
# 35         0          1000       None             0.979333
# 37         0          1000       None             0.978333
# 39         0          1000       None             0.988333
# 41         0          1000       None             0.989000
# 43         0          1000       None             0.991000
#
#     episode_return_std  episode_return_max  ...  episode_return_CI  \
# 35            0.095543                 1.0  ...           0.005922
# 37            0.089923                 1.0  ...           0.005573
# 39            0.064786                 1.0  ...           0.004015
# 41            0.068241                 1.0  ...           0.004230
# 43            0.061708                 1.0  ...           0.003825
#
#     episode_steps_CI  episode_time_CI  prop_LOSS  prop_DRAW  prop_WIN  \
# 35          0.531433         0.002710        0.0        0.0     0.947
# 37          0.464842         0.002911        0.0        0.0     0.941
# 39          0.369694         0.002524        0.0        0.0     0.967
# 41          0.485453         0.002314        0.0        0.0     0.971
# 43          0.360629         0.002220        0.0        0.0     0.977
#
#     prop_NA  num_sims  truncated  coplayer_policy_id
# 35    0.053         0      False         sp_seed0-v0
# 37    0.059         0      False         sp_seed1-v0
# 39    0.033         0      False         sp_seed2-v0
# 41    0.029         0      False         sp_seed3-v0
# 43    0.023         0      False         sp_seed4-v0
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Loading BAPOSGMCP Data

# %%
baposgmcp_df = plot_utils.import_results(
    baposgmcp_results_file, clean_policy_id=True, add_coplayer_policy_id=True
)
policy_ids = baposgmcp_df["policy_id"].unique().tolist()
policy_ids.sort()
print("Policies")
print("--------")
for pi_id in policy_ids:
    print("  ", pi_id)

print("\nColumns")
print("-------")
for c in baposgmcp_df.columns:
    print("  ", f'"{c}",')
# Out:
# Policies
# --------
#    POMetaRollout_greedy_numsims10
#    POMetaRollout_greedy_numsims100
#    POMetaRollout_greedy_numsims1000
#    POMetaRollout_greedy_numsims50
#    POMetaRollout_greedy_numsims500
#    POMetaRollout_softmax_numsims10
#    POMetaRollout_softmax_numsims100
#    POMetaRollout_softmax_numsims1000
#    POMetaRollout_softmax_numsims50
#    POMetaRollout_softmax_numsims500
#    POMetaRollout_uniform_numsims10
#    POMetaRollout_uniform_numsims100
#    POMetaRollout_uniform_numsims1000
#    POMetaRollout_uniform_numsims50
#    POMetaRollout_uniform_numsims500
#    POMeta_greedy_numsims10
#    POMeta_greedy_numsims100
#    POMeta_greedy_numsims1000
#    POMeta_greedy_numsims50
#    POMeta_greedy_numsims500
#    POMeta_softmax_numsims10
#    POMeta_softmax_numsims100
#    POMeta_softmax_numsims1000
#    POMeta_softmax_numsims50
#    POMeta_softmax_numsims500
#    POMeta_uniform_numsims10
#    POMeta_uniform_numsims100
#    POMeta_uniform_numsims1000
#    POMeta_uniform_numsims50
#    POMeta_uniform_numsims500
#    baposgmcp_fixed_pispseed0-v0_numsims10
#    baposgmcp_fixed_pispseed0-v0_numsims100
#    baposgmcp_fixed_pispseed0-v0_numsims1000
#    baposgmcp_fixed_pispseed0-v0_numsims50
#    baposgmcp_fixed_pispseed0-v0_numsims500
#    baposgmcp_fixed_pispseed1-v0_numsims10
#    baposgmcp_fixed_pispseed1-v0_numsims100
#    baposgmcp_fixed_pispseed1-v0_numsims1000
#    baposgmcp_fixed_pispseed1-v0_numsims50
#    baposgmcp_fixed_pispseed1-v0_numsims500
#    baposgmcp_fixed_pispseed2-v0_numsims10
#    baposgmcp_fixed_pispseed2-v0_numsims100
#    baposgmcp_fixed_pispseed2-v0_numsims1000
#    baposgmcp_fixed_pispseed2-v0_numsims50
#    baposgmcp_fixed_pispseed2-v0_numsims500
#    baposgmcp_fixed_pispseed3-v0_numsims10
#    baposgmcp_fixed_pispseed3-v0_numsims100
#    baposgmcp_fixed_pispseed3-v0_numsims1000
#    baposgmcp_fixed_pispseed3-v0_numsims50
#    baposgmcp_fixed_pispseed3-v0_numsims500
#    baposgmcp_fixed_pispseed4-v0_numsims10
#    baposgmcp_fixed_pispseed4-v0_numsims100
#    baposgmcp_fixed_pispseed4-v0_numsims1000
#    baposgmcp_fixed_pispseed4-v0_numsims50
#    baposgmcp_fixed_pispseed4-v0_numsims500
#    baposgmcp_greedy_numsims10
#    baposgmcp_greedy_numsims100
#    baposgmcp_greedy_numsims1000
#    baposgmcp_greedy_numsims50
#    baposgmcp_greedy_numsims500
#    baposgmcp_random_numsims10
#    baposgmcp_random_numsims100
#    baposgmcp_random_numsims1000
#    baposgmcp_random_numsims50
#    baposgmcp_random_numsims500
#    baposgmcp_softmax_numsims10
#    baposgmcp_softmax_numsims100
#    baposgmcp_softmax_numsims1000
#    baposgmcp_softmax_numsims50
#    baposgmcp_softmax_numsims500
#    baposgmcp_uniform_numsims10
#    baposgmcp_uniform_numsims100
#    baposgmcp_uniform_numsims1000
#    baposgmcp_uniform_numsims50
#    baposgmcp_uniform_numsims500
#    metabaseline_greedy
#    metabaseline_softmax
#    metabaseline_uniform
#    sp_seed0-v0
#    sp_seed1-v0
#    sp_seed2-v0
#    sp_seed3-v0
#    sp_seed4-v0
#
# Columns
# -------
#    "policy_id",
#    "coplayer_policy_id",
#    "exp_id",
#    "exp_seed",
#    "agent_id",
#    "env_id",
#    "time_limit",
#    "episode_step_limit",
#    "discount",
#    "c_init",
#    "c_base",
#    "truncated",
#    "action_selection",
#    "dirichlet_alpha",
#    "root_exploration_fraction",
#    "known_bounds",
#    "extra_particles_prop",
#    "step_limit",
#    "epsilon",
#    "policy_prior_map",
#    "meta_policy_dict",
#    "num_sims",
#    "num_episodes",
#    "fixed_policy_id",
#    "num_WIN",
#    "num_LOSS",
#    "num_DRAW",
#    "num_NA",
#    "search_time_mean",
#    "search_time_std",
#    "search_time_min",
#    "search_time_max",
#    "update_time_mean",
#    "update_time_std",
#    "update_time_min",
#    "update_time_max",
#    "reinvigoration_time_mean",
#    "reinvigoration_time_std",
#    "reinvigoration_time_min",
#    "reinvigoration_time_max",
#    "evaluation_time_mean",
#    "evaluation_time_std",
#    "evaluation_time_min",
#    "evaluation_time_max",
#    "policy_calls_mean",
#    "policy_calls_std",
#    "policy_calls_min",
#    "policy_calls_max",
#    "inference_time_mean",
#    "inference_time_std",
#    "inference_time_min",
#    "inference_time_max",
#    "search_depth_mean",
#    "search_depth_std",
#    "search_depth_min",
#    "search_depth_max",
#    "min_value_mean",
#    "min_value_std",
#    "min_value_min",
#    "min_value_max",
#    "max_value_mean",
#    "max_value_std",
#    "max_value_min",
#    "max_value_max",
#    "episode_return_mean",
#    "episode_return_std",
#    "episode_return_min",
#    "episode_return_max",
#    "episode_discounted_return_mean",
#    "episode_discounted_return_std",
#    "episode_discounted_return_min",
#    "episode_discounted_return_max",
#    "episode_steps_mean",
#    "episode_steps_std",
#    "episode_steps_min",
#    "episode_steps_max",
#    "episode_time_mean",
#    "episode_time_std",
#    "episode_time_min",
#    "episode_time_max",
#    "action_dist_distance_0_mean",
#    "action_dist_distance_0_std",
#    "action_dist_distance_0_n",
#    "action_dist_distance_1_mean",
#    "action_dist_distance_1_std",
#    "action_dist_distance_1_n",
#    "action_dist_distance_0_0_mean",
#    "action_dist_distance_0_0_std",
#    "action_dist_distance_0_0_n",
#    "action_dist_distance_0_1_mean",
#    "action_dist_distance_0_1_std",
#    "action_dist_distance_0_1_n",
#    "action_dist_distance_0_2_mean",
#    "action_dist_distance_0_2_std",
#    "action_dist_distance_0_2_n",
#    "action_dist_distance_0_3_mean",
#    "action_dist_distance_0_3_std",
#    "action_dist_distance_0_3_n",
#    "action_dist_distance_0_4_mean",
#    "action_dist_distance_0_4_std",
#    "action_dist_distance_0_4_n",
#    "action_dist_distance_0_5_mean",
#    "action_dist_distance_0_5_std",
#    "action_dist_distance_0_5_n",
#    "action_dist_distance_0_6_mean",
#    "action_dist_distance_0_6_std",
#    "action_dist_distance_0_6_n",
#    "action_dist_distance_0_7_mean",
#    "action_dist_distance_0_7_std",
#    "action_dist_distance_0_7_n",
#    "action_dist_distance_0_8_mean",
#    "action_dist_distance_0_8_std",
#    "action_dist_distance_0_8_n",
#    "action_dist_distance_0_9_mean",
#    "action_dist_distance_0_9_std",
#    "action_dist_distance_0_9_n",
#    "action_dist_distance_0_10_mean",
#    "action_dist_distance_0_10_std",
#    "action_dist_distance_0_10_n",
#    "action_dist_distance_0_11_mean",
#    "action_dist_distance_0_11_std",
#    "action_dist_distance_0_11_n",
#    "action_dist_distance_0_12_mean",
#    "action_dist_distance_0_12_std",
#    "action_dist_distance_0_12_n",
#    "action_dist_distance_0_13_mean",
#    "action_dist_distance_0_13_std",
#    "action_dist_distance_0_13_n",
#    "action_dist_distance_0_14_mean",
#    "action_dist_distance_0_14_std",
#    "action_dist_distance_0_14_n",
#    "action_dist_distance_0_15_mean",
#    "action_dist_distance_0_15_std",
#    "action_dist_distance_0_15_n",
#    "action_dist_distance_0_16_mean",
#    "action_dist_distance_0_16_std",
#    "action_dist_distance_0_16_n",
#    "action_dist_distance_0_17_mean",
#    "action_dist_distance_0_17_std",
#    "action_dist_distance_0_17_n",
#    "action_dist_distance_0_18_mean",
#    "action_dist_distance_0_18_std",
#    "action_dist_distance_0_18_n",
#    "action_dist_distance_0_19_mean",
#    "action_dist_distance_0_19_std",
#    "action_dist_distance_0_19_n",
#    "action_dist_distance_0_20_mean",
#    "action_dist_distance_0_20_std",
#    "action_dist_distance_0_20_n",
#    "action_dist_distance_0_21_mean",
#    "action_dist_distance_0_21_std",
#    "action_dist_distance_0_21_n",
#    "action_dist_distance_0_22_mean",
#    "action_dist_distance_0_22_std",
#    "action_dist_distance_0_22_n",
#    "action_dist_distance_0_23_mean",
#    "action_dist_distance_0_23_std",
#    "action_dist_distance_0_23_n",
#    "action_dist_distance_0_24_mean",
#    "action_dist_distance_0_24_std",
#    "action_dist_distance_0_24_n",
#    "action_dist_distance_0_25_mean",
#    "action_dist_distance_0_25_std",
#    "action_dist_distance_0_25_n",
#    "action_dist_distance_0_26_mean",
#    "action_dist_distance_0_26_std",
#    "action_dist_distance_0_26_n",
#    "action_dist_distance_0_27_mean",
#    "action_dist_distance_0_27_std",
#    "action_dist_distance_0_27_n",
#    "action_dist_distance_0_28_mean",
#    "action_dist_distance_0_28_std",
#    "action_dist_distance_0_28_n",
#    "action_dist_distance_0_29_mean",
#    "action_dist_distance_0_29_std",
#    "action_dist_distance_0_29_n",
#    "action_dist_distance_0_30_mean",
#    "action_dist_distance_0_30_std",
#    "action_dist_distance_0_30_n",
#    "action_dist_distance_0_31_mean",
#    "action_dist_distance_0_31_std",
#    "action_dist_distance_0_31_n",
#    "action_dist_distance_0_32_mean",
#    "action_dist_distance_0_32_std",
#    "action_dist_distance_0_32_n",
#    "action_dist_distance_0_33_mean",
#    "action_dist_distance_0_33_std",
#    "action_dist_distance_0_33_n",
#    "action_dist_distance_0_34_mean",
#    "action_dist_distance_0_34_std",
#    "action_dist_distance_0_34_n",
#    "action_dist_distance_0_35_mean",
#    "action_dist_distance_0_35_std",
#    "action_dist_distance_0_35_n",
#    "action_dist_distance_0_36_mean",
#    "action_dist_distance_0_36_std",
#    "action_dist_distance_0_36_n",
#    "action_dist_distance_0_37_mean",
#    "action_dist_distance_0_37_std",
#    "action_dist_distance_0_37_n",
#    "action_dist_distance_0_38_mean",
#    "action_dist_distance_0_38_std",
#    "action_dist_distance_0_38_n",
#    "action_dist_distance_0_39_mean",
#    "action_dist_distance_0_39_std",
#    "action_dist_distance_0_39_n",
#    "action_dist_distance_0_40_mean",
#    "action_dist_distance_0_40_std",
#    "action_dist_distance_0_40_n",
#    "action_dist_distance_0_41_mean",
#    "action_dist_distance_0_41_std",
#    "action_dist_distance_0_41_n",
#    "action_dist_distance_0_42_mean",
#    "action_dist_distance_0_42_std",
#    "action_dist_distance_0_42_n",
#    "action_dist_distance_0_43_mean",
#    "action_dist_distance_0_43_std",
#    "action_dist_distance_0_43_n",
#    "action_dist_distance_0_44_mean",
#    "action_dist_distance_0_44_std",
#    "action_dist_distance_0_44_n",
#    "action_dist_distance_0_45_mean",
#    "action_dist_distance_0_45_std",
#    "action_dist_distance_0_45_n",
#    "action_dist_distance_0_46_mean",
#    "action_dist_distance_0_46_std",
#    "action_dist_distance_0_46_n",
#    "action_dist_distance_0_47_mean",
#    "action_dist_distance_0_47_std",
#    "action_dist_distance_0_47_n",
#    "action_dist_distance_0_48_mean",
#    "action_dist_distance_0_48_std",
#    "action_dist_distance_0_48_n",
#    "action_dist_distance_0_49_mean",
#    "action_dist_distance_0_49_std",
#    "action_dist_distance_0_49_n",
#    "action_dist_distance_1_0_mean",
#    "action_dist_distance_1_0_std",
#    "action_dist_distance_1_0_n",
#    "action_dist_distance_1_1_mean",
#    "action_dist_distance_1_1_std",
#    "action_dist_distance_1_1_n",
#    "action_dist_distance_1_2_mean",
#    "action_dist_distance_1_2_std",
#    "action_dist_distance_1_2_n",
#    "action_dist_distance_1_3_mean",
#    "action_dist_distance_1_3_std",
#    "action_dist_distance_1_3_n",
#    "action_dist_distance_1_4_mean",
#    "action_dist_distance_1_4_std",
#    "action_dist_distance_1_4_n",
#    "action_dist_distance_1_5_mean",
#    "action_dist_distance_1_5_std",
#    "action_dist_distance_1_5_n",
#    "action_dist_distance_1_6_mean",
#    "action_dist_distance_1_6_std",
#    "action_dist_distance_1_6_n",
#    "action_dist_distance_1_7_mean",
#    "action_dist_distance_1_7_std",
#    "action_dist_distance_1_7_n",
#    "action_dist_distance_1_8_mean",
#    "action_dist_distance_1_8_std",
#    "action_dist_distance_1_8_n",
#    "action_dist_distance_1_9_mean",
#    "action_dist_distance_1_9_std",
#    "action_dist_distance_1_9_n",
#    "action_dist_distance_1_10_mean",
#    "action_dist_distance_1_10_std",
#    "action_dist_distance_1_10_n",
#    "action_dist_distance_1_11_mean",
#    "action_dist_distance_1_11_std",
#    "action_dist_distance_1_11_n",
#    "action_dist_distance_1_12_mean",
#    "action_dist_distance_1_12_std",
#    "action_dist_distance_1_12_n",
#    "action_dist_distance_1_13_mean",
#    "action_dist_distance_1_13_std",
#    "action_dist_distance_1_13_n",
#    "action_dist_distance_1_14_mean",
#    "action_dist_distance_1_14_std",
#    "action_dist_distance_1_14_n",
#    "action_dist_distance_1_15_mean",
#    "action_dist_distance_1_15_std",
#    "action_dist_distance_1_15_n",
#    "action_dist_distance_1_16_mean",
#    "action_dist_distance_1_16_std",
#    "action_dist_distance_1_16_n",
#    "action_dist_distance_1_17_mean",
#    "action_dist_distance_1_17_std",
#    "action_dist_distance_1_17_n",
#    "action_dist_distance_1_18_mean",
#    "action_dist_distance_1_18_std",
#    "action_dist_distance_1_18_n",
#    "action_dist_distance_1_19_mean",
#    "action_dist_distance_1_19_std",
#    "action_dist_distance_1_19_n",
#    "action_dist_distance_1_20_mean",
#    "action_dist_distance_1_20_std",
#    "action_dist_distance_1_20_n",
#    "action_dist_distance_1_21_mean",
#    "action_dist_distance_1_21_std",
#    "action_dist_distance_1_21_n",
#    "action_dist_distance_1_22_mean",
#    "action_dist_distance_1_22_std",
#    "action_dist_distance_1_22_n",
#    "action_dist_distance_1_23_mean",
#    "action_dist_distance_1_23_std",
#    "action_dist_distance_1_23_n",
#    "action_dist_distance_1_24_mean",
#    "action_dist_distance_1_24_std",
#    "action_dist_distance_1_24_n",
#    "action_dist_distance_1_25_mean",
#    "action_dist_distance_1_25_std",
#    "action_dist_distance_1_25_n",
#    "action_dist_distance_1_26_mean",
#    "action_dist_distance_1_26_std",
#    "action_dist_distance_1_26_n",
#    "action_dist_distance_1_27_mean",
#    "action_dist_distance_1_27_std",
#    "action_dist_distance_1_27_n",
#    "action_dist_distance_1_28_mean",
#    "action_dist_distance_1_28_std",
#    "action_dist_distance_1_28_n",
#    "action_dist_distance_1_29_mean",
#    "action_dist_distance_1_29_std",
#    "action_dist_distance_1_29_n",
#    "action_dist_distance_1_30_mean",
#    "action_dist_distance_1_30_std",
#    "action_dist_distance_1_30_n",
#    "action_dist_distance_1_31_mean",
#    "action_dist_distance_1_31_std",
#    "action_dist_distance_1_31_n",
#    "action_dist_distance_1_32_mean",
#    "action_dist_distance_1_32_std",
#    "action_dist_distance_1_32_n",
#    "action_dist_distance_1_33_mean",
#    "action_dist_distance_1_33_std",
#    "action_dist_distance_1_33_n",
#    "action_dist_distance_1_34_mean",
#    "action_dist_distance_1_34_std",
#    "action_dist_distance_1_34_n",
#    "action_dist_distance_1_35_mean",
#    "action_dist_distance_1_35_std",
#    "action_dist_distance_1_35_n",
#    "action_dist_distance_1_36_mean",
#    "action_dist_distance_1_36_std",
#    "action_dist_distance_1_36_n",
#    "action_dist_distance_1_37_mean",
#    "action_dist_distance_1_37_std",
#    "action_dist_distance_1_37_n",
#    "action_dist_distance_1_38_mean",
#    "action_dist_distance_1_38_std",
#    "action_dist_distance_1_38_n",
#    "action_dist_distance_1_39_mean",
#    "action_dist_distance_1_39_std",
#    "action_dist_distance_1_39_n",
#    "action_dist_distance_1_40_mean",
#    "action_dist_distance_1_40_std",
#    "action_dist_distance_1_40_n",
#    "action_dist_distance_1_41_mean",
#    "action_dist_distance_1_41_std",
#    "action_dist_distance_1_41_n",
#    "action_dist_distance_1_42_mean",
#    "action_dist_distance_1_42_std",
#    "action_dist_distance_1_42_n",
#    "action_dist_distance_1_43_mean",
#    "action_dist_distance_1_43_std",
#    "action_dist_distance_1_43_n",
#    "action_dist_distance_1_44_mean",
#    "action_dist_distance_1_44_std",
#    "action_dist_distance_1_44_n",
#    "action_dist_distance_1_45_mean",
#    "action_dist_distance_1_45_std",
#    "action_dist_distance_1_45_n",
#    "action_dist_distance_1_46_mean",
#    "action_dist_distance_1_46_std",
#    "action_dist_distance_1_46_n",
#    "action_dist_distance_1_47_mean",
#    "action_dist_distance_1_47_std",
#    "action_dist_distance_1_47_n",
#    "action_dist_distance_1_48_mean",
#    "action_dist_distance_1_48_std",
#    "action_dist_distance_1_48_n",
#    "action_dist_distance_1_49_mean",
#    "action_dist_distance_1_49_std",
#    "action_dist_distance_1_49_n",
#    "bayes_accuracy_0_mean",
#    "bayes_accuracy_0_std",
#    "bayes_accuracy_0_n",
#    "bayes_accuracy_1_mean",
#    "bayes_accuracy_1_std",
#    "bayes_accuracy_1_n",
#    "bayes_accuracy_0_0_mean",
#    "bayes_accuracy_0_0_std",
#    "bayes_accuracy_0_0_n",
#    "bayes_accuracy_0_1_mean",
#    "bayes_accuracy_0_1_std",
#    "bayes_accuracy_0_1_n",
#    "bayes_accuracy_0_2_mean",
#    "bayes_accuracy_0_2_std",
#    "bayes_accuracy_0_2_n",
#    "bayes_accuracy_0_3_mean",
#    "bayes_accuracy_0_3_std",
#    "bayes_accuracy_0_3_n",
#    "bayes_accuracy_0_4_mean",
#    "bayes_accuracy_0_4_std",
#    "bayes_accuracy_0_4_n",
#    "bayes_accuracy_0_5_mean",
#    "bayes_accuracy_0_5_std",
#    "bayes_accuracy_0_5_n",
#    "bayes_accuracy_0_6_mean",
#    "bayes_accuracy_0_6_std",
#    "bayes_accuracy_0_6_n",
#    "bayes_accuracy_0_7_mean",
#    "bayes_accuracy_0_7_std",
#    "bayes_accuracy_0_7_n",
#    "bayes_accuracy_0_8_mean",
#    "bayes_accuracy_0_8_std",
#    "bayes_accuracy_0_8_n",
#    "bayes_accuracy_0_9_mean",
#    "bayes_accuracy_0_9_std",
#    "bayes_accuracy_0_9_n",
#    "bayes_accuracy_0_10_mean",
#    "bayes_accuracy_0_10_std",
#    "bayes_accuracy_0_10_n",
#    "bayes_accuracy_0_11_mean",
#    "bayes_accuracy_0_11_std",
#    "bayes_accuracy_0_11_n",
#    "bayes_accuracy_0_12_mean",
#    "bayes_accuracy_0_12_std",
#    "bayes_accuracy_0_12_n",
#    "bayes_accuracy_0_13_mean",
#    "bayes_accuracy_0_13_std",
#    "bayes_accuracy_0_13_n",
#    "bayes_accuracy_0_14_mean",
#    "bayes_accuracy_0_14_std",
#    "bayes_accuracy_0_14_n",
#    "bayes_accuracy_0_15_mean",
#    "bayes_accuracy_0_15_std",
#    "bayes_accuracy_0_15_n",
#    "bayes_accuracy_0_16_mean",
#    "bayes_accuracy_0_16_std",
#    "bayes_accuracy_0_16_n",
#    "bayes_accuracy_0_17_mean",
#    "bayes_accuracy_0_17_std",
#    "bayes_accuracy_0_17_n",
#    "bayes_accuracy_0_18_mean",
#    "bayes_accuracy_0_18_std",
#    "bayes_accuracy_0_18_n",
#    "bayes_accuracy_0_19_mean",
#    "bayes_accuracy_0_19_std",
#    "bayes_accuracy_0_19_n",
#    "bayes_accuracy_0_20_mean",
#    "bayes_accuracy_0_20_std",
#    "bayes_accuracy_0_20_n",
#    "bayes_accuracy_0_21_mean",
#    "bayes_accuracy_0_21_std",
#    "bayes_accuracy_0_21_n",
#    "bayes_accuracy_0_22_mean",
#    "bayes_accuracy_0_22_std",
#    "bayes_accuracy_0_22_n",
#    "bayes_accuracy_0_23_mean",
#    "bayes_accuracy_0_23_std",
#    "bayes_accuracy_0_23_n",
#    "bayes_accuracy_0_24_mean",
#    "bayes_accuracy_0_24_std",
#    "bayes_accuracy_0_24_n",
#    "bayes_accuracy_0_25_mean",
#    "bayes_accuracy_0_25_std",
#    "bayes_accuracy_0_25_n",
#    "bayes_accuracy_0_26_mean",
#    "bayes_accuracy_0_26_std",
#    "bayes_accuracy_0_26_n",
#    "bayes_accuracy_0_27_mean",
#    "bayes_accuracy_0_27_std",
#    "bayes_accuracy_0_27_n",
#    "bayes_accuracy_0_28_mean",
#    "bayes_accuracy_0_28_std",
#    "bayes_accuracy_0_28_n",
#    "bayes_accuracy_0_29_mean",
#    "bayes_accuracy_0_29_std",
#    "bayes_accuracy_0_29_n",
#    "bayes_accuracy_0_30_mean",
#    "bayes_accuracy_0_30_std",
#    "bayes_accuracy_0_30_n",
#    "bayes_accuracy_0_31_mean",
#    "bayes_accuracy_0_31_std",
#    "bayes_accuracy_0_31_n",
#    "bayes_accuracy_0_32_mean",
#    "bayes_accuracy_0_32_std",
#    "bayes_accuracy_0_32_n",
#    "bayes_accuracy_0_33_mean",
#    "bayes_accuracy_0_33_std",
#    "bayes_accuracy_0_33_n",
#    "bayes_accuracy_0_34_mean",
#    "bayes_accuracy_0_34_std",
#    "bayes_accuracy_0_34_n",
#    "bayes_accuracy_0_35_mean",
#    "bayes_accuracy_0_35_std",
#    "bayes_accuracy_0_35_n",
#    "bayes_accuracy_0_36_mean",
#    "bayes_accuracy_0_36_std",
#    "bayes_accuracy_0_36_n",
#    "bayes_accuracy_0_37_mean",
#    "bayes_accuracy_0_37_std",
#    "bayes_accuracy_0_37_n",
#    "bayes_accuracy_0_38_mean",
#    "bayes_accuracy_0_38_std",
#    "bayes_accuracy_0_38_n",
#    "bayes_accuracy_0_39_mean",
#    "bayes_accuracy_0_39_std",
#    "bayes_accuracy_0_39_n",
#    "bayes_accuracy_0_40_mean",
#    "bayes_accuracy_0_40_std",
#    "bayes_accuracy_0_40_n",
#    "bayes_accuracy_0_41_mean",
#    "bayes_accuracy_0_41_std",
#    "bayes_accuracy_0_41_n",
#    "bayes_accuracy_0_42_mean",
#    "bayes_accuracy_0_42_std",
#    "bayes_accuracy_0_42_n",
#    "bayes_accuracy_0_43_mean",
#    "bayes_accuracy_0_43_std",
#    "bayes_accuracy_0_43_n",
#    "bayes_accuracy_0_44_mean",
#    "bayes_accuracy_0_44_std",
#    "bayes_accuracy_0_44_n",
#    "bayes_accuracy_0_45_mean",
#    "bayes_accuracy_0_45_std",
#    "bayes_accuracy_0_45_n",
#    "bayes_accuracy_0_46_mean",
#    "bayes_accuracy_0_46_std",
#    "bayes_accuracy_0_46_n",
#    "bayes_accuracy_0_47_mean",
#    "bayes_accuracy_0_47_std",
#    "bayes_accuracy_0_47_n",
#    "bayes_accuracy_0_48_mean",
#    "bayes_accuracy_0_48_std",
#    "bayes_accuracy_0_48_n",
#    "bayes_accuracy_0_49_mean",
#    "bayes_accuracy_0_49_std",
#    "bayes_accuracy_0_49_n",
#    "bayes_accuracy_1_0_mean",
#    "bayes_accuracy_1_0_std",
#    "bayes_accuracy_1_0_n",
#    "bayes_accuracy_1_1_mean",
#    "bayes_accuracy_1_1_std",
#    "bayes_accuracy_1_1_n",
#    "bayes_accuracy_1_2_mean",
#    "bayes_accuracy_1_2_std",
#    "bayes_accuracy_1_2_n",
#    "bayes_accuracy_1_3_mean",
#    "bayes_accuracy_1_3_std",
#    "bayes_accuracy_1_3_n",
#    "bayes_accuracy_1_4_mean",
#    "bayes_accuracy_1_4_std",
#    "bayes_accuracy_1_4_n",
#    "bayes_accuracy_1_5_mean",
#    "bayes_accuracy_1_5_std",
#    "bayes_accuracy_1_5_n",
#    "bayes_accuracy_1_6_mean",
#    "bayes_accuracy_1_6_std",
#    "bayes_accuracy_1_6_n",
#    "bayes_accuracy_1_7_mean",
#    "bayes_accuracy_1_7_std",
#    "bayes_accuracy_1_7_n",
#    "bayes_accuracy_1_8_mean",
#    "bayes_accuracy_1_8_std",
#    "bayes_accuracy_1_8_n",
#    "bayes_accuracy_1_9_mean",
#    "bayes_accuracy_1_9_std",
#    "bayes_accuracy_1_9_n",
#    "bayes_accuracy_1_10_mean",
#    "bayes_accuracy_1_10_std",
#    "bayes_accuracy_1_10_n",
#    "bayes_accuracy_1_11_mean",
#    "bayes_accuracy_1_11_std",
#    "bayes_accuracy_1_11_n",
#    "bayes_accuracy_1_12_mean",
#    "bayes_accuracy_1_12_std",
#    "bayes_accuracy_1_12_n",
#    "bayes_accuracy_1_13_mean",
#    "bayes_accuracy_1_13_std",
#    "bayes_accuracy_1_13_n",
#    "bayes_accuracy_1_14_mean",
#    "bayes_accuracy_1_14_std",
#    "bayes_accuracy_1_14_n",
#    "bayes_accuracy_1_15_mean",
#    "bayes_accuracy_1_15_std",
#    "bayes_accuracy_1_15_n",
#    "bayes_accuracy_1_16_mean",
#    "bayes_accuracy_1_16_std",
#    "bayes_accuracy_1_16_n",
#    "bayes_accuracy_1_17_mean",
#    "bayes_accuracy_1_17_std",
#    "bayes_accuracy_1_17_n",
#    "bayes_accuracy_1_18_mean",
#    "bayes_accuracy_1_18_std",
#    "bayes_accuracy_1_18_n",
#    "bayes_accuracy_1_19_mean",
#    "bayes_accuracy_1_19_std",
#    "bayes_accuracy_1_19_n",
#    "bayes_accuracy_1_20_mean",
#    "bayes_accuracy_1_20_std",
#    "bayes_accuracy_1_20_n",
#    "bayes_accuracy_1_21_mean",
#    "bayes_accuracy_1_21_std",
#    "bayes_accuracy_1_21_n",
#    "bayes_accuracy_1_22_mean",
#    "bayes_accuracy_1_22_std",
#    "bayes_accuracy_1_22_n",
#    "bayes_accuracy_1_23_mean",
#    "bayes_accuracy_1_23_std",
#    "bayes_accuracy_1_23_n",
#    "bayes_accuracy_1_24_mean",
#    "bayes_accuracy_1_24_std",
#    "bayes_accuracy_1_24_n",
#    "bayes_accuracy_1_25_mean",
#    "bayes_accuracy_1_25_std",
#    "bayes_accuracy_1_25_n",
#    "bayes_accuracy_1_26_mean",
#    "bayes_accuracy_1_26_std",
#    "bayes_accuracy_1_26_n",
#    "bayes_accuracy_1_27_mean",
#    "bayes_accuracy_1_27_std",
#    "bayes_accuracy_1_27_n",
#    "bayes_accuracy_1_28_mean",
#    "bayes_accuracy_1_28_std",
#    "bayes_accuracy_1_28_n",
#    "bayes_accuracy_1_29_mean",
#    "bayes_accuracy_1_29_std",
#    "bayes_accuracy_1_29_n",
#    "bayes_accuracy_1_30_mean",
#    "bayes_accuracy_1_30_std",
#    "bayes_accuracy_1_30_n",
#    "bayes_accuracy_1_31_mean",
#    "bayes_accuracy_1_31_std",
#    "bayes_accuracy_1_31_n",
#    "bayes_accuracy_1_32_mean",
#    "bayes_accuracy_1_32_std",
#    "bayes_accuracy_1_32_n",
#    "bayes_accuracy_1_33_mean",
#    "bayes_accuracy_1_33_std",
#    "bayes_accuracy_1_33_n",
#    "bayes_accuracy_1_34_mean",
#    "bayes_accuracy_1_34_std",
#    "bayes_accuracy_1_34_n",
#    "bayes_accuracy_1_35_mean",
#    "bayes_accuracy_1_35_std",
#    "bayes_accuracy_1_35_n",
#    "bayes_accuracy_1_36_mean",
#    "bayes_accuracy_1_36_std",
#    "bayes_accuracy_1_36_n",
#    "bayes_accuracy_1_37_mean",
#    "bayes_accuracy_1_37_std",
#    "bayes_accuracy_1_37_n",
#    "bayes_accuracy_1_38_mean",
#    "bayes_accuracy_1_38_std",
#    "bayes_accuracy_1_38_n",
#    "bayes_accuracy_1_39_mean",
#    "bayes_accuracy_1_39_std",
#    "bayes_accuracy_1_39_n",
#    "bayes_accuracy_1_40_mean",
#    "bayes_accuracy_1_40_std",
#    "bayes_accuracy_1_40_n",
#    "bayes_accuracy_1_41_mean",
#    "bayes_accuracy_1_41_std",
#    "bayes_accuracy_1_41_n",
#    "bayes_accuracy_1_42_mean",
#    "bayes_accuracy_1_42_std",
#    "bayes_accuracy_1_42_n",
#    "bayes_accuracy_1_43_mean",
#    "bayes_accuracy_1_43_std",
#    "bayes_accuracy_1_43_n",
#    "bayes_accuracy_1_44_mean",
#    "bayes_accuracy_1_44_std",
#    "bayes_accuracy_1_44_n",
#    "bayes_accuracy_1_45_mean",
#    "bayes_accuracy_1_45_std",
#    "bayes_accuracy_1_45_n",
#    "bayes_accuracy_1_46_mean",
#    "bayes_accuracy_1_46_std",
#    "bayes_accuracy_1_46_n",
#    "bayes_accuracy_1_47_mean",
#    "bayes_accuracy_1_47_std",
#    "bayes_accuracy_1_47_n",
#    "bayes_accuracy_1_48_mean",
#    "bayes_accuracy_1_48_std",
#    "bayes_accuracy_1_48_n",
#    "bayes_accuracy_1_49_mean",
#    "bayes_accuracy_1_49_std",
#    "bayes_accuracy_1_49_n",
#    "search_time_CI",
#    "update_time_CI",
#    "reinvigoration_time_CI",
#    "evaluation_time_CI",
#    "policy_calls_CI",
#    "inference_time_CI",
#    "search_depth_CI",
#    "min_value_CI",
#    "max_value_CI",
#    "episode_return_CI",
#    "episode_discounted_return_CI",
#    "episode_steps_CI",
#    "episode_time_CI",
#    "action_dist_distance_0_CI",
#    "action_dist_distance_1_CI",
#    "action_dist_distance_0_0_CI",
#    "action_dist_distance_0_1_CI",
#    "action_dist_distance_0_2_CI",
#    "action_dist_distance_0_3_CI",
#    "action_dist_distance_0_4_CI",
#    "action_dist_distance_0_5_CI",
#    "action_dist_distance_0_6_CI",
#    "action_dist_distance_0_7_CI",
#    "action_dist_distance_0_8_CI",
#    "action_dist_distance_0_9_CI",
#    "action_dist_distance_0_10_CI",
#    "action_dist_distance_0_11_CI",
#    "action_dist_distance_0_12_CI",
#    "action_dist_distance_0_13_CI",
#    "action_dist_distance_0_14_CI",
#    "action_dist_distance_0_15_CI",
#    "action_dist_distance_0_16_CI",
#    "action_dist_distance_0_17_CI",
#    "action_dist_distance_0_18_CI",
#    "action_dist_distance_0_19_CI",
#    "action_dist_distance_0_20_CI",
#    "action_dist_distance_0_21_CI",
#    "action_dist_distance_0_22_CI",
#    "action_dist_distance_0_23_CI",
#    "action_dist_distance_0_24_CI",
#    "action_dist_distance_0_25_CI",
#    "action_dist_distance_0_26_CI",
#    "action_dist_distance_0_27_CI",
#    "action_dist_distance_0_28_CI",
#    "action_dist_distance_0_29_CI",
#    "action_dist_distance_0_30_CI",
#    "action_dist_distance_0_31_CI",
#    "action_dist_distance_0_32_CI",
#    "action_dist_distance_0_33_CI",
#    "action_dist_distance_0_34_CI",
#    "action_dist_distance_0_35_CI",
#    "action_dist_distance_0_36_CI",
#    "action_dist_distance_0_37_CI",
#    "action_dist_distance_0_38_CI",
#    "action_dist_distance_0_39_CI",
#    "action_dist_distance_0_40_CI",
#    "action_dist_distance_0_41_CI",
#    "action_dist_distance_0_42_CI",
#    "action_dist_distance_0_43_CI",
#    "action_dist_distance_0_44_CI",
#    "action_dist_distance_0_45_CI",
#    "action_dist_distance_0_46_CI",
#    "action_dist_distance_0_47_CI",
#    "action_dist_distance_0_48_CI",
#    "action_dist_distance_0_49_CI",
#    "action_dist_distance_1_0_CI",
#    "action_dist_distance_1_1_CI",
#    "action_dist_distance_1_2_CI",
#    "action_dist_distance_1_3_CI",
#    "action_dist_distance_1_4_CI",
#    "action_dist_distance_1_5_CI",
#    "action_dist_distance_1_6_CI",
#    "action_dist_distance_1_7_CI",
#    "action_dist_distance_1_8_CI",
#    "action_dist_distance_1_9_CI",
#    "action_dist_distance_1_10_CI",
#    "action_dist_distance_1_11_CI",
#    "action_dist_distance_1_12_CI",
#    "action_dist_distance_1_13_CI",
#    "action_dist_distance_1_14_CI",
#    "action_dist_distance_1_15_CI",
#    "action_dist_distance_1_16_CI",
#    "action_dist_distance_1_17_CI",
#    "action_dist_distance_1_18_CI",
#    "action_dist_distance_1_19_CI",
#    "action_dist_distance_1_20_CI",
#    "action_dist_distance_1_21_CI",
#    "action_dist_distance_1_22_CI",
#    "action_dist_distance_1_23_CI",
#    "action_dist_distance_1_24_CI",
#    "action_dist_distance_1_25_CI",
#    "action_dist_distance_1_26_CI",
#    "action_dist_distance_1_27_CI",
#    "action_dist_distance_1_28_CI",
#    "action_dist_distance_1_29_CI",
#    "action_dist_distance_1_30_CI",
#    "action_dist_distance_1_31_CI",
#    "action_dist_distance_1_32_CI",
#    "action_dist_distance_1_33_CI",
#    "action_dist_distance_1_34_CI",
#    "action_dist_distance_1_35_CI",
#    "action_dist_distance_1_36_CI",
#    "action_dist_distance_1_37_CI",
#    "action_dist_distance_1_38_CI",
#    "action_dist_distance_1_39_CI",
#    "action_dist_distance_1_40_CI",
#    "action_dist_distance_1_41_CI",
#    "action_dist_distance_1_42_CI",
#    "action_dist_distance_1_43_CI",
#    "action_dist_distance_1_44_CI",
#    "action_dist_distance_1_45_CI",
#    "action_dist_distance_1_46_CI",
#    "action_dist_distance_1_47_CI",
#    "action_dist_distance_1_48_CI",
#    "action_dist_distance_1_49_CI",
#    "bayes_accuracy_0_CI",
#    "bayes_accuracy_1_CI",
#    "bayes_accuracy_0_0_CI",
#    "bayes_accuracy_0_1_CI",
#    "bayes_accuracy_0_2_CI",
#    "bayes_accuracy_0_3_CI",
#    "bayes_accuracy_0_4_CI",
#    "bayes_accuracy_0_5_CI",
#    "bayes_accuracy_0_6_CI",
#    "bayes_accuracy_0_7_CI",
#    "bayes_accuracy_0_8_CI",
#    "bayes_accuracy_0_9_CI",
#    "bayes_accuracy_0_10_CI",
#    "bayes_accuracy_0_11_CI",
#    "bayes_accuracy_0_12_CI",
#    "bayes_accuracy_0_13_CI",
#    "bayes_accuracy_0_14_CI",
#    "bayes_accuracy_0_15_CI",
#    "bayes_accuracy_0_16_CI",
#    "bayes_accuracy_0_17_CI",
#    "bayes_accuracy_0_18_CI",
#    "bayes_accuracy_0_19_CI",
#    "bayes_accuracy_0_20_CI",
#    "bayes_accuracy_0_21_CI",
#    "bayes_accuracy_0_22_CI",
#    "bayes_accuracy_0_23_CI",
#    "bayes_accuracy_0_24_CI",
#    "bayes_accuracy_0_25_CI",
#    "bayes_accuracy_0_26_CI",
#    "bayes_accuracy_0_27_CI",
#    "bayes_accuracy_0_28_CI",
#    "bayes_accuracy_0_29_CI",
#    "bayes_accuracy_0_30_CI",
#    "bayes_accuracy_0_31_CI",
#    "bayes_accuracy_0_32_CI",
#    "bayes_accuracy_0_33_CI",
#    "bayes_accuracy_0_34_CI",
#    "bayes_accuracy_0_35_CI",
#    "bayes_accuracy_0_36_CI",
#    "bayes_accuracy_0_37_CI",
#    "bayes_accuracy_0_38_CI",
#    "bayes_accuracy_0_39_CI",
#    "bayes_accuracy_0_40_CI",
#    "bayes_accuracy_0_41_CI",
#    "bayes_accuracy_0_42_CI",
#    "bayes_accuracy_0_43_CI",
#    "bayes_accuracy_0_44_CI",
#    "bayes_accuracy_0_45_CI",
#    "bayes_accuracy_0_46_CI",
#    "bayes_accuracy_0_47_CI",
#    "bayes_accuracy_0_48_CI",
#    "bayes_accuracy_0_49_CI",
#    "bayes_accuracy_1_0_CI",
#    "bayes_accuracy_1_1_CI",
#    "bayes_accuracy_1_2_CI",
#    "bayes_accuracy_1_3_CI",
#    "bayes_accuracy_1_4_CI",
#    "bayes_accuracy_1_5_CI",
#    "bayes_accuracy_1_6_CI",
#    "bayes_accuracy_1_7_CI",
#    "bayes_accuracy_1_8_CI",
#    "bayes_accuracy_1_9_CI",
#    "bayes_accuracy_1_10_CI",
#    "bayes_accuracy_1_11_CI",
#    "bayes_accuracy_1_12_CI",
#    "bayes_accuracy_1_13_CI",
#    "bayes_accuracy_1_14_CI",
#    "bayes_accuracy_1_15_CI",
#    "bayes_accuracy_1_16_CI",
#    "bayes_accuracy_1_17_CI",
#    "bayes_accuracy_1_18_CI",
#    "bayes_accuracy_1_19_CI",
#    "bayes_accuracy_1_20_CI",
#    "bayes_accuracy_1_21_CI",
#    "bayes_accuracy_1_22_CI",
#    "bayes_accuracy_1_23_CI",
#    "bayes_accuracy_1_24_CI",
#    "bayes_accuracy_1_25_CI",
#    "bayes_accuracy_1_26_CI",
#    "bayes_accuracy_1_27_CI",
#    "bayes_accuracy_1_28_CI",
#    "bayes_accuracy_1_29_CI",
#    "bayes_accuracy_1_30_CI",
#    "bayes_accuracy_1_31_CI",
#    "bayes_accuracy_1_32_CI",
#    "bayes_accuracy_1_33_CI",
#    "bayes_accuracy_1_34_CI",
#    "bayes_accuracy_1_35_CI",
#    "bayes_accuracy_1_36_CI",
#    "bayes_accuracy_1_37_CI",
#    "bayes_accuracy_1_38_CI",
#    "bayes_accuracy_1_39_CI",
#    "bayes_accuracy_1_40_CI",
#    "bayes_accuracy_1_41_CI",
#    "bayes_accuracy_1_42_CI",
#    "bayes_accuracy_1_43_CI",
#    "bayes_accuracy_1_44_CI",
#    "bayes_accuracy_1_45_CI",
#    "bayes_accuracy_1_46_CI",
#    "bayes_accuracy_1_47_CI",
#    "bayes_accuracy_1_48_CI",
#    "bayes_accuracy_1_49_CI",
#    "prop_LOSS",
#    "prop_DRAW",
#    "prop_WIN",
#    "prop_NA",

# %% [markdown]
# ## Combine data

# %%
# First need to update exp_ids of one dataframe so there are no duplicate exp_ids
df1 = baposgmcp_df
df2 = policy_br_df

df1_max_exp_id = df1["exp_id"].max()
if df2["exp_id"].min() <= df1_max_exp_id:
    df2["exp_id"] += df1_max_exp_id+1

combined_df = pd.concat([df1, df2]).reset_index(drop = True)

def add_alg_id(row):
    pi_id = row["policy_id"]
    if pi_id.startswith("sp_"):
        return "fixed"
    tokens = pi_id.split("_")
    alg_id = "_".join([
        t for t in tokens 
        if all(
            s not in t for s in [
                "actionselection", "numsims", "truncated", "greedy", "softmax", "uniform", "pisp"
            ]
        )
    ])
    return alg_id


def add_meta_pi(row):
    pi_id = row["policy_id"]
    for meta_pi in ["greedy", "softmax", "uniform"]:
        if meta_pi in pi_id:
            return meta_pi
    return "NA"


combined_df["alg_id"] = combined_df.apply(add_alg_id, axis=1)
combined_df["meta_pi"] = combined_df.apply(add_meta_pi, axis=1)
    
policy_ids = combined_df["policy_id"].unique().tolist()
policy_ids.sort()
print("Policies")
print("--------")
for pi_id in policy_ids:
    print("  ", pi_id)
    
alg_ids = combined_df["alg_id"].unique().tolist()
alg_ids.sort()
print("\nAlg IDs")
print("-------")
for n in alg_ids:
    print("  ", n)
    
print("\nMeta Pis:")
print("---------")
print(combined_df["meta_pi"].unique().tolist())

print("\nColumns")
print("-------")
for c in combined_df.columns:
    print("  ", c)
# Out:
# Policies
# --------
#    POMetaRollout_greedy_numsims10
#    POMetaRollout_greedy_numsims100
#    POMetaRollout_greedy_numsims1000
#    POMetaRollout_greedy_numsims50
#    POMetaRollout_greedy_numsims500
#    POMetaRollout_softmax_numsims10
#    POMetaRollout_softmax_numsims100
#    POMetaRollout_softmax_numsims1000
#    POMetaRollout_softmax_numsims50
#    POMetaRollout_softmax_numsims500
#    POMetaRollout_uniform_numsims10
#    POMetaRollout_uniform_numsims100
#    POMetaRollout_uniform_numsims1000
#    POMetaRollout_uniform_numsims50
#    POMetaRollout_uniform_numsims500
#    POMeta_greedy_numsims10
#    POMeta_greedy_numsims100
#    POMeta_greedy_numsims1000
#    POMeta_greedy_numsims50
#    POMeta_greedy_numsims500
#    POMeta_softmax_numsims10
#    POMeta_softmax_numsims100
#    POMeta_softmax_numsims1000
#    POMeta_softmax_numsims50
#    POMeta_softmax_numsims500
#    POMeta_uniform_numsims10
#    POMeta_uniform_numsims100
#    POMeta_uniform_numsims1000
#    POMeta_uniform_numsims50
#    POMeta_uniform_numsims500
#    baposgmcp_fixed_pispseed0-v0_numsims10
#    baposgmcp_fixed_pispseed0-v0_numsims100
#    baposgmcp_fixed_pispseed0-v0_numsims1000
#    baposgmcp_fixed_pispseed0-v0_numsims50
#    baposgmcp_fixed_pispseed0-v0_numsims500
#    baposgmcp_fixed_pispseed1-v0_numsims10
#    baposgmcp_fixed_pispseed1-v0_numsims100
#    baposgmcp_fixed_pispseed1-v0_numsims1000
#    baposgmcp_fixed_pispseed1-v0_numsims50
#    baposgmcp_fixed_pispseed1-v0_numsims500
#    baposgmcp_fixed_pispseed2-v0_numsims10
#    baposgmcp_fixed_pispseed2-v0_numsims100
#    baposgmcp_fixed_pispseed2-v0_numsims1000
#    baposgmcp_fixed_pispseed2-v0_numsims50
#    baposgmcp_fixed_pispseed2-v0_numsims500
#    baposgmcp_fixed_pispseed3-v0_numsims10
#    baposgmcp_fixed_pispseed3-v0_numsims100
#    baposgmcp_fixed_pispseed3-v0_numsims1000
#    baposgmcp_fixed_pispseed3-v0_numsims50
#    baposgmcp_fixed_pispseed3-v0_numsims500
#    baposgmcp_fixed_pispseed4-v0_numsims10
#    baposgmcp_fixed_pispseed4-v0_numsims100
#    baposgmcp_fixed_pispseed4-v0_numsims1000
#    baposgmcp_fixed_pispseed4-v0_numsims50
#    baposgmcp_fixed_pispseed4-v0_numsims500
#    baposgmcp_greedy_numsims10
#    baposgmcp_greedy_numsims100
#    baposgmcp_greedy_numsims1000
#    baposgmcp_greedy_numsims50
#    baposgmcp_greedy_numsims500
#    baposgmcp_random_numsims10
#    baposgmcp_random_numsims100
#    baposgmcp_random_numsims1000
#    baposgmcp_random_numsims50
#    baposgmcp_random_numsims500
#    baposgmcp_softmax_numsims10
#    baposgmcp_softmax_numsims100
#    baposgmcp_softmax_numsims1000
#    baposgmcp_softmax_numsims50
#    baposgmcp_softmax_numsims500
#    baposgmcp_uniform_numsims10
#    baposgmcp_uniform_numsims100
#    baposgmcp_uniform_numsims1000
#    baposgmcp_uniform_numsims50
#    baposgmcp_uniform_numsims500
#    full-knowledge-br
#    metabaseline_greedy
#    metabaseline_softmax
#    metabaseline_uniform
#    sp_seed0-v0
#    sp_seed1-v0
#    sp_seed2-v0
#    sp_seed3-v0
#    sp_seed4-v0
#
# Alg IDs
# -------
#    POMeta
#    POMetaRollout
#    baposgmcp
#    baposgmcp_fixed
#    baposgmcp_random
#    fixed
#    full-knowledge-br
#    metabaseline
#
# Meta Pis:
# ---------
# ['greedy', 'softmax', 'uniform', 'NA']
#
# Columns
# -------
#    policy_id
#    coplayer_policy_id
#    exp_id
#    exp_seed
#    agent_id
#    env_id
#    time_limit
#    episode_step_limit
#    discount
#    c_init
#    c_base
#    truncated
#    action_selection
#    dirichlet_alpha
#    root_exploration_fraction
#    known_bounds
#    extra_particles_prop
#    step_limit
#    epsilon
#    policy_prior_map
#    meta_policy_dict
#    num_sims
#    num_episodes
#    fixed_policy_id
#    num_WIN
#    num_LOSS
#    num_DRAW
#    num_NA
#    search_time_mean
#    search_time_std
#    search_time_min
#    search_time_max
#    update_time_mean
#    update_time_std
#    update_time_min
#    update_time_max
#    reinvigoration_time_mean
#    reinvigoration_time_std
#    reinvigoration_time_min
#    reinvigoration_time_max
#    evaluation_time_mean
#    evaluation_time_std
#    evaluation_time_min
#    evaluation_time_max
#    policy_calls_mean
#    policy_calls_std
#    policy_calls_min
#    policy_calls_max
#    inference_time_mean
#    inference_time_std
#    inference_time_min
#    inference_time_max
#    search_depth_mean
#    search_depth_std
#    search_depth_min
#    search_depth_max
#    min_value_mean
#    min_value_std
#    min_value_min
#    min_value_max
#    max_value_mean
#    max_value_std
#    max_value_min
#    max_value_max
#    episode_return_mean
#    episode_return_std
#    episode_return_min
#    episode_return_max
#    episode_discounted_return_mean
#    episode_discounted_return_std
#    episode_discounted_return_min
#    episode_discounted_return_max
#    episode_steps_mean
#    episode_steps_std
#    episode_steps_min
#    episode_steps_max
#    episode_time_mean
#    episode_time_std
#    episode_time_min
#    episode_time_max
#    action_dist_distance_0_mean
#    action_dist_distance_0_std
#    action_dist_distance_0_n
#    action_dist_distance_1_mean
#    action_dist_distance_1_std
#    action_dist_distance_1_n
#    action_dist_distance_0_0_mean
#    action_dist_distance_0_0_std
#    action_dist_distance_0_0_n
#    action_dist_distance_0_1_mean
#    action_dist_distance_0_1_std
#    action_dist_distance_0_1_n
#    action_dist_distance_0_2_mean
#    action_dist_distance_0_2_std
#    action_dist_distance_0_2_n
#    action_dist_distance_0_3_mean
#    action_dist_distance_0_3_std
#    action_dist_distance_0_3_n
#    action_dist_distance_0_4_mean
#    action_dist_distance_0_4_std
#    action_dist_distance_0_4_n
#    action_dist_distance_0_5_mean
#    action_dist_distance_0_5_std
#    action_dist_distance_0_5_n
#    action_dist_distance_0_6_mean
#    action_dist_distance_0_6_std
#    action_dist_distance_0_6_n
#    action_dist_distance_0_7_mean
#    action_dist_distance_0_7_std
#    action_dist_distance_0_7_n
#    action_dist_distance_0_8_mean
#    action_dist_distance_0_8_std
#    action_dist_distance_0_8_n
#    action_dist_distance_0_9_mean
#    action_dist_distance_0_9_std
#    action_dist_distance_0_9_n
#    action_dist_distance_0_10_mean
#    action_dist_distance_0_10_std
#    action_dist_distance_0_10_n
#    action_dist_distance_0_11_mean
#    action_dist_distance_0_11_std
#    action_dist_distance_0_11_n
#    action_dist_distance_0_12_mean
#    action_dist_distance_0_12_std
#    action_dist_distance_0_12_n
#    action_dist_distance_0_13_mean
#    action_dist_distance_0_13_std
#    action_dist_distance_0_13_n
#    action_dist_distance_0_14_mean
#    action_dist_distance_0_14_std
#    action_dist_distance_0_14_n
#    action_dist_distance_0_15_mean
#    action_dist_distance_0_15_std
#    action_dist_distance_0_15_n
#    action_dist_distance_0_16_mean
#    action_dist_distance_0_16_std
#    action_dist_distance_0_16_n
#    action_dist_distance_0_17_mean
#    action_dist_distance_0_17_std
#    action_dist_distance_0_17_n
#    action_dist_distance_0_18_mean
#    action_dist_distance_0_18_std
#    action_dist_distance_0_18_n
#    action_dist_distance_0_19_mean
#    action_dist_distance_0_19_std
#    action_dist_distance_0_19_n
#    action_dist_distance_0_20_mean
#    action_dist_distance_0_20_std
#    action_dist_distance_0_20_n
#    action_dist_distance_0_21_mean
#    action_dist_distance_0_21_std
#    action_dist_distance_0_21_n
#    action_dist_distance_0_22_mean
#    action_dist_distance_0_22_std
#    action_dist_distance_0_22_n
#    action_dist_distance_0_23_mean
#    action_dist_distance_0_23_std
#    action_dist_distance_0_23_n
#    action_dist_distance_0_24_mean
#    action_dist_distance_0_24_std
#    action_dist_distance_0_24_n
#    action_dist_distance_0_25_mean
#    action_dist_distance_0_25_std
#    action_dist_distance_0_25_n
#    action_dist_distance_0_26_mean
#    action_dist_distance_0_26_std
#    action_dist_distance_0_26_n
#    action_dist_distance_0_27_mean
#    action_dist_distance_0_27_std
#    action_dist_distance_0_27_n
#    action_dist_distance_0_28_mean
#    action_dist_distance_0_28_std
#    action_dist_distance_0_28_n
#    action_dist_distance_0_29_mean
#    action_dist_distance_0_29_std
#    action_dist_distance_0_29_n
#    action_dist_distance_0_30_mean
#    action_dist_distance_0_30_std
#    action_dist_distance_0_30_n
#    action_dist_distance_0_31_mean
#    action_dist_distance_0_31_std
#    action_dist_distance_0_31_n
#    action_dist_distance_0_32_mean
#    action_dist_distance_0_32_std
#    action_dist_distance_0_32_n
#    action_dist_distance_0_33_mean
#    action_dist_distance_0_33_std
#    action_dist_distance_0_33_n
#    action_dist_distance_0_34_mean
#    action_dist_distance_0_34_std
#    action_dist_distance_0_34_n
#    action_dist_distance_0_35_mean
#    action_dist_distance_0_35_std
#    action_dist_distance_0_35_n
#    action_dist_distance_0_36_mean
#    action_dist_distance_0_36_std
#    action_dist_distance_0_36_n
#    action_dist_distance_0_37_mean
#    action_dist_distance_0_37_std
#    action_dist_distance_0_37_n
#    action_dist_distance_0_38_mean
#    action_dist_distance_0_38_std
#    action_dist_distance_0_38_n
#    action_dist_distance_0_39_mean
#    action_dist_distance_0_39_std
#    action_dist_distance_0_39_n
#    action_dist_distance_0_40_mean
#    action_dist_distance_0_40_std
#    action_dist_distance_0_40_n
#    action_dist_distance_0_41_mean
#    action_dist_distance_0_41_std
#    action_dist_distance_0_41_n
#    action_dist_distance_0_42_mean
#    action_dist_distance_0_42_std
#    action_dist_distance_0_42_n
#    action_dist_distance_0_43_mean
#    action_dist_distance_0_43_std
#    action_dist_distance_0_43_n
#    action_dist_distance_0_44_mean
#    action_dist_distance_0_44_std
#    action_dist_distance_0_44_n
#    action_dist_distance_0_45_mean
#    action_dist_distance_0_45_std
#    action_dist_distance_0_45_n
#    action_dist_distance_0_46_mean
#    action_dist_distance_0_46_std
#    action_dist_distance_0_46_n
#    action_dist_distance_0_47_mean
#    action_dist_distance_0_47_std
#    action_dist_distance_0_47_n
#    action_dist_distance_0_48_mean
#    action_dist_distance_0_48_std
#    action_dist_distance_0_48_n
#    action_dist_distance_0_49_mean
#    action_dist_distance_0_49_std
#    action_dist_distance_0_49_n
#    action_dist_distance_1_0_mean
#    action_dist_distance_1_0_std
#    action_dist_distance_1_0_n
#    action_dist_distance_1_1_mean
#    action_dist_distance_1_1_std
#    action_dist_distance_1_1_n
#    action_dist_distance_1_2_mean
#    action_dist_distance_1_2_std
#    action_dist_distance_1_2_n
#    action_dist_distance_1_3_mean
#    action_dist_distance_1_3_std
#    action_dist_distance_1_3_n
#    action_dist_distance_1_4_mean
#    action_dist_distance_1_4_std
#    action_dist_distance_1_4_n
#    action_dist_distance_1_5_mean
#    action_dist_distance_1_5_std
#    action_dist_distance_1_5_n
#    action_dist_distance_1_6_mean
#    action_dist_distance_1_6_std
#    action_dist_distance_1_6_n
#    action_dist_distance_1_7_mean
#    action_dist_distance_1_7_std
#    action_dist_distance_1_7_n
#    action_dist_distance_1_8_mean
#    action_dist_distance_1_8_std
#    action_dist_distance_1_8_n
#    action_dist_distance_1_9_mean
#    action_dist_distance_1_9_std
#    action_dist_distance_1_9_n
#    action_dist_distance_1_10_mean
#    action_dist_distance_1_10_std
#    action_dist_distance_1_10_n
#    action_dist_distance_1_11_mean
#    action_dist_distance_1_11_std
#    action_dist_distance_1_11_n
#    action_dist_distance_1_12_mean
#    action_dist_distance_1_12_std
#    action_dist_distance_1_12_n
#    action_dist_distance_1_13_mean
#    action_dist_distance_1_13_std
#    action_dist_distance_1_13_n
#    action_dist_distance_1_14_mean
#    action_dist_distance_1_14_std
#    action_dist_distance_1_14_n
#    action_dist_distance_1_15_mean
#    action_dist_distance_1_15_std
#    action_dist_distance_1_15_n
#    action_dist_distance_1_16_mean
#    action_dist_distance_1_16_std
#    action_dist_distance_1_16_n
#    action_dist_distance_1_17_mean
#    action_dist_distance_1_17_std
#    action_dist_distance_1_17_n
#    action_dist_distance_1_18_mean
#    action_dist_distance_1_18_std
#    action_dist_distance_1_18_n
#    action_dist_distance_1_19_mean
#    action_dist_distance_1_19_std
#    action_dist_distance_1_19_n
#    action_dist_distance_1_20_mean
#    action_dist_distance_1_20_std
#    action_dist_distance_1_20_n
#    action_dist_distance_1_21_mean
#    action_dist_distance_1_21_std
#    action_dist_distance_1_21_n
#    action_dist_distance_1_22_mean
#    action_dist_distance_1_22_std
#    action_dist_distance_1_22_n
#    action_dist_distance_1_23_mean
#    action_dist_distance_1_23_std
#    action_dist_distance_1_23_n
#    action_dist_distance_1_24_mean
#    action_dist_distance_1_24_std
#    action_dist_distance_1_24_n
#    action_dist_distance_1_25_mean
#    action_dist_distance_1_25_std
#    action_dist_distance_1_25_n
#    action_dist_distance_1_26_mean
#    action_dist_distance_1_26_std
#    action_dist_distance_1_26_n
#    action_dist_distance_1_27_mean
#    action_dist_distance_1_27_std
#    action_dist_distance_1_27_n
#    action_dist_distance_1_28_mean
#    action_dist_distance_1_28_std
#    action_dist_distance_1_28_n
#    action_dist_distance_1_29_mean
#    action_dist_distance_1_29_std
#    action_dist_distance_1_29_n
#    action_dist_distance_1_30_mean
#    action_dist_distance_1_30_std
#    action_dist_distance_1_30_n
#    action_dist_distance_1_31_mean
#    action_dist_distance_1_31_std
#    action_dist_distance_1_31_n
#    action_dist_distance_1_32_mean
#    action_dist_distance_1_32_std
#    action_dist_distance_1_32_n
#    action_dist_distance_1_33_mean
#    action_dist_distance_1_33_std
#    action_dist_distance_1_33_n
#    action_dist_distance_1_34_mean
#    action_dist_distance_1_34_std
#    action_dist_distance_1_34_n
#    action_dist_distance_1_35_mean
#    action_dist_distance_1_35_std
#    action_dist_distance_1_35_n
#    action_dist_distance_1_36_mean
#    action_dist_distance_1_36_std
#    action_dist_distance_1_36_n
#    action_dist_distance_1_37_mean
#    action_dist_distance_1_37_std
#    action_dist_distance_1_37_n
#    action_dist_distance_1_38_mean
#    action_dist_distance_1_38_std
#    action_dist_distance_1_38_n
#    action_dist_distance_1_39_mean
#    action_dist_distance_1_39_std
#    action_dist_distance_1_39_n
#    action_dist_distance_1_40_mean
#    action_dist_distance_1_40_std
#    action_dist_distance_1_40_n
#    action_dist_distance_1_41_mean
#    action_dist_distance_1_41_std
#    action_dist_distance_1_41_n
#    action_dist_distance_1_42_mean
#    action_dist_distance_1_42_std
#    action_dist_distance_1_42_n
#    action_dist_distance_1_43_mean
#    action_dist_distance_1_43_std
#    action_dist_distance_1_43_n
#    action_dist_distance_1_44_mean
#    action_dist_distance_1_44_std
#    action_dist_distance_1_44_n
#    action_dist_distance_1_45_mean
#    action_dist_distance_1_45_std
#    action_dist_distance_1_45_n
#    action_dist_distance_1_46_mean
#    action_dist_distance_1_46_std
#    action_dist_distance_1_46_n
#    action_dist_distance_1_47_mean
#    action_dist_distance_1_47_std
#    action_dist_distance_1_47_n
#    action_dist_distance_1_48_mean
#    action_dist_distance_1_48_std
#    action_dist_distance_1_48_n
#    action_dist_distance_1_49_mean
#    action_dist_distance_1_49_std
#    action_dist_distance_1_49_n
#    bayes_accuracy_0_mean
#    bayes_accuracy_0_std
#    bayes_accuracy_0_n
#    bayes_accuracy_1_mean
#    bayes_accuracy_1_std
#    bayes_accuracy_1_n
#    bayes_accuracy_0_0_mean
#    bayes_accuracy_0_0_std
#    bayes_accuracy_0_0_n
#    bayes_accuracy_0_1_mean
#    bayes_accuracy_0_1_std
#    bayes_accuracy_0_1_n
#    bayes_accuracy_0_2_mean
#    bayes_accuracy_0_2_std
#    bayes_accuracy_0_2_n
#    bayes_accuracy_0_3_mean
#    bayes_accuracy_0_3_std
#    bayes_accuracy_0_3_n
#    bayes_accuracy_0_4_mean
#    bayes_accuracy_0_4_std
#    bayes_accuracy_0_4_n
#    bayes_accuracy_0_5_mean
#    bayes_accuracy_0_5_std
#    bayes_accuracy_0_5_n
#    bayes_accuracy_0_6_mean
#    bayes_accuracy_0_6_std
#    bayes_accuracy_0_6_n
#    bayes_accuracy_0_7_mean
#    bayes_accuracy_0_7_std
#    bayes_accuracy_0_7_n
#    bayes_accuracy_0_8_mean
#    bayes_accuracy_0_8_std
#    bayes_accuracy_0_8_n
#    bayes_accuracy_0_9_mean
#    bayes_accuracy_0_9_std
#    bayes_accuracy_0_9_n
#    bayes_accuracy_0_10_mean
#    bayes_accuracy_0_10_std
#    bayes_accuracy_0_10_n
#    bayes_accuracy_0_11_mean
#    bayes_accuracy_0_11_std
#    bayes_accuracy_0_11_n
#    bayes_accuracy_0_12_mean
#    bayes_accuracy_0_12_std
#    bayes_accuracy_0_12_n
#    bayes_accuracy_0_13_mean
#    bayes_accuracy_0_13_std
#    bayes_accuracy_0_13_n
#    bayes_accuracy_0_14_mean
#    bayes_accuracy_0_14_std
#    bayes_accuracy_0_14_n
#    bayes_accuracy_0_15_mean
#    bayes_accuracy_0_15_std
#    bayes_accuracy_0_15_n
#    bayes_accuracy_0_16_mean
#    bayes_accuracy_0_16_std
#    bayes_accuracy_0_16_n
#    bayes_accuracy_0_17_mean
#    bayes_accuracy_0_17_std
#    bayes_accuracy_0_17_n
#    bayes_accuracy_0_18_mean
#    bayes_accuracy_0_18_std
#    bayes_accuracy_0_18_n
#    bayes_accuracy_0_19_mean
#    bayes_accuracy_0_19_std
#    bayes_accuracy_0_19_n
#    bayes_accuracy_0_20_mean
#    bayes_accuracy_0_20_std
#    bayes_accuracy_0_20_n
#    bayes_accuracy_0_21_mean
#    bayes_accuracy_0_21_std
#    bayes_accuracy_0_21_n
#    bayes_accuracy_0_22_mean
#    bayes_accuracy_0_22_std
#    bayes_accuracy_0_22_n
#    bayes_accuracy_0_23_mean
#    bayes_accuracy_0_23_std
#    bayes_accuracy_0_23_n
#    bayes_accuracy_0_24_mean
#    bayes_accuracy_0_24_std
#    bayes_accuracy_0_24_n
#    bayes_accuracy_0_25_mean
#    bayes_accuracy_0_25_std
#    bayes_accuracy_0_25_n
#    bayes_accuracy_0_26_mean
#    bayes_accuracy_0_26_std
#    bayes_accuracy_0_26_n
#    bayes_accuracy_0_27_mean
#    bayes_accuracy_0_27_std
#    bayes_accuracy_0_27_n
#    bayes_accuracy_0_28_mean
#    bayes_accuracy_0_28_std
#    bayes_accuracy_0_28_n
#    bayes_accuracy_0_29_mean
#    bayes_accuracy_0_29_std
#    bayes_accuracy_0_29_n
#    bayes_accuracy_0_30_mean
#    bayes_accuracy_0_30_std
#    bayes_accuracy_0_30_n
#    bayes_accuracy_0_31_mean
#    bayes_accuracy_0_31_std
#    bayes_accuracy_0_31_n
#    bayes_accuracy_0_32_mean
#    bayes_accuracy_0_32_std
#    bayes_accuracy_0_32_n
#    bayes_accuracy_0_33_mean
#    bayes_accuracy_0_33_std
#    bayes_accuracy_0_33_n
#    bayes_accuracy_0_34_mean
#    bayes_accuracy_0_34_std
#    bayes_accuracy_0_34_n
#    bayes_accuracy_0_35_mean
#    bayes_accuracy_0_35_std
#    bayes_accuracy_0_35_n
#    bayes_accuracy_0_36_mean
#    bayes_accuracy_0_36_std
#    bayes_accuracy_0_36_n
#    bayes_accuracy_0_37_mean
#    bayes_accuracy_0_37_std
#    bayes_accuracy_0_37_n
#    bayes_accuracy_0_38_mean
#    bayes_accuracy_0_38_std
#    bayes_accuracy_0_38_n
#    bayes_accuracy_0_39_mean
#    bayes_accuracy_0_39_std
#    bayes_accuracy_0_39_n
#    bayes_accuracy_0_40_mean
#    bayes_accuracy_0_40_std
#    bayes_accuracy_0_40_n
#    bayes_accuracy_0_41_mean
#    bayes_accuracy_0_41_std
#    bayes_accuracy_0_41_n
#    bayes_accuracy_0_42_mean
#    bayes_accuracy_0_42_std
#    bayes_accuracy_0_42_n
#    bayes_accuracy_0_43_mean
#    bayes_accuracy_0_43_std
#    bayes_accuracy_0_43_n
#    bayes_accuracy_0_44_mean
#    bayes_accuracy_0_44_std
#    bayes_accuracy_0_44_n
#    bayes_accuracy_0_45_mean
#    bayes_accuracy_0_45_std
#    bayes_accuracy_0_45_n
#    bayes_accuracy_0_46_mean
#    bayes_accuracy_0_46_std
#    bayes_accuracy_0_46_n
#    bayes_accuracy_0_47_mean
#    bayes_accuracy_0_47_std
#    bayes_accuracy_0_47_n
#    bayes_accuracy_0_48_mean
#    bayes_accuracy_0_48_std
#    bayes_accuracy_0_48_n
#    bayes_accuracy_0_49_mean
#    bayes_accuracy_0_49_std
#    bayes_accuracy_0_49_n
#    bayes_accuracy_1_0_mean
#    bayes_accuracy_1_0_std
#    bayes_accuracy_1_0_n
#    bayes_accuracy_1_1_mean
#    bayes_accuracy_1_1_std
#    bayes_accuracy_1_1_n
#    bayes_accuracy_1_2_mean
#    bayes_accuracy_1_2_std
#    bayes_accuracy_1_2_n
#    bayes_accuracy_1_3_mean
#    bayes_accuracy_1_3_std
#    bayes_accuracy_1_3_n
#    bayes_accuracy_1_4_mean
#    bayes_accuracy_1_4_std
#    bayes_accuracy_1_4_n
#    bayes_accuracy_1_5_mean
#    bayes_accuracy_1_5_std
#    bayes_accuracy_1_5_n
#    bayes_accuracy_1_6_mean
#    bayes_accuracy_1_6_std
#    bayes_accuracy_1_6_n
#    bayes_accuracy_1_7_mean
#    bayes_accuracy_1_7_std
#    bayes_accuracy_1_7_n
#    bayes_accuracy_1_8_mean
#    bayes_accuracy_1_8_std
#    bayes_accuracy_1_8_n
#    bayes_accuracy_1_9_mean
#    bayes_accuracy_1_9_std
#    bayes_accuracy_1_9_n
#    bayes_accuracy_1_10_mean
#    bayes_accuracy_1_10_std
#    bayes_accuracy_1_10_n
#    bayes_accuracy_1_11_mean
#    bayes_accuracy_1_11_std
#    bayes_accuracy_1_11_n
#    bayes_accuracy_1_12_mean
#    bayes_accuracy_1_12_std
#    bayes_accuracy_1_12_n
#    bayes_accuracy_1_13_mean
#    bayes_accuracy_1_13_std
#    bayes_accuracy_1_13_n
#    bayes_accuracy_1_14_mean
#    bayes_accuracy_1_14_std
#    bayes_accuracy_1_14_n
#    bayes_accuracy_1_15_mean
#    bayes_accuracy_1_15_std
#    bayes_accuracy_1_15_n
#    bayes_accuracy_1_16_mean
#    bayes_accuracy_1_16_std
#    bayes_accuracy_1_16_n
#    bayes_accuracy_1_17_mean
#    bayes_accuracy_1_17_std
#    bayes_accuracy_1_17_n
#    bayes_accuracy_1_18_mean
#    bayes_accuracy_1_18_std
#    bayes_accuracy_1_18_n
#    bayes_accuracy_1_19_mean
#    bayes_accuracy_1_19_std
#    bayes_accuracy_1_19_n
#    bayes_accuracy_1_20_mean
#    bayes_accuracy_1_20_std
#    bayes_accuracy_1_20_n
#    bayes_accuracy_1_21_mean
#    bayes_accuracy_1_21_std
#    bayes_accuracy_1_21_n
#    bayes_accuracy_1_22_mean
#    bayes_accuracy_1_22_std
#    bayes_accuracy_1_22_n
#    bayes_accuracy_1_23_mean
#    bayes_accuracy_1_23_std
#    bayes_accuracy_1_23_n
#    bayes_accuracy_1_24_mean
#    bayes_accuracy_1_24_std
#    bayes_accuracy_1_24_n
#    bayes_accuracy_1_25_mean
#    bayes_accuracy_1_25_std
#    bayes_accuracy_1_25_n
#    bayes_accuracy_1_26_mean
#    bayes_accuracy_1_26_std
#    bayes_accuracy_1_26_n
#    bayes_accuracy_1_27_mean
#    bayes_accuracy_1_27_std
#    bayes_accuracy_1_27_n
#    bayes_accuracy_1_28_mean
#    bayes_accuracy_1_28_std
#    bayes_accuracy_1_28_n
#    bayes_accuracy_1_29_mean
#    bayes_accuracy_1_29_std
#    bayes_accuracy_1_29_n
#    bayes_accuracy_1_30_mean
#    bayes_accuracy_1_30_std
#    bayes_accuracy_1_30_n
#    bayes_accuracy_1_31_mean
#    bayes_accuracy_1_31_std
#    bayes_accuracy_1_31_n
#    bayes_accuracy_1_32_mean
#    bayes_accuracy_1_32_std
#    bayes_accuracy_1_32_n
#    bayes_accuracy_1_33_mean
#    bayes_accuracy_1_33_std
#    bayes_accuracy_1_33_n
#    bayes_accuracy_1_34_mean
#    bayes_accuracy_1_34_std
#    bayes_accuracy_1_34_n
#    bayes_accuracy_1_35_mean
#    bayes_accuracy_1_35_std
#    bayes_accuracy_1_35_n
#    bayes_accuracy_1_36_mean
#    bayes_accuracy_1_36_std
#    bayes_accuracy_1_36_n
#    bayes_accuracy_1_37_mean
#    bayes_accuracy_1_37_std
#    bayes_accuracy_1_37_n
#    bayes_accuracy_1_38_mean
#    bayes_accuracy_1_38_std
#    bayes_accuracy_1_38_n
#    bayes_accuracy_1_39_mean
#    bayes_accuracy_1_39_std
#    bayes_accuracy_1_39_n
#    bayes_accuracy_1_40_mean
#    bayes_accuracy_1_40_std
#    bayes_accuracy_1_40_n
#    bayes_accuracy_1_41_mean
#    bayes_accuracy_1_41_std
#    bayes_accuracy_1_41_n
#    bayes_accuracy_1_42_mean
#    bayes_accuracy_1_42_std
#    bayes_accuracy_1_42_n
#    bayes_accuracy_1_43_mean
#    bayes_accuracy_1_43_std
#    bayes_accuracy_1_43_n
#    bayes_accuracy_1_44_mean
#    bayes_accuracy_1_44_std
#    bayes_accuracy_1_44_n
#    bayes_accuracy_1_45_mean
#    bayes_accuracy_1_45_std
#    bayes_accuracy_1_45_n
#    bayes_accuracy_1_46_mean
#    bayes_accuracy_1_46_std
#    bayes_accuracy_1_46_n
#    bayes_accuracy_1_47_mean
#    bayes_accuracy_1_47_std
#    bayes_accuracy_1_47_n
#    bayes_accuracy_1_48_mean
#    bayes_accuracy_1_48_std
#    bayes_accuracy_1_48_n
#    bayes_accuracy_1_49_mean
#    bayes_accuracy_1_49_std
#    bayes_accuracy_1_49_n
#    search_time_CI
#    update_time_CI
#    reinvigoration_time_CI
#    evaluation_time_CI
#    policy_calls_CI
#    inference_time_CI
#    search_depth_CI
#    min_value_CI
#    max_value_CI
#    episode_return_CI
#    episode_discounted_return_CI
#    episode_steps_CI
#    episode_time_CI
#    action_dist_distance_0_CI
#    action_dist_distance_1_CI
#    action_dist_distance_0_0_CI
#    action_dist_distance_0_1_CI
#    action_dist_distance_0_2_CI
#    action_dist_distance_0_3_CI
#    action_dist_distance_0_4_CI
#    action_dist_distance_0_5_CI
#    action_dist_distance_0_6_CI
#    action_dist_distance_0_7_CI
#    action_dist_distance_0_8_CI
#    action_dist_distance_0_9_CI
#    action_dist_distance_0_10_CI
#    action_dist_distance_0_11_CI
#    action_dist_distance_0_12_CI
#    action_dist_distance_0_13_CI
#    action_dist_distance_0_14_CI
#    action_dist_distance_0_15_CI
#    action_dist_distance_0_16_CI
#    action_dist_distance_0_17_CI
#    action_dist_distance_0_18_CI
#    action_dist_distance_0_19_CI
#    action_dist_distance_0_20_CI
#    action_dist_distance_0_21_CI
#    action_dist_distance_0_22_CI
#    action_dist_distance_0_23_CI
#    action_dist_distance_0_24_CI
#    action_dist_distance_0_25_CI
#    action_dist_distance_0_26_CI
#    action_dist_distance_0_27_CI
#    action_dist_distance_0_28_CI
#    action_dist_distance_0_29_CI
#    action_dist_distance_0_30_CI
#    action_dist_distance_0_31_CI
#    action_dist_distance_0_32_CI
#    action_dist_distance_0_33_CI
#    action_dist_distance_0_34_CI
#    action_dist_distance_0_35_CI
#    action_dist_distance_0_36_CI
#    action_dist_distance_0_37_CI
#    action_dist_distance_0_38_CI
#    action_dist_distance_0_39_CI
#    action_dist_distance_0_40_CI
#    action_dist_distance_0_41_CI
#    action_dist_distance_0_42_CI
#    action_dist_distance_0_43_CI
#    action_dist_distance_0_44_CI
#    action_dist_distance_0_45_CI
#    action_dist_distance_0_46_CI
#    action_dist_distance_0_47_CI
#    action_dist_distance_0_48_CI
#    action_dist_distance_0_49_CI
#    action_dist_distance_1_0_CI
#    action_dist_distance_1_1_CI
#    action_dist_distance_1_2_CI
#    action_dist_distance_1_3_CI
#    action_dist_distance_1_4_CI
#    action_dist_distance_1_5_CI
#    action_dist_distance_1_6_CI
#    action_dist_distance_1_7_CI
#    action_dist_distance_1_8_CI
#    action_dist_distance_1_9_CI
#    action_dist_distance_1_10_CI
#    action_dist_distance_1_11_CI
#    action_dist_distance_1_12_CI
#    action_dist_distance_1_13_CI
#    action_dist_distance_1_14_CI
#    action_dist_distance_1_15_CI
#    action_dist_distance_1_16_CI
#    action_dist_distance_1_17_CI
#    action_dist_distance_1_18_CI
#    action_dist_distance_1_19_CI
#    action_dist_distance_1_20_CI
#    action_dist_distance_1_21_CI
#    action_dist_distance_1_22_CI
#    action_dist_distance_1_23_CI
#    action_dist_distance_1_24_CI
#    action_dist_distance_1_25_CI
#    action_dist_distance_1_26_CI
#    action_dist_distance_1_27_CI
#    action_dist_distance_1_28_CI
#    action_dist_distance_1_29_CI
#    action_dist_distance_1_30_CI
#    action_dist_distance_1_31_CI
#    action_dist_distance_1_32_CI
#    action_dist_distance_1_33_CI
#    action_dist_distance_1_34_CI
#    action_dist_distance_1_35_CI
#    action_dist_distance_1_36_CI
#    action_dist_distance_1_37_CI
#    action_dist_distance_1_38_CI
#    action_dist_distance_1_39_CI
#    action_dist_distance_1_40_CI
#    action_dist_distance_1_41_CI
#    action_dist_distance_1_42_CI
#    action_dist_distance_1_43_CI
#    action_dist_distance_1_44_CI
#    action_dist_distance_1_45_CI
#    action_dist_distance_1_46_CI
#    action_dist_distance_1_47_CI
#    action_dist_distance_1_48_CI
#    action_dist_distance_1_49_CI
#    bayes_accuracy_0_CI
#    bayes_accuracy_1_CI
#    bayes_accuracy_0_0_CI
#    bayes_accuracy_0_1_CI
#    bayes_accuracy_0_2_CI
#    bayes_accuracy_0_3_CI
#    bayes_accuracy_0_4_CI
#    bayes_accuracy_0_5_CI
#    bayes_accuracy_0_6_CI
#    bayes_accuracy_0_7_CI
#    bayes_accuracy_0_8_CI
#    bayes_accuracy_0_9_CI
#    bayes_accuracy_0_10_CI
#    bayes_accuracy_0_11_CI
#    bayes_accuracy_0_12_CI
#    bayes_accuracy_0_13_CI
#    bayes_accuracy_0_14_CI
#    bayes_accuracy_0_15_CI
#    bayes_accuracy_0_16_CI
#    bayes_accuracy_0_17_CI
#    bayes_accuracy_0_18_CI
#    bayes_accuracy_0_19_CI
#    bayes_accuracy_0_20_CI
#    bayes_accuracy_0_21_CI
#    bayes_accuracy_0_22_CI
#    bayes_accuracy_0_23_CI
#    bayes_accuracy_0_24_CI
#    bayes_accuracy_0_25_CI
#    bayes_accuracy_0_26_CI
#    bayes_accuracy_0_27_CI
#    bayes_accuracy_0_28_CI
#    bayes_accuracy_0_29_CI
#    bayes_accuracy_0_30_CI
#    bayes_accuracy_0_31_CI
#    bayes_accuracy_0_32_CI
#    bayes_accuracy_0_33_CI
#    bayes_accuracy_0_34_CI
#    bayes_accuracy_0_35_CI
#    bayes_accuracy_0_36_CI
#    bayes_accuracy_0_37_CI
#    bayes_accuracy_0_38_CI
#    bayes_accuracy_0_39_CI
#    bayes_accuracy_0_40_CI
#    bayes_accuracy_0_41_CI
#    bayes_accuracy_0_42_CI
#    bayes_accuracy_0_43_CI
#    bayes_accuracy_0_44_CI
#    bayes_accuracy_0_45_CI
#    bayes_accuracy_0_46_CI
#    bayes_accuracy_0_47_CI
#    bayes_accuracy_0_48_CI
#    bayes_accuracy_0_49_CI
#    bayes_accuracy_1_0_CI
#    bayes_accuracy_1_1_CI
#    bayes_accuracy_1_2_CI
#    bayes_accuracy_1_3_CI
#    bayes_accuracy_1_4_CI
#    bayes_accuracy_1_5_CI
#    bayes_accuracy_1_6_CI
#    bayes_accuracy_1_7_CI
#    bayes_accuracy_1_8_CI
#    bayes_accuracy_1_9_CI
#    bayes_accuracy_1_10_CI
#    bayes_accuracy_1_11_CI
#    bayes_accuracy_1_12_CI
#    bayes_accuracy_1_13_CI
#    bayes_accuracy_1_14_CI
#    bayes_accuracy_1_15_CI
#    bayes_accuracy_1_16_CI
#    bayes_accuracy_1_17_CI
#    bayes_accuracy_1_18_CI
#    bayes_accuracy_1_19_CI
#    bayes_accuracy_1_20_CI
#    bayes_accuracy_1_21_CI
#    bayes_accuracy_1_22_CI
#    bayes_accuracy_1_23_CI
#    bayes_accuracy_1_24_CI
#    bayes_accuracy_1_25_CI
#    bayes_accuracy_1_26_CI
#    bayes_accuracy_1_27_CI
#    bayes_accuracy_1_28_CI
#    bayes_accuracy_1_29_CI
#    bayes_accuracy_1_30_CI
#    bayes_accuracy_1_31_CI
#    bayes_accuracy_1_32_CI
#    bayes_accuracy_1_33_CI
#    bayes_accuracy_1_34_CI
#    bayes_accuracy_1_35_CI
#    bayes_accuracy_1_36_CI
#    bayes_accuracy_1_37_CI
#    bayes_accuracy_1_38_CI
#    bayes_accuracy_1_39_CI
#    bayes_accuracy_1_40_CI
#    bayes_accuracy_1_41_CI
#    bayes_accuracy_1_42_CI
#    bayes_accuracy_1_43_CI
#    bayes_accuracy_1_44_CI
#    bayes_accuracy_1_45_CI
#    bayes_accuracy_1_46_CI
#    bayes_accuracy_1_47_CI
#    bayes_accuracy_1_48_CI
#    bayes_accuracy_1_49_CI
#    prop_LOSS
#    prop_DRAW
#    prop_WIN
#    prop_NA
#    num_episode_done
#    alg_id
#    meta_pi

# %% [markdown]
# ## Pairwise performance
#
# Here we look at the performance of each policy against each other policy including BAPOSGMCP and baselines with different number of simulations, action selection, and meta-policies.

# %%
plot_utils.plot_pairwise_comparison(
    combined_df,
    y_key="episode_return_mean", 
    policy_key="policy_id",
    y_err_key="episode_return_CI",
    vrange=None, 
    figsize=(20, len(combined_df["policy_id"].unique())), 
    valfmt="{x:.2f}",
    coplayer_policies=coplayer_policy_ids,
    average_duplicates=True,
    duplicate_warning=False
)
# Out:
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# (<Figure size 1440x6048 with 2 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %%
plot_utils.plot_pairwise_comparison(
    combined_df,
    y_key="num_episodes", 
    policy_key="policy_id",
    y_err_key=None,
    vrange=None, 
    figsize=(20, len(combined_df["policy_id"].unique())), 
    valfmt="{x:.0f}",
    coplayer_policies=coplayer_policy_ids,
    average_duplicates=True,
    duplicate_warning=False
)
# Out:
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# (<Figure size 1440x6048 with 1 Axes>, array([[<AxesSubplot:>]], dtype=object))

# %% [markdown]
# ## Policy Prior Performance
#
# Here we look at the expected performance against the policy prior of BAPOSGMCP.

# %%
exp_df = plot_utils.get_uniform_expected_df(combined_df, coplayer_policy_ids)
# Out:
# Ungrouped size = 430
# Grouped size = 84

# %%
# Base plot kwargs
base_plot_kwargs = paper_utils.get_base_plot_kwargs()
return_plot_kwargs = copy.deepcopy(base_plot_kwargs)
return_plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Episode Return",
})

step_plot_kwargs = copy.deepcopy(return_plot_kwargs)
step_plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Episode Steps"
})

# %% [markdown]
# ### Action Selection

# %%
exp_df["action_selection"].unique()
# Out:
# array(['pucb', None], dtype=object)

# %% [markdown]
# ### Comparison of truncation

# %%
exp_df["truncated"].unique()
# Out:
# array([ True, False])

# %% [markdown]
# ### Comparison of the different Meta-Policies

# %%
meta_pi_label_map = {
    "greedy": r"$\sigma^{G}$",
    "softmax": r"$\sigma^{S}$",
    "uniform": r"$\sigma^{U}$",
}

meta_pi_df = exp_df[
    (exp_df["action_selection"].isin(["pucb", None]))
    & (
        (exp_df["alg_id"].isin(["POMeta", "metabaseline"]))
        | (
            (exp_df["alg_id"].isin(["baposgmcp", "POMetaRollout"])) & (exp_df["truncated"] == True)
        )
    )
]

meta_alg_ids = meta_pi_df["alg_id"].unique().tolist()
meta_alg_ids.sort()
print("Alg IDs")
print("-------")
for n in meta_alg_ids:
    print(n)
    
policy_ids = meta_pi_df["policy_id"].unique().tolist()
policy_ids.sort()
print("\nPolicy IDs")
print("----------")
for n in policy_ids:
    print(n)
# Out:
# Alg IDs
# -------
# POMeta
# POMetaRollout
# baposgmcp
# metabaseline
#
# Policy IDs
# ----------
# POMetaRollout_greedy_numsims10
# POMetaRollout_greedy_numsims100
# POMetaRollout_greedy_numsims1000
# POMetaRollout_greedy_numsims50
# POMetaRollout_greedy_numsims500
# POMetaRollout_softmax_numsims10
# POMetaRollout_softmax_numsims100
# POMetaRollout_softmax_numsims1000
# POMetaRollout_softmax_numsims50
# POMetaRollout_softmax_numsims500
# POMetaRollout_uniform_numsims10
# POMetaRollout_uniform_numsims100
# POMetaRollout_uniform_numsims1000
# POMetaRollout_uniform_numsims50
# POMetaRollout_uniform_numsims500
# POMeta_greedy_numsims10
# POMeta_greedy_numsims100
# POMeta_greedy_numsims1000
# POMeta_greedy_numsims50
# POMeta_greedy_numsims500
# POMeta_softmax_numsims10
# POMeta_softmax_numsims100
# POMeta_softmax_numsims1000
# POMeta_softmax_numsims50
# POMeta_softmax_numsims500
# POMeta_uniform_numsims10
# POMeta_uniform_numsims100
# POMeta_uniform_numsims1000
# POMeta_uniform_numsims50
# POMeta_uniform_numsims500
# baposgmcp_greedy_numsims10
# baposgmcp_greedy_numsims100
# baposgmcp_greedy_numsims1000
# baposgmcp_greedy_numsims50
# baposgmcp_greedy_numsims500
# baposgmcp_softmax_numsims10
# baposgmcp_softmax_numsims100
# baposgmcp_softmax_numsims1000
# baposgmcp_softmax_numsims50
# baposgmcp_softmax_numsims500
# baposgmcp_uniform_numsims10
# baposgmcp_uniform_numsims100
# baposgmcp_uniform_numsims1000
# baposgmcp_uniform_numsims50
# baposgmcp_uniform_numsims500
# metabaseline_greedy
# metabaseline_softmax
# metabaseline_uniform

# %%
plot_kwargs = copy.deepcopy(return_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylim": (0.15, 0.9),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "lower right",
    # "title": "Meta-Policy" 
})

for alg_id in meta_alg_ids:
    print(alg_id)
    fig, _ = plot_utils.paper.plot_multiple_meta_policy_vs_num_sims(
        meta_pi_df[meta_pi_df["alg_id"] == alg_id],
        y_key="episode_return_mean",
        y_err_key="episode_return_CI",
        meta_pi_label_map=meta_pi_label_map,
        alg_id_key="alg_id",
        set_title=False,
        **plot_kwargs
    )
    fig.savefig(osp.join(figure_dir, f"meta_pi_return_{alg_id}.png"))
    
del plot_kwargs
# Out:
# POMeta
# POMetaRollout
# baposgmcp
# metabaseline

# %%
plot_kwargs = copy.deepcopy(step_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylim": (35, 50),
})
plot_kwargs["legend_kwargs"].update({
    "loc": 'lower left',
    # "title": "Meta-Policy",  
})

for alg_id in meta_alg_ids:
    print(alg_id)
    fig, _ = plot_utils.paper.plot_multiple_meta_policy_vs_num_sims(
        meta_pi_df[meta_pi_df["alg_id"] == alg_id],
        y_key="episode_steps_mean",
        y_err_key="episode_steps_CI",
        meta_pi_label_map=meta_pi_label_map,
        alg_id_key="alg_id",
        set_title=False,
        **plot_kwargs
    )
    fig.savefig(osp.join(figure_dir, f"meta_pi_step_{alg_id}.png"))
    
del plot_kwargs
# Out:
# POMeta
# POMetaRollout
# baposgmcp
# metabaseline

# %% [markdown]
# ## Comparing Meta-Policy versus no meta-policy
#
# Here we look at the performance of BAPOSGMCP (using PUCB) with using a meta-policy against not using a meta-policy (i.e. using the different fixed policies).

# %%
meta_vs_no_pi_label_map = {
    "baposgmcp_softmax": r"$\sigma^{S}$",
    "baposgmcp_random": "Random",
    "baposgmcp_fixed_pispseed0-v0": "S0",
    "baposgmcp_fixed_pispseed1-v0": "S1",
    "baposgmcp_fixed_pispseed2-v0": "S2",
    "baposgmcp_fixed_pispseed3-v0": "S3",
    "baposgmcp_fixed_pispseed4-v0": "S4",
}

# Use DF containing only policies with PUCB action_selection or NA
meta_vs_no_meta_df = exp_df[
    (exp_df["alg_id"].isin(["baposgmcp", "baposgmcp_fixed", "baposgmcp_random"]))
    # & (exp_df["action_selection"].isin(["pucb"]))
    & (exp_df["meta_pi"].isin(["softmax", "NA"]))
#     & (
#         (exp_df["alg_id"] == "baposgmcp_random") | (exp_df["truncated"] == True)
#     )
]

meta_vs_no_meta_alg_ids = meta_vs_no_meta_df["alg_id"].unique().tolist()
meta_vs_no_meta_alg_ids.sort()
print("Alg IDs")
print("-------")
for n in meta_vs_no_meta_alg_ids:
    print(n)
    
policy_ids = meta_vs_no_meta_df["policy_id"].unique().tolist()
policy_ids.sort()
print("\nPolicy IDs")
print("----------")
for n in policy_ids:
    print(n)
    
fixed_policy_ids = meta_vs_no_meta_df["fixed_policy_id"].unique().tolist()
print("\nFixed Policy IDs")
print("----------------")
for n in fixed_policy_ids:
    print(n)
# Out:
# Alg IDs
# -------
# baposgmcp
# baposgmcp_fixed
# baposgmcp_random
#
# Policy IDs
# ----------
# baposgmcp_fixed_pispseed0-v0_numsims10
# baposgmcp_fixed_pispseed0-v0_numsims100
# baposgmcp_fixed_pispseed0-v0_numsims1000
# baposgmcp_fixed_pispseed0-v0_numsims50
# baposgmcp_fixed_pispseed0-v0_numsims500
# baposgmcp_fixed_pispseed1-v0_numsims10
# baposgmcp_fixed_pispseed1-v0_numsims100
# baposgmcp_fixed_pispseed1-v0_numsims1000
# baposgmcp_fixed_pispseed1-v0_numsims50
# baposgmcp_fixed_pispseed1-v0_numsims500
# baposgmcp_fixed_pispseed2-v0_numsims10
# baposgmcp_fixed_pispseed2-v0_numsims100
# baposgmcp_fixed_pispseed2-v0_numsims1000
# baposgmcp_fixed_pispseed2-v0_numsims50
# baposgmcp_fixed_pispseed2-v0_numsims500
# baposgmcp_fixed_pispseed3-v0_numsims10
# baposgmcp_fixed_pispseed3-v0_numsims100
# baposgmcp_fixed_pispseed3-v0_numsims1000
# baposgmcp_fixed_pispseed3-v0_numsims50
# baposgmcp_fixed_pispseed3-v0_numsims500
# baposgmcp_fixed_pispseed4-v0_numsims10
# baposgmcp_fixed_pispseed4-v0_numsims100
# baposgmcp_fixed_pispseed4-v0_numsims1000
# baposgmcp_fixed_pispseed4-v0_numsims50
# baposgmcp_fixed_pispseed4-v0_numsims500
# baposgmcp_random_numsims10
# baposgmcp_random_numsims100
# baposgmcp_random_numsims1000
# baposgmcp_random_numsims50
# baposgmcp_random_numsims500
# baposgmcp_softmax_numsims10
# baposgmcp_softmax_numsims100
# baposgmcp_softmax_numsims1000
# baposgmcp_softmax_numsims50
# baposgmcp_softmax_numsims500
#
# Fixed Policy IDs
# ----------------
# PredatorPrey10x10-P2-p3-s2-coop-v0/sp_seed0-v0
# PredatorPrey10x10-P2-p3-s2-coop-v0/sp_seed1-v0
# PredatorPrey10x10-P2-p3-s2-coop-v0/sp_seed2-v0
# PredatorPrey10x10-P2-p3-s2-coop-v0/sp_seed3-v0
# PredatorPrey10x10-P2-p3-s2-coop-v0/sp_seed4-v0
# random-v0
# None

# %%
plot_kwargs = copy.deepcopy(return_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    # "ylim": (0.1, 0.85),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "lower right",
    # "title": "Policy",
    "ncol": 2
})

fig, _ = plot_utils.paper.plot_multiple_performance_vs_num_sims(
    meta_vs_no_meta_df,
    y_key="episode_return_mean",
    y_err_key="episode_return_CI",
    policy_prefixes=[list(meta_vs_no_pi_label_map)],
    pi_label_map=meta_vs_no_pi_label_map,
    **plot_kwargs,
)

fig.savefig(osp.join(figure_dir, f"meta_vs_fixed_return.png"))
    
del plot_kwargs

# %%
meta_vs_no_best_and_worst_pi_label_map = {
    "baposgmcp_softmax": r"$\sigma^{S}$",
    "baposgmcp_random": "Random",
    # "baposgmcp_fixed_pispseed0-v0": "S0",
    "baposgmcp_fixed_pispseed1-v0": "Worst",
    # "baposgmcp_fixed_pispseed2-v0": "S2",
    # "baposgmcp_fixed_pispseed3-v0": "S3",
    "baposgmcp_fixed_pispseed4-v0": "Best",
}

plot_kwargs = copy.deepcopy(return_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    # "ylim": (0.1, 0.85),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "lower right",
    # "title": "Policy",
    "ncol": 1
})

fig, _ = plot_utils.paper.plot_multiple_performance_vs_num_sims(
    meta_vs_no_meta_df,
    y_key="episode_return_mean",
    y_err_key="episode_return_CI",
    policy_prefixes=[list(meta_vs_no_best_and_worst_pi_label_map)],
    pi_label_map=meta_vs_no_best_and_worst_pi_label_map,
    **plot_kwargs,
)

fig.savefig(osp.join(figure_dir, f"meta_vs_fixed_return_best_and_worst.png"))
    
del plot_kwargs

# %%
plot_kwargs = copy.deepcopy(step_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylim": (33, 50),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "lower left",
    # "title": "Policy",
    "ncol": 2
})

fig, _ = plot_utils.paper.plot_multiple_performance_vs_num_sims(
    meta_vs_no_meta_df,
    y_key="episode_steps_mean",
    y_err_key="episode_steps_CI",
    policy_prefixes=[list(meta_vs_no_pi_label_map)],
    pi_label_map=meta_vs_no_pi_label_map,
    **plot_kwargs,
)

fig.savefig(osp.join(figure_dir, f"meta_vs_fixed_steps.png"))
    
del plot_kwargs

# %% [markdown]
# ## Comparing BAPOSGMCP versus baselines

# %%
perf_df = exp_df[
    (exp_df["action_selection"].isin(["pucb", None]))
    & (
        (exp_df["alg_id"].isin(["POMeta", "metabaseline", "full-knowledge-br"]))
        | ((exp_df["alg_id"].isin(["baposgmcp", "POMetaRollout"])) & (exp_df["truncated"] == True))
    )
]

policy_prefixes_to_plot = [
    "baposgmcp_softmax",
    "POMeta_greedy",
    "POMetaRollout_softmax",
    "metabaseline_greedy",
    "full-knowledge-br"
]

baseline_pi_label_map = {
    "baposgmcp_softmax": "BAPOSGMCP",
    # "baposgmcp_random": "BAPOSGMCP Random",
    "POMeta_greedy": "POMeta", 
    "POMetaRollout_softmax": "POMetaRollout", 
    "metabaseline_greedy": "Meta-Policy",
    "full-knowledge-br": "Best-Response"
}

# %%
plot_kwargs = copy.deepcopy(return_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    # "ylim": (0.25, 2.3),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "lower right",
})

fig, _ = plot_utils.paper.plot_multiple_performance_vs_num_sims(
    perf_df,
    y_key="episode_return_mean",
    y_err_key="episode_return_CI",
    policy_prefixes=[policy_prefixes_to_plot],
    pi_label_map=baseline_pi_label_map,
    **plot_kwargs,
)

fig.savefig(osp.join(figure_dir, "baselines_return.png"))
    
del plot_kwargs

# %% [markdown]
# ## Looking at Belief accuracy by steps
#
# - action_dist_distance
# - bayes_accuracy

# %%
belief_df = exp_df[
    (exp_df["action_selection"].isin(["pucb", None]))
    & (
        (exp_df["alg_id"].isin(["POMeta"]))
        | ((exp_df["alg_id"].isin(["baposgmcp", "POMetaRollout"])) & (exp_df["truncated"] == True))
    )
    
]

belief_alg_ids = belief_df["alg_id"].unique().tolist()
belief_alg_ids.sort()
print("Alg IDs")
print("-------")
for n in belief_alg_ids:
    print(n)

# group over meta-policy values
belief_group_keys = ["alg_id", "num_sims"]
belief_agg_dict = plot_utils.get_uniform_expected_agg_map(exp_df)
for k in belief_group_keys:
    if k in belief_agg_dict:
        belief_agg_dict.pop(k)
        
gb = belief_df.groupby(belief_group_keys)
gb_agg = gb.agg(**belief_agg_dict)
belief_gb_df = gb_agg.reset_index()

belief_gb_df.sort_values(by=["num_sims"], inplace=True)

print("Ungrouped size =", len(belief_df))
print("Grouped size =", len(belief_gb_df))
# print(belief_gb_df)
# Out:
# Alg IDs
# -------
# POMeta
# POMetaRollout
# baposgmcp
# Ungrouped size = 45
# Grouped size = 15

# %%
belief_plot_kwargs = copy.deepcopy(base_plot_kwargs)
belief_plot_kwargs["subplot_kwargs"].update({
    "xlabel": "Step",
})
belief_plot_kwargs["legend_kwargs"].update({
    "loc": "upper left",
    # "title": "Num. Sims." 
})

# %%
plot_kwargs = copy.deepcopy(belief_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Belief Probability",
    "ylim": (0.05, 1.05),
})

for alg_id in belief_alg_ids:
    print(alg_id)
    fig, _ = plot_utils.paper.plot_multiple_belief_stats(
        belief_gb_df[belief_gb_df["alg_id"] == alg_id],
        y_key_prefix="bayes_accuracy",
        step_limit=50,
        other_agent_id=1,
        y_suffix="mean",
        y_err_suffix="CI",
        alg_id_key="alg_id",
        **plot_kwargs
    )

    fig.savefig(osp.join(figure_dir, f"bayes_accuracy_{alg_id}.png"))
    
del plot_kwargs
# Out:
# POMeta
# POMetaRollout
# baposgmcp

# %%
plot_kwargs = copy.deepcopy(belief_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Wasserstein Distance",
    "ylim": (-0.02, 1.7),
})

plot_kwargs["legend_kwargs"].update({
    "loc": "lower left",
})

for alg_id in belief_alg_ids:
    print(alg_id)
    fig, _ = plot_utils.paper.plot_multiple_belief_stats(
        belief_gb_df[belief_gb_df["alg_id"] == alg_id],
        y_key_prefix="action_dist_distance",
        step_limit=50,
        other_agent_id=1,
        y_suffix="mean",
        y_err_suffix="CI",
        alg_id_key="alg_id",
        **plot_kwargs
    )

    fig.savefig(osp.join(figure_dir, f"action_dist_{alg_id}.png"))
    
del plot_kwargs
# Out:
# POMeta
# POMetaRollout
# baposgmcp

# %% [markdown]
# ## Looking at time
#
#    - search_time
#    - update_time
#    - reinvigoration_time
#    - policy_calls
#    - inference_time
#    - search_depth

# %%
times_df = exp_df[
    (exp_df["action_selection"].isin(['pucb', None]))
    & (exp_df["alg_id"].isin(["baposgmcp", "baposgmcp_fixed", "baposgmcp_random", "POMetaRollout", "POMeta"]))
]

print(times_df["truncated"].unique())

times_group_keys = ["alg_id", "truncated", "num_sims"]
times_agg_dict = plot_utils.get_uniform_expected_agg_map(exp_df)
for k in times_group_keys:
    if k in times_agg_dict:
        times_agg_dict.pop(k)
    
times_agg_dict["policy_id"] = pd.NamedAgg(column="policy_id", aggfunc="first")
        
gb = times_df.groupby(times_group_keys)
gb_agg = gb.agg(**times_agg_dict)
times_gb_df = gb_agg.reset_index()

times_gb_df.sort_values(by=["alg_id", "truncated", "num_sims"], inplace=True)

print("Ungrouped size =", len(times_df))
print("Grouped size =", len(times_gb_df))

times_alg_ids = times_gb_df["alg_id"].unique().tolist()
times_alg_ids.sort()
print("Alg IDs")
print("-------")
for n in times_alg_ids:
    print(n)
    
times_policy_ids = times_gb_df["policy_id"].unique().tolist()
times_policy_ids.sort()
print("\nPolicy IDs")
print("----------")
for n in times_policy_ids:
    print(n)
    
    
# based on output of policy IDs (since we group IDS)
time_pi_label_map = {
    # "baposgmcp_uniform": r"BAPOSGMCP",
    "baposgmcp_softmax": r"BAPOSGMCP",
    # "baposgmcp_greedy": r"BAPOSGMCP",
    # "baposgmcp_random": "BAPOSGMCP Random",
    # "baposgmcp_fixed": "BAPOSGMCP Fixed",
    "POMeta": "POMeta", 
    "POMetaRollout": "POMetaRollout", 
    # "metabaseline": "Meta-Policy",
}

sim_policies = [
    # "baposgmcp_uniform",
    "baposgmcp_softmax",
    # "baposgmcp_greedy",
    # "baposgmcp_random",
    # "baposgmcp_fixed",
    "POMetaRollout", 
]
# Out:
# [ True False]
# Ungrouped size = 75
# Grouped size = 25
# Alg IDs
# -------
# POMeta
# POMetaRollout
# baposgmcp
# baposgmcp_fixed
# baposgmcp_random
#
# Policy IDs
# ----------
# POMetaRollout_greedy_numsims10
# POMetaRollout_greedy_numsims100
# POMetaRollout_greedy_numsims1000
# POMetaRollout_greedy_numsims50
# POMetaRollout_greedy_numsims500
# POMeta_greedy_numsims10
# POMeta_greedy_numsims100
# POMeta_greedy_numsims1000
# POMeta_greedy_numsims50
# POMeta_greedy_numsims500
# baposgmcp_fixed_pispseed0-v0_numsims10
# baposgmcp_fixed_pispseed0-v0_numsims100
# baposgmcp_fixed_pispseed0-v0_numsims1000
# baposgmcp_fixed_pispseed0-v0_numsims50
# baposgmcp_fixed_pispseed0-v0_numsims500
# baposgmcp_greedy_numsims10
# baposgmcp_greedy_numsims100
# baposgmcp_greedy_numsims1000
# baposgmcp_greedy_numsims50
# baposgmcp_greedy_numsims500
# baposgmcp_random_numsims10
# baposgmcp_random_numsims100
# baposgmcp_random_numsims1000
# baposgmcp_random_numsims50
# baposgmcp_random_numsims500

# %%
time_plot_kwargs = copy.deepcopy(return_plot_kwargs)
time_plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Step Search Time",
    # "ylim": (0, 75),
})
time_plot_kwargs["legend_kwargs"].update({
    "loc": 'upper left',
    "title": "Truncated",  
})

for alg_id in times_alg_ids:
    if alg_id == "POMeta":
        continue
    print(alg_id)
    fig, _ = paper_utils.plot_multiple_truncated_vs_num_sims_by_alg(
        times_gb_df[times_gb_df["alg_id"] == alg_id],
        y_key="search_time_mean",
        y_err_key="search_time_CI",
        alg_id_key="alg_id",
        set_title=False,
        **time_plot_kwargs
    )
    fig.savefig(osp.join(figure_dir, f"truncated_search_time_{alg_id}.png"))
    
del time_plot_kwargs
# Out:
# POMetaRollout
# baposgmcp
# baposgmcp_fixed
# baposgmcp_random

# %%
time_plot_kwargs = copy.deepcopy(return_plot_kwargs)
time_plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Leaf Node Evaluation Time",
    # "ylim": (0, 75),
})
time_plot_kwargs["legend_kwargs"].update({
    "loc": 'upper left',
    "title": "Truncated",  
})

for alg_id in times_alg_ids:
    if alg_id == "POMeta":
        continue
    print(alg_id)
    fig, _ = paper_utils.plot_multiple_truncated_vs_num_sims_by_alg(
        times_gb_df[times_gb_df["alg_id"] == alg_id],
        y_key="evaluation_time_mean",
        y_err_key="evaluation_time_CI",
        alg_id_key="alg_id",
        set_title=False,
        **time_plot_kwargs
    )
    fig.savefig(osp.join(figure_dir, f"truncated_eval_time_{alg_id}.png"))
    
del time_plot_kwargs
# Out:
# POMetaRollout
# baposgmcp
# baposgmcp_fixed
# baposgmcp_random

# %%
time_plot_kwargs = copy.deepcopy(return_plot_kwargs)
time_plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Inference Time",
    # "ylim": (0, 75),
})
time_plot_kwargs["legend_kwargs"].update({
    "loc": 'upper left',
    "title": "Truncated",  
})

for alg_id in times_alg_ids:
    print(alg_id)
    fig, _ = paper_utils.plot_multiple_truncated_vs_num_sims_by_alg(
        times_gb_df[times_gb_df["alg_id"] == alg_id],
        y_key="inference_time_mean",
        y_err_key="inference_time_CI",
        alg_id_key="alg_id",
        set_title=False,
        **time_plot_kwargs
    )
    fig.savefig(osp.join(figure_dir, f"truncated_inference_time_{alg_id}.png"))
    
del time_plot_kwargs
# Out:
# POMeta
# POMetaRollout
# baposgmcp
# baposgmcp_fixed
# baposgmcp_random

# %%
time_plot_kwargs = copy.deepcopy(return_plot_kwargs)
time_plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Update Time",
    # "ylim": (0, 75),
})
time_plot_kwargs["legend_kwargs"].update({
    "loc": 'upper left',
    "title": "Truncated",  
})

for alg_id in times_alg_ids:
    print(alg_id)
    fig, _ = paper_utils.plot_multiple_truncated_vs_num_sims_by_alg(
        times_gb_df[times_gb_df["alg_id"] == alg_id],
        y_key="update_time_mean",
        y_err_key="update_time_CI",
        alg_id_key="alg_id",
        set_title=False,
        **time_plot_kwargs
    )
    fig.savefig(osp.join(figure_dir, f"truncated_update_time_{alg_id}.png"))
    
del time_plot_kwargs
# Out:
# POMeta
# POMetaRollout
# baposgmcp
# baposgmcp_fixed
# baposgmcp_random

# %%
time_plot_kwargs = copy.deepcopy(return_plot_kwargs)
time_plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Belief Reinvigoration Time",
    # "ylim": (0, 75),
})
time_plot_kwargs["legend_kwargs"].update({
    "loc": 'upper left',
    "title": "Truncated",  
})

for alg_id in times_alg_ids:
    print(alg_id)
    fig, _ = paper_utils.plot_multiple_truncated_vs_num_sims_by_alg(
        times_gb_df[times_gb_df["alg_id"] == alg_id],
        y_key="reinvigoration_time_mean",
        y_err_key="reinvigoration_time_CI",
        alg_id_key="alg_id",
        set_title=False,
        **time_plot_kwargs
    )
    fig.savefig(osp.join(figure_dir, f"truncated_reinvigoration_time_{alg_id}.png"))
    
del time_plot_kwargs
# Out:
# POMeta
# POMetaRollout
# baposgmcp
# baposgmcp_fixed
# baposgmcp_random

# %%
time_plot_kwargs = copy.deepcopy(return_plot_kwargs)
time_plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Search Depth",
    # "ylim": (0, 75),
})
time_plot_kwargs["legend_kwargs"].update({
    "loc": 'upper left',
    "title": "Truncated",  
})

for alg_id in times_alg_ids:
    if alg_id == "POMeta":
        continue
    print(alg_id)
    fig, _ = paper_utils.plot_multiple_truncated_vs_num_sims_by_alg(
        times_gb_df[times_gb_df["alg_id"] == alg_id],
        y_key="search_depth_mean",
        y_err_key="search_depth_CI",
        alg_id_key="alg_id",
        set_title=False,
        **time_plot_kwargs
    )
    fig.savefig(osp.join(figure_dir, f"truncated_search_depth_{alg_id}.png"))
    
del time_plot_kwargs
# Out:
# POMetaRollout
# baposgmcp
# baposgmcp_fixed
# baposgmcp_random
