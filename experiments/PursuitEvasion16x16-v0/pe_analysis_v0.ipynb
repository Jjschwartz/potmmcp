# %% [markdown]
# # PursuitEvasion16x16-v0 Heuristic experiment analysis

# %%
import copy
import os.path as osp

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import posggym_agents

import baposgmcp.plot as plot_utils
import baposgmcp.plot.paper as paper_utils
from baposgmcp.config import BASE_REPO_DIR

baposgmcp_results_file = osp.join(
    BASE_REPO_DIR, "experiments", "PursuitEvasion16x16-v0", "results", "klr_results_v0.csv"
)
figure_dir = osp.join(
    BASE_REPO_DIR, "experiments", "PursuitEvasion16x16-v0", "figures"
)
policy_results_file = osp.join(
    posggym_agents.config.BASE_DIR, 'agents', "pursuitevasion16x16_v0", "results", "pairwise_results.csv"
)

# %% [markdown]
# ## Define Co-Player Prior

# %%
# Uniform
# Note K4 is not in prior 
policy_prior = {
    0: {
        "klr_k0_seed0_i0-v0": 1/4,
        "klr_k1_seed0_i0-v0": 1/4,
        "klr_k2_seed0_i0-v0": 1/4,
        "klr_k3_seed0_i0-v0": 1/4
    },
    1: {
        "klr_k0_seed0_i1-v0": 1/4,
        "klr_k1_seed0_i1-v0": 1/4,
        "klr_k2_seed0_i1-v0": 1/4,
        "klr_k3_seed0_i1-v0": 1/4
    }
}
coplayer_policy_ids = list(policy_prior[0]) + list(policy_prior[1])
coplayer_policy_ids.sort()
fixed_policy_ids = coplayer_policy_ids + ["klr_k4_seed0_i0-v0", "klr_k4_seed0_i1-v0"]
fixed_policy_ids.sort()

# %% [markdown]
# # Problem size
#
# - Grid size = 16 x 16
# - Num free coods = 145
# - Num goal = 3
#
# **States**
#
# ```
# = evader_states * pursuer_states
# = (pos * dir * goal * min_goal_dist) * (pos * dir)
# = (145 * 4 * 3 * 23) * (145 * 4)
# = 23,211,600
# ```
#
# **Actions** = 4 (Forward, Backward, Left, Right)
#
# **Observations**
#
# ```
# = adj_cells * seed * heard * evader_start_coord, pursuer_start_coord * goal_coord
# = 2**4 * 2 * 2 * 6 * 2 * 6
# = 4,608
# ```
#
# Coord observations are constant throught an episode so only influence branching for the initial observation.
# Given agents know their initial location and the map is fixed and known the branching is `2*2=4`.

# %% [markdown]
# ## The Environment

# %%
fig, ax = plot_utils.plot_environment("PursuitEvasion16x16-v0", (9, 9))
fig.savefig(osp.join(figure_dir, "env.png"))
plt.show()

# %% [markdown]
# ## Loading Fixed Policy Data

# %%
policy_df = plot_utils.import_results(
    policy_results_file, clean_policy_id=True, add_coplayer_policy_id=True
)

all_fixed_policy_ids = policy_df["policy_id"].unique().tolist()
all_fixed_policy_ids.sort()
print("All Fixed Policies")
print("------------------")
for pi_id in all_fixed_policy_ids:
    print("  ", pi_id)
    
    
# Drop unneeded co-player policies
policy_df = policy_df[policy_df["policy_id"].isin(fixed_policy_ids)]
fixed_policy_ids = policy_df["policy_id"].unique().tolist()
fixed_policy_ids.sort()
print("\nExperiment Fixed Policies")
print("-------------------------")
for pi_id in fixed_policy_ids:
    print("  ", pi_id)

print("\nColumns")
print("-------")
for c in policy_df.columns:
    print("  ", c)
# Out:
# All Fixed Policies
# ------------------
#    klr_k0_seed0_i0-v0
#    klr_k0_seed0_i1-v0
#    klr_k0_seed1_i0-v0
#    klr_k0_seed1_i1-v0
#    klr_k0_seed2_i0-v0
#    klr_k0_seed2_i1-v0
#    klr_k0_seed3_i0-v0
#    klr_k0_seed3_i1-v0
#    klr_k0_seed4_i0-v0
#    klr_k0_seed4_i1-v0
#    klr_k1_seed0_i0-v0
#    klr_k1_seed0_i1-v0
#    klr_k1_seed1_i0-v0
#    klr_k1_seed1_i1-v0
#    klr_k1_seed2_i0-v0
#    klr_k1_seed2_i1-v0
#    klr_k1_seed3_i0-v0
#    klr_k1_seed3_i1-v0
#    klr_k1_seed4_i0-v0
#    klr_k1_seed4_i1-v0
#    klr_k2_seed0_i0-v0
#    klr_k2_seed0_i1-v0
#    klr_k2_seed1_i0-v0
#    klr_k2_seed1_i1-v0
#    klr_k2_seed2_i0-v0
#    klr_k2_seed2_i1-v0
#    klr_k2_seed3_i0-v0
#    klr_k2_seed3_i1-v0
#    klr_k2_seed4_i0-v0
#    klr_k2_seed4_i1-v0
#    klr_k3_seed0_i0-v0
#    klr_k3_seed0_i1-v0
#    klr_k3_seed1_i0-v0
#    klr_k3_seed1_i1-v0
#    klr_k3_seed2_i0-v0
#    klr_k3_seed2_i1-v0
#    klr_k3_seed3_i0-v0
#    klr_k3_seed3_i1-v0
#    klr_k3_seed4_i0-v0
#    klr_k3_seed4_i1-v0
#    klr_k4_seed0_i0-v0
#    klr_k4_seed0_i1-v0
#    klr_k4_seed1_i0-v0
#    klr_k4_seed1_i1-v0
#    klr_k4_seed2_i0-v0
#    klr_k4_seed2_i1-v0
#    klr_k4_seed3_i0-v0
#    klr_k4_seed3_i1-v0
#    klr_k4_seed4_i0-v0
#    klr_k4_seed4_i1-v0
#    klrbr_k4_seed0_i0-v0
#    klrbr_k4_seed0_i1-v0
#    klrbr_k4_seed1_i0-v0
#    klrbr_k4_seed1_i1-v0
#    klrbr_k4_seed2_i0-v0
#    klrbr_k4_seed2_i1-v0
#    klrbr_k4_seed3_i0-v0
#    klrbr_k4_seed3_i1-v0
#    klrbr_k4_seed4_i0-v0
#    klrbr_k4_seed4_i1-v0
#    random-v0
#    shortestpath-v0
#    sp_seed0_i0-v0
#    sp_seed0_i1-v0
#    sp_seed1_i0-v0
#    sp_seed1_i1-v0
#    sp_seed2_i0-v0
#    sp_seed2_i1-v0
#    sp_seed3_i0-v0
#    sp_seed3_i1-v0
#    sp_seed4_i0-v0
#    sp_seed4_i1-v0
#
# Experiment Fixed Policies
# -------------------------
#    klr_k0_seed0_i0-v0
#    klr_k0_seed0_i1-v0
#    klr_k1_seed0_i0-v0
#    klr_k1_seed0_i1-v0
#    klr_k2_seed0_i0-v0
#    klr_k2_seed0_i1-v0
#    klr_k3_seed0_i0-v0
#    klr_k3_seed0_i1-v0
#    klr_k4_seed0_i0-v0
#    klr_k4_seed0_i1-v0
#
# Columns
# -------
#    exp_id
#    agent_id
#    env_id
#    policy_id
#    exp_seed
#    num_episodes
#    time_limit
#    episode_return_mean
#    episode_return_std
#    episode_return_max
#    episode_return_min
#    episode_steps_mean
#    episode_steps_std
#    episode_time_mean
#    episode_time_std
#    num_episode_done
#    num_LOSS
#    num_DRAW
#    num_WIN
#    num_NA
#    episode_return_CI
#    episode_steps_CI
#    episode_time_CI
#    prop_LOSS
#    prop_DRAW
#    prop_WIN
#    prop_NA
#    num_sims
#    truncated
#    coplayer_policy_id

# %% [markdown]
# ## Heuristic policies pairwise performance
#
# This is what was used to generate the meta-policies.

# %%
fixed_policies_0 = [
    "klr_k0_seed0_i0-v0",
    "klr_k1_seed0_i0-v0",
    "klr_k2_seed0_i0-v0",
    "klr_k3_seed0_i0-v0",
    "klr_k4_seed0_i0-v0"
]
fixed_policies_1 = [
    "klr_k0_seed0_i1-v0",
    "klr_k1_seed0_i1-v0",
    "klr_k2_seed0_i1-v0",
    "klr_k3_seed0_i1-v0",
    "klr_k4_seed0_i1-v0"
]
fixed_policy_labels={
    "klr_k0_seed0_i0-v0": "K0_0",
    "klr_k1_seed0_i0-v0": "K1_0",
    "klr_k2_seed0_i0-v0": "K2_0",
    "klr_k3_seed0_i0-v0": "K3_0",
    "klr_k4_seed0_i0-v0": "K4_0",
    "klr_k0_seed0_i1-v0": "K0_1",
    "klr_k1_seed0_i1-v0": "K1_1",
    "klr_k2_seed0_i1-v0": "K2_1",
    "klr_k3_seed0_i1-v0": "K3_1",
    "klr_k4_seed0_i1-v0": "K4_1",
}

# %%
fig, axs = plot_utils.plot_pairwise_comparison(
    policy_df,
    y_key="episode_return_mean", 
    policy_key="policy_id",
    y_err_key="episode_return_CI",
    vrange=None, 
    figsize=(6, 3), 
    valfmt="{x:.2f}",
    policies=fixed_policies_0,
    coplayer_policies=fixed_policies_1,
    policy_labels=fixed_policy_labels,
    average_duplicates=True,
    duplicate_warning=False
)
fig.savefig(osp.join(figure_dir, "fixed_policy_payoff_0.png"))

fig, axs = plot_utils.plot_pairwise_comparison(
    policy_df,
    y_key="episode_return_mean", 
    policy_key="policy_id",
    y_err_key="episode_return_CI",
    vrange=None, 
    figsize=(6, 3), 
    valfmt="{x:.2f}",
    policies=fixed_policies_1,
    coplayer_policies=fixed_policies_0,
    policy_labels=fixed_policy_labels,
    average_duplicates=True,
    duplicate_warning=False
)
fig.savefig(osp.join(figure_dir, "fixed_policy_payoff_1.png"))
# Out:
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]

# %%
# Get payofss in meta policy dictionary format (for use in experiments)
pw_values, (row_policies, col_policies) = plot_utils.get_pairwise_values(
    policy_df,
    y_key="episode_return_mean", 
    policy_key="policy_id",
    policies=fixed_policies_0,
    coplayer_policies=fixed_policies_1,
    average_duplicates=True,
    duplicate_warning=True
)

for c, col_policy in enumerate(col_policies):
    print(f'(-1, "{col_policy}"):', "{")
    for r, row_policy in enumerate(row_policies):
        print(f'    "{row_policy}": {pw_values[r][c]:.2f},')
    print("},")
    
pw_values, (row_policies, col_policies) = plot_utils.get_pairwise_values(
    policy_df,
    y_key="episode_return_mean", 
    policy_key="policy_id",
    policies=fixed_policies_1,
    coplayer_policies=fixed_policies_0,
    average_duplicates=True,
    duplicate_warning=True
)


for c, col_policy in enumerate(col_policies):
    print(f'("{col_policy}", -1):', "{")
    for r, row_policy in enumerate(row_policies):
        print(f'    "{row_policy}": {pw_values[r][c]:.2f},')
    print("},")
# Out:
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# (-1, "klr_k0_seed0_i1-v0"): {
#     "klr_k0_seed0_i0-v0": 0.21,
#     "klr_k1_seed0_i0-v0": 0.97,
#     "klr_k2_seed0_i0-v0": -0.16,
#     "klr_k3_seed0_i0-v0": -0.27,
#     "klr_k4_seed0_i0-v0": 0.60,
# },
# (-1, "klr_k1_seed0_i1-v0"): {
#     "klr_k0_seed0_i0-v0": -0.66,
#     "klr_k1_seed0_i0-v0": -0.25,
#     "klr_k2_seed0_i0-v0": 0.91,
#     "klr_k3_seed0_i0-v0": 0.02,
#     "klr_k4_seed0_i0-v0": -0.41,
# },
# (-1, "klr_k2_seed0_i1-v0"): {
#     "klr_k0_seed0_i0-v0": -0.60,
#     "klr_k1_seed0_i0-v0": -0.74,
#     "klr_k2_seed0_i0-v0": 0.25,
#     "klr_k3_seed0_i0-v0": 0.61,
#     "klr_k4_seed0_i0-v0": -0.20,
# },
# (-1, "klr_k3_seed0_i1-v0"): {
#     "klr_k0_seed0_i0-v0": 0.19,
#     "klr_k1_seed0_i0-v0": 0.59,
#     "klr_k2_seed0_i0-v0": -0.78,
#     "klr_k3_seed0_i0-v0": -0.45,
#     "klr_k4_seed0_i0-v0": 0.97,
# },
# (-1, "klr_k4_seed0_i1-v0"): {
#     "klr_k0_seed0_i0-v0": 0.17,
#     "klr_k1_seed0_i0-v0": 0.67,
#     "klr_k2_seed0_i0-v0": -0.36,
#     "klr_k3_seed0_i0-v0": -0.78,
#     "klr_k4_seed0_i0-v0": 0.68,
# },
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# ("klr_k0_seed0_i0-v0", -1): {
#     "klr_k0_seed0_i1-v0": -0.21,
#     "klr_k1_seed0_i1-v0": 0.66,
#     "klr_k2_seed0_i1-v0": 0.60,
#     "klr_k3_seed0_i1-v0": -0.19,
#     "klr_k4_seed0_i1-v0": -0.17,
# },
# ("klr_k1_seed0_i0-v0", -1): {
#     "klr_k0_seed0_i1-v0": -0.97,
#     "klr_k1_seed0_i1-v0": 0.25,
#     "klr_k2_seed0_i1-v0": 0.74,
#     "klr_k3_seed0_i1-v0": -0.59,
#     "klr_k4_seed0_i1-v0": -0.67,
# },
# ("klr_k2_seed0_i0-v0", -1): {
#     "klr_k0_seed0_i1-v0": 0.16,
#     "klr_k1_seed0_i1-v0": -0.91,
#     "klr_k2_seed0_i1-v0": -0.25,
#     "klr_k3_seed0_i1-v0": 0.78,
#     "klr_k4_seed0_i1-v0": 0.36,
# },
# ("klr_k3_seed0_i0-v0", -1): {
#     "klr_k0_seed0_i1-v0": 0.27,
#     "klr_k1_seed0_i1-v0": -0.02,
#     "klr_k2_seed0_i1-v0": -0.61,
#     "klr_k3_seed0_i1-v0": 0.45,
#     "klr_k4_seed0_i1-v0": 0.78,
# },
# ("klr_k4_seed0_i0-v0", -1): {
#     "klr_k0_seed0_i1-v0": -0.60,
#     "klr_k1_seed0_i1-v0": 0.41,
#     "klr_k2_seed0_i1-v0": 0.20,
#     "klr_k3_seed0_i1-v0": -0.97,
#     "klr_k4_seed0_i1-v0": -0.68,
# },

# %% [markdown]
# ### Add Full-Knowledge Best-Response baseline

# %%
# Maps policy_id -> best response policy_id
best_response_map = {
    0: {
        "klr_k0_seed0_i1-v0": "klr_k1_seed0_i0-v0",
        "klr_k1_seed0_i1-v0": "klr_k2_seed0_i0-v0",
        "klr_k2_seed0_i1-v0": "klr_k3_seed0_i0-v0",
        "klr_k3_seed0_i1-v0": "klr_k4_seed0_i0-v0",
        # "klr_k4_seed0_i1-v0": "klr_k4_seed0_i0-v0",
    }, 
    1: {
        "klr_k0_seed0_i0-v0": "klr_k1_seed0_i1-v0",
        "klr_k1_seed0_i0-v0": "klr_k2_seed0_i1-v0",
        "klr_k2_seed0_i0-v0": "klr_k3_seed0_i1-v0",
        "klr_k3_seed0_i0-v0": "klr_k4_seed0_i1-v0",
        # "klr_k4_seed0_i0-v0": "klr_k4_seed0_i1-v0",
    }
}

new_rows = []
for (agent_id, coplayer_agent_id) in [(0, 1), (1, 0)]:
    for coplayer_policy_id, br_policy_id in best_response_map[agent_id].items():
        next_exp_id = policy_df["exp_id"].max() + 1
        br_row = policy_df.loc[
            (policy_df["agent_id"] == agent_id)
            & (policy_df["policy_id"] == br_policy_id) 
            & (policy_df["coplayer_policy_id"] == coplayer_policy_id)
        ].copy()
        br_coplayer_row = policy_df.loc[
            (policy_df["agent_id"] == coplayer_agent_id)
            & (policy_df["exp_id"].isin(br_row["exp_id"]))
        ].copy()
        # update policy id to baseline name
        br_row["policy_id"] = f"full-knowledge-br_i{agent_id}"
        # update exp ids to avoid duplicates
        br_row["exp_id"] = next_exp_id
        br_coplayer_row["exp_id"] = next_exp_id
        new_rows.append(br_row)
        new_rows.append(br_coplayer_row)

print(len(new_rows))
br_df = pd.concat(new_rows, axis='rows').reset_index(drop=True)
print(len(br_df))
policy_br_df = pd.concat([policy_df, br_df], ignore_index=True)

print(len(policy_br_df))
policy_br_df[policy_br_df["policy_id"].isin(["full-knowledge-br_i0", "full-knowledge-br_i1"])]
# Out:
# 16
# 16
# 386
#      exp_id  agent_id                  env_id             policy_id  exp_seed  \
# 370    1339         0  PursuitEvasion16x16-v0  full-knowledge-br_i0         0
# 372    1339         0  PursuitEvasion16x16-v0  full-knowledge-br_i0         0
# 374    1339         0  PursuitEvasion16x16-v0  full-knowledge-br_i0         0
# 376    1339         0  PursuitEvasion16x16-v0  full-knowledge-br_i0         0
# 378    1339         1  PursuitEvasion16x16-v0  full-knowledge-br_i1         0
# 380    1339         1  PursuitEvasion16x16-v0  full-knowledge-br_i1         0
# 382    1339         1  PursuitEvasion16x16-v0  full-knowledge-br_i1         0
# 384    1339         1  PursuitEvasion16x16-v0  full-knowledge-br_i1         0
#
#      num_episodes time_limit  episode_return_mean  episode_return_std  \
# 370          1000       None             0.965419            0.018966
# 372          1000       None             0.911089            0.296733
# 374          1000       None             0.608452            0.607099
# 376          1000       None             0.965653            0.019036
# 378          1000       None             0.663605            0.382248
# 380          1000       None             0.740653            0.028971
# 382          1000       None             0.779145            0.017689
# 384          1000       None             0.777556            0.012517
#
#      episode_return_max  ...  episode_return_CI  episode_steps_CI  \
# 370            0.991935  ...           0.001176          0.272501
# 372            0.991935  ...           0.018392          0.374425
# 374            0.991935  ...           0.037628          1.728013
# 376            0.991935  ...           0.001180          0.274766
# 378            0.798387  ...           0.023692          0.257832
# 380            0.790323  ...           0.001796          0.205305
# 382            0.806452  ...           0.001096          0.180085
# 384            0.806452  ...           0.000776          0.253001
#
#      episode_time_CI  prop_LOSS  prop_DRAW  prop_WIN  prop_NA  num_sims  \
# 370         0.001036      0.000        0.0     1.000    0.000         0
# 372         0.001199      0.032        0.0     0.968    0.000         0
# 374         0.005550      0.122        0.0     0.714    0.164         0
# 376         0.001033      0.000        0.0     1.000    0.000         0
# 378         0.000837      0.053        0.0     0.947    0.000         0
# 380         0.000668      0.000        0.0     1.000    0.000         0
# 382         0.000591      0.000        0.0     1.000    0.000         0
# 384         0.000852      0.000        0.0     1.000    0.000         0
#
#      truncated  coplayer_policy_id
# 370      False  klr_k0_seed0_i1-v0
# 372      False  klr_k1_seed0_i1-v0
# 374      False  klr_k2_seed0_i1-v0
# 376      False  klr_k3_seed0_i1-v0
# 378      False  klr_k0_seed0_i0-v0
# 380      False  klr_k1_seed0_i0-v0
# 382      False  klr_k2_seed0_i0-v0
# 384      False  klr_k3_seed0_i0-v0
#
# [8 rows x 30 columns]

# %% [markdown]
# ## Loading BAPOSGMCP Data

# %%
baposgmcp_df = plot_utils.import_results(
    baposgmcp_results_file, clean_policy_id=True, add_coplayer_policy_id=True
)
policy_ids = baposgmcp_df["policy_id"].unique().tolist()
policy_ids.sort()
print("Policies")
print("--------")
for pi_id in policy_ids:
    print("  ", pi_id)

print("\nColumns")
print("-------")
for c in baposgmcp_df.columns:
    print("  ", c)
# Out:
# Policies
# --------
#    POMetaRollout_greedy_i0_numsims1000_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i0_numsims100_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i0_numsims10_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i0_numsims500_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i0_numsims50_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i1_numsims1000_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i1_numsims100_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i1_numsims10_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i1_numsims500_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i1_numsims50_actionselectionpucb_truncatedTrue
#    POMeta_greedy_i0_numsims10
#    POMeta_greedy_i0_numsims100
#    POMeta_greedy_i0_numsims1000
#    POMeta_greedy_i0_numsims50
#    POMeta_greedy_i0_numsims500
#    POMeta_greedy_i1_numsims10
#    POMeta_greedy_i1_numsims100
#    POMeta_greedy_i1_numsims1000
#    POMeta_greedy_i1_numsims50
#    POMeta_greedy_i1_numsims500
#    baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-random_i0_numsims1000_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i0_numsims100_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i0_numsims10_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i0_numsims500_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i0_numsims50_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i1_numsims1000_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i1_numsims100_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i1_numsims10_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i1_numsims500_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i1_numsims50_actionselectionpucb_truncatedFalse
#    baposgmcp_greedy_i0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i1_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i1_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i1_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i1_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i1_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i1_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i1_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i1_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i1_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i1_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i1_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i1_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i1_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i1_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i1_numsims50_actionselectionpucb_truncatedTrue
#    klr_k0_seed0_i0-v0
#    klr_k0_seed0_i1-v0
#    klr_k1_seed0_i0-v0
#    klr_k1_seed0_i1-v0
#    klr_k2_seed0_i0-v0
#    klr_k2_seed0_i1-v0
#    klr_k3_seed0_i0-v0
#    klr_k3_seed0_i1-v0
#    metabaseline_greedy_i0
#    metabaseline_greedy_i1
#
# Columns
# -------
#    policy_id
#    coplayer_policy_id
#    exp_id
#    exp_seed
#    agent_id
#    env_id
#    time_limit
#    episode_step_limit
#    discount
#    c_init
#    c_base
#    truncated
#    action_selection
#    dirichlet_alpha
#    root_exploration_fraction
#    known_bounds
#    extra_particles_prop
#    step_limit
#    epsilon
#    other_policy_dist
#    meta_policy_dict
#    num_sims
#    num_episodes
#    fixed_policy_id
#    num_WIN
#    num_LOSS
#    num_DRAW
#    num_NA
#    search_time_mean
#    search_time_std
#    search_time_min
#    search_time_max
#    update_time_mean
#    update_time_std
#    update_time_min
#    update_time_max
#    reinvigoration_time_mean
#    reinvigoration_time_std
#    reinvigoration_time_min
#    reinvigoration_time_max
#    evaluation_time_mean
#    evaluation_time_std
#    evaluation_time_min
#    evaluation_time_max
#    policy_calls_mean
#    policy_calls_std
#    policy_calls_min
#    policy_calls_max
#    inference_time_mean
#    inference_time_std
#    inference_time_min
#    inference_time_max
#    search_depth_mean
#    search_depth_std
#    search_depth_min
#    search_depth_max
#    min_value_mean
#    min_value_std
#    min_value_min
#    min_value_max
#    max_value_mean
#    max_value_std
#    max_value_min
#    max_value_max
#    episode_return_mean
#    episode_return_std
#    episode_return_min
#    episode_return_max
#    episode_discounted_return_mean
#    episode_discounted_return_std
#    episode_discounted_return_min
#    episode_discounted_return_max
#    episode_steps_mean
#    episode_steps_std
#    episode_steps_min
#    episode_steps_max
#    episode_time_mean
#    episode_time_std
#    episode_time_min
#    episode_time_max
#    action_dist_distance_0_mean
#    action_dist_distance_0_std
#    action_dist_distance_0_n
#    action_dist_distance_1_mean
#    action_dist_distance_1_std
#    action_dist_distance_1_n
#    action_dist_distance_0_0_mean
#    action_dist_distance_0_0_std
#    action_dist_distance_0_0_n
#    action_dist_distance_0_1_mean
#    action_dist_distance_0_1_std
#    action_dist_distance_0_1_n
#    action_dist_distance_0_2_mean
#    action_dist_distance_0_2_std
#    action_dist_distance_0_2_n
#    action_dist_distance_0_3_mean
#    action_dist_distance_0_3_std
#    action_dist_distance_0_3_n
#    action_dist_distance_0_4_mean
#    action_dist_distance_0_4_std
#    action_dist_distance_0_4_n
#    action_dist_distance_0_5_mean
#    action_dist_distance_0_5_std
#    action_dist_distance_0_5_n
#    action_dist_distance_0_6_mean
#    action_dist_distance_0_6_std
#    action_dist_distance_0_6_n
#    action_dist_distance_0_7_mean
#    action_dist_distance_0_7_std
#    action_dist_distance_0_7_n
#    action_dist_distance_0_8_mean
#    action_dist_distance_0_8_std
#    action_dist_distance_0_8_n
#    action_dist_distance_0_9_mean
#    action_dist_distance_0_9_std
#    action_dist_distance_0_9_n
#    action_dist_distance_0_10_mean
#    action_dist_distance_0_10_std
#    action_dist_distance_0_10_n
#    action_dist_distance_0_11_mean
#    action_dist_distance_0_11_std
#    action_dist_distance_0_11_n
#    action_dist_distance_0_12_mean
#    action_dist_distance_0_12_std
#    action_dist_distance_0_12_n
#    action_dist_distance_0_13_mean
#    action_dist_distance_0_13_std
#    action_dist_distance_0_13_n
#    action_dist_distance_0_14_mean
#    action_dist_distance_0_14_std
#    action_dist_distance_0_14_n
#    action_dist_distance_0_15_mean
#    action_dist_distance_0_15_std
#    action_dist_distance_0_15_n
#    action_dist_distance_0_16_mean
#    action_dist_distance_0_16_std
#    action_dist_distance_0_16_n
#    action_dist_distance_0_17_mean
#    action_dist_distance_0_17_std
#    action_dist_distance_0_17_n
#    action_dist_distance_0_18_mean
#    action_dist_distance_0_18_std
#    action_dist_distance_0_18_n
#    action_dist_distance_0_19_mean
#    action_dist_distance_0_19_std
#    action_dist_distance_0_19_n
#    action_dist_distance_0_20_mean
#    action_dist_distance_0_20_std
#    action_dist_distance_0_20_n
#    action_dist_distance_0_21_mean
#    action_dist_distance_0_21_std
#    action_dist_distance_0_21_n
#    action_dist_distance_0_22_mean
#    action_dist_distance_0_22_std
#    action_dist_distance_0_22_n
#    action_dist_distance_0_23_mean
#    action_dist_distance_0_23_std
#    action_dist_distance_0_23_n
#    action_dist_distance_0_24_mean
#    action_dist_distance_0_24_std
#    action_dist_distance_0_24_n
#    action_dist_distance_0_25_mean
#    action_dist_distance_0_25_std
#    action_dist_distance_0_25_n
#    action_dist_distance_0_26_mean
#    action_dist_distance_0_26_std
#    action_dist_distance_0_26_n
#    action_dist_distance_0_27_mean
#    action_dist_distance_0_27_std
#    action_dist_distance_0_27_n
#    action_dist_distance_0_28_mean
#    action_dist_distance_0_28_std
#    action_dist_distance_0_28_n
#    action_dist_distance_0_29_mean
#    action_dist_distance_0_29_std
#    action_dist_distance_0_29_n
#    action_dist_distance_0_30_mean
#    action_dist_distance_0_30_std
#    action_dist_distance_0_30_n
#    action_dist_distance_0_31_mean
#    action_dist_distance_0_31_std
#    action_dist_distance_0_31_n
#    action_dist_distance_0_32_mean
#    action_dist_distance_0_32_std
#    action_dist_distance_0_32_n
#    action_dist_distance_0_33_mean
#    action_dist_distance_0_33_std
#    action_dist_distance_0_33_n
#    action_dist_distance_0_34_mean
#    action_dist_distance_0_34_std
#    action_dist_distance_0_34_n
#    action_dist_distance_0_35_mean
#    action_dist_distance_0_35_std
#    action_dist_distance_0_35_n
#    action_dist_distance_0_36_mean
#    action_dist_distance_0_36_std
#    action_dist_distance_0_36_n
#    action_dist_distance_0_37_mean
#    action_dist_distance_0_37_std
#    action_dist_distance_0_37_n
#    action_dist_distance_0_38_mean
#    action_dist_distance_0_38_std
#    action_dist_distance_0_38_n
#    action_dist_distance_0_39_mean
#    action_dist_distance_0_39_std
#    action_dist_distance_0_39_n
#    action_dist_distance_0_40_mean
#    action_dist_distance_0_40_std
#    action_dist_distance_0_40_n
#    action_dist_distance_0_41_mean
#    action_dist_distance_0_41_std
#    action_dist_distance_0_41_n
#    action_dist_distance_0_42_mean
#    action_dist_distance_0_42_std
#    action_dist_distance_0_42_n
#    action_dist_distance_0_43_mean
#    action_dist_distance_0_43_std
#    action_dist_distance_0_43_n
#    action_dist_distance_0_44_mean
#    action_dist_distance_0_44_std
#    action_dist_distance_0_44_n
#    action_dist_distance_0_45_mean
#    action_dist_distance_0_45_std
#    action_dist_distance_0_45_n
#    action_dist_distance_0_46_mean
#    action_dist_distance_0_46_std
#    action_dist_distance_0_46_n
#    action_dist_distance_0_47_mean
#    action_dist_distance_0_47_std
#    action_dist_distance_0_47_n
#    action_dist_distance_0_48_mean
#    action_dist_distance_0_48_std
#    action_dist_distance_0_48_n
#    action_dist_distance_0_49_mean
#    action_dist_distance_0_49_std
#    action_dist_distance_0_49_n
#    action_dist_distance_0_50_mean
#    action_dist_distance_0_50_std
#    action_dist_distance_0_50_n
#    action_dist_distance_0_51_mean
#    action_dist_distance_0_51_std
#    action_dist_distance_0_51_n
#    action_dist_distance_0_52_mean
#    action_dist_distance_0_52_std
#    action_dist_distance_0_52_n
#    action_dist_distance_0_53_mean
#    action_dist_distance_0_53_std
#    action_dist_distance_0_53_n
#    action_dist_distance_0_54_mean
#    action_dist_distance_0_54_std
#    action_dist_distance_0_54_n
#    action_dist_distance_0_55_mean
#    action_dist_distance_0_55_std
#    action_dist_distance_0_55_n
#    action_dist_distance_0_56_mean
#    action_dist_distance_0_56_std
#    action_dist_distance_0_56_n
#    action_dist_distance_0_57_mean
#    action_dist_distance_0_57_std
#    action_dist_distance_0_57_n
#    action_dist_distance_0_58_mean
#    action_dist_distance_0_58_std
#    action_dist_distance_0_58_n
#    action_dist_distance_0_59_mean
#    action_dist_distance_0_59_std
#    action_dist_distance_0_59_n
#    action_dist_distance_0_60_mean
#    action_dist_distance_0_60_std
#    action_dist_distance_0_60_n
#    action_dist_distance_0_61_mean
#    action_dist_distance_0_61_std
#    action_dist_distance_0_61_n
#    action_dist_distance_0_62_mean
#    action_dist_distance_0_62_std
#    action_dist_distance_0_62_n
#    action_dist_distance_0_63_mean
#    action_dist_distance_0_63_std
#    action_dist_distance_0_63_n
#    action_dist_distance_0_64_mean
#    action_dist_distance_0_64_std
#    action_dist_distance_0_64_n
#    action_dist_distance_0_65_mean
#    action_dist_distance_0_65_std
#    action_dist_distance_0_65_n
#    action_dist_distance_0_66_mean
#    action_dist_distance_0_66_std
#    action_dist_distance_0_66_n
#    action_dist_distance_0_67_mean
#    action_dist_distance_0_67_std
#    action_dist_distance_0_67_n
#    action_dist_distance_0_68_mean
#    action_dist_distance_0_68_std
#    action_dist_distance_0_68_n
#    action_dist_distance_0_69_mean
#    action_dist_distance_0_69_std
#    action_dist_distance_0_69_n
#    action_dist_distance_0_70_mean
#    action_dist_distance_0_70_std
#    action_dist_distance_0_70_n
#    action_dist_distance_0_71_mean
#    action_dist_distance_0_71_std
#    action_dist_distance_0_71_n
#    action_dist_distance_0_72_mean
#    action_dist_distance_0_72_std
#    action_dist_distance_0_72_n
#    action_dist_distance_0_73_mean
#    action_dist_distance_0_73_std
#    action_dist_distance_0_73_n
#    action_dist_distance_0_74_mean
#    action_dist_distance_0_74_std
#    action_dist_distance_0_74_n
#    action_dist_distance_0_75_mean
#    action_dist_distance_0_75_std
#    action_dist_distance_0_75_n
#    action_dist_distance_0_76_mean
#    action_dist_distance_0_76_std
#    action_dist_distance_0_76_n
#    action_dist_distance_0_77_mean
#    action_dist_distance_0_77_std
#    action_dist_distance_0_77_n
#    action_dist_distance_0_78_mean
#    action_dist_distance_0_78_std
#    action_dist_distance_0_78_n
#    action_dist_distance_0_79_mean
#    action_dist_distance_0_79_std
#    action_dist_distance_0_79_n
#    action_dist_distance_0_80_mean
#    action_dist_distance_0_80_std
#    action_dist_distance_0_80_n
#    action_dist_distance_0_81_mean
#    action_dist_distance_0_81_std
#    action_dist_distance_0_81_n
#    action_dist_distance_0_82_mean
#    action_dist_distance_0_82_std
#    action_dist_distance_0_82_n
#    action_dist_distance_0_83_mean
#    action_dist_distance_0_83_std
#    action_dist_distance_0_83_n
#    action_dist_distance_0_84_mean
#    action_dist_distance_0_84_std
#    action_dist_distance_0_84_n
#    action_dist_distance_0_85_mean
#    action_dist_distance_0_85_std
#    action_dist_distance_0_85_n
#    action_dist_distance_0_86_mean
#    action_dist_distance_0_86_std
#    action_dist_distance_0_86_n
#    action_dist_distance_0_87_mean
#    action_dist_distance_0_87_std
#    action_dist_distance_0_87_n
#    action_dist_distance_0_88_mean
#    action_dist_distance_0_88_std
#    action_dist_distance_0_88_n
#    action_dist_distance_0_89_mean
#    action_dist_distance_0_89_std
#    action_dist_distance_0_89_n
#    action_dist_distance_0_90_mean
#    action_dist_distance_0_90_std
#    action_dist_distance_0_90_n
#    action_dist_distance_0_91_mean
#    action_dist_distance_0_91_std
#    action_dist_distance_0_91_n
#    action_dist_distance_0_92_mean
#    action_dist_distance_0_92_std
#    action_dist_distance_0_92_n
#    action_dist_distance_0_93_mean
#    action_dist_distance_0_93_std
#    action_dist_distance_0_93_n
#    action_dist_distance_0_94_mean
#    action_dist_distance_0_94_std
#    action_dist_distance_0_94_n
#    action_dist_distance_0_95_mean
#    action_dist_distance_0_95_std
#    action_dist_distance_0_95_n
#    action_dist_distance_0_96_mean
#    action_dist_distance_0_96_std
#    action_dist_distance_0_96_n
#    action_dist_distance_0_97_mean
#    action_dist_distance_0_97_std
#    action_dist_distance_0_97_n
#    action_dist_distance_0_98_mean
#    action_dist_distance_0_98_std
#    action_dist_distance_0_98_n
#    action_dist_distance_0_99_mean
#    action_dist_distance_0_99_std
#    action_dist_distance_0_99_n
#    action_dist_distance_1_0_mean
#    action_dist_distance_1_0_std
#    action_dist_distance_1_0_n
#    action_dist_distance_1_1_mean
#    action_dist_distance_1_1_std
#    action_dist_distance_1_1_n
#    action_dist_distance_1_2_mean
#    action_dist_distance_1_2_std
#    action_dist_distance_1_2_n
#    action_dist_distance_1_3_mean
#    action_dist_distance_1_3_std
#    action_dist_distance_1_3_n
#    action_dist_distance_1_4_mean
#    action_dist_distance_1_4_std
#    action_dist_distance_1_4_n
#    action_dist_distance_1_5_mean
#    action_dist_distance_1_5_std
#    action_dist_distance_1_5_n
#    action_dist_distance_1_6_mean
#    action_dist_distance_1_6_std
#    action_dist_distance_1_6_n
#    action_dist_distance_1_7_mean
#    action_dist_distance_1_7_std
#    action_dist_distance_1_7_n
#    action_dist_distance_1_8_mean
#    action_dist_distance_1_8_std
#    action_dist_distance_1_8_n
#    action_dist_distance_1_9_mean
#    action_dist_distance_1_9_std
#    action_dist_distance_1_9_n
#    action_dist_distance_1_10_mean
#    action_dist_distance_1_10_std
#    action_dist_distance_1_10_n
#    action_dist_distance_1_11_mean
#    action_dist_distance_1_11_std
#    action_dist_distance_1_11_n
#    action_dist_distance_1_12_mean
#    action_dist_distance_1_12_std
#    action_dist_distance_1_12_n
#    action_dist_distance_1_13_mean
#    action_dist_distance_1_13_std
#    action_dist_distance_1_13_n
#    action_dist_distance_1_14_mean
#    action_dist_distance_1_14_std
#    action_dist_distance_1_14_n
#    action_dist_distance_1_15_mean
#    action_dist_distance_1_15_std
#    action_dist_distance_1_15_n
#    action_dist_distance_1_16_mean
#    action_dist_distance_1_16_std
#    action_dist_distance_1_16_n
#    action_dist_distance_1_17_mean
#    action_dist_distance_1_17_std
#    action_dist_distance_1_17_n
#    action_dist_distance_1_18_mean
#    action_dist_distance_1_18_std
#    action_dist_distance_1_18_n
#    action_dist_distance_1_19_mean
#    action_dist_distance_1_19_std
#    action_dist_distance_1_19_n
#    action_dist_distance_1_20_mean
#    action_dist_distance_1_20_std
#    action_dist_distance_1_20_n
#    action_dist_distance_1_21_mean
#    action_dist_distance_1_21_std
#    action_dist_distance_1_21_n
#    action_dist_distance_1_22_mean
#    action_dist_distance_1_22_std
#    action_dist_distance_1_22_n
#    action_dist_distance_1_23_mean
#    action_dist_distance_1_23_std
#    action_dist_distance_1_23_n
#    action_dist_distance_1_24_mean
#    action_dist_distance_1_24_std
#    action_dist_distance_1_24_n
#    action_dist_distance_1_25_mean
#    action_dist_distance_1_25_std
#    action_dist_distance_1_25_n
#    action_dist_distance_1_26_mean
#    action_dist_distance_1_26_std
#    action_dist_distance_1_26_n
#    action_dist_distance_1_27_mean
#    action_dist_distance_1_27_std
#    action_dist_distance_1_27_n
#    action_dist_distance_1_28_mean
#    action_dist_distance_1_28_std
#    action_dist_distance_1_28_n
#    action_dist_distance_1_29_mean
#    action_dist_distance_1_29_std
#    action_dist_distance_1_29_n
#    action_dist_distance_1_30_mean
#    action_dist_distance_1_30_std
#    action_dist_distance_1_30_n
#    action_dist_distance_1_31_mean
#    action_dist_distance_1_31_std
#    action_dist_distance_1_31_n
#    action_dist_distance_1_32_mean
#    action_dist_distance_1_32_std
#    action_dist_distance_1_32_n
#    action_dist_distance_1_33_mean
#    action_dist_distance_1_33_std
#    action_dist_distance_1_33_n
#    action_dist_distance_1_34_mean
#    action_dist_distance_1_34_std
#    action_dist_distance_1_34_n
#    action_dist_distance_1_35_mean
#    action_dist_distance_1_35_std
#    action_dist_distance_1_35_n
#    action_dist_distance_1_36_mean
#    action_dist_distance_1_36_std
#    action_dist_distance_1_36_n
#    action_dist_distance_1_37_mean
#    action_dist_distance_1_37_std
#    action_dist_distance_1_37_n
#    action_dist_distance_1_38_mean
#    action_dist_distance_1_38_std
#    action_dist_distance_1_38_n
#    action_dist_distance_1_39_mean
#    action_dist_distance_1_39_std
#    action_dist_distance_1_39_n
#    action_dist_distance_1_40_mean
#    action_dist_distance_1_40_std
#    action_dist_distance_1_40_n
#    action_dist_distance_1_41_mean
#    action_dist_distance_1_41_std
#    action_dist_distance_1_41_n
#    action_dist_distance_1_42_mean
#    action_dist_distance_1_42_std
#    action_dist_distance_1_42_n
#    action_dist_distance_1_43_mean
#    action_dist_distance_1_43_std
#    action_dist_distance_1_43_n
#    action_dist_distance_1_44_mean
#    action_dist_distance_1_44_std
#    action_dist_distance_1_44_n
#    action_dist_distance_1_45_mean
#    action_dist_distance_1_45_std
#    action_dist_distance_1_45_n
#    action_dist_distance_1_46_mean
#    action_dist_distance_1_46_std
#    action_dist_distance_1_46_n
#    action_dist_distance_1_47_mean
#    action_dist_distance_1_47_std
#    action_dist_distance_1_47_n
#    action_dist_distance_1_48_mean
#    action_dist_distance_1_48_std
#    action_dist_distance_1_48_n
#    action_dist_distance_1_49_mean
#    action_dist_distance_1_49_std
#    action_dist_distance_1_49_n
#    action_dist_distance_1_50_mean
#    action_dist_distance_1_50_std
#    action_dist_distance_1_50_n
#    action_dist_distance_1_51_mean
#    action_dist_distance_1_51_std
#    action_dist_distance_1_51_n
#    action_dist_distance_1_52_mean
#    action_dist_distance_1_52_std
#    action_dist_distance_1_52_n
#    action_dist_distance_1_53_mean
#    action_dist_distance_1_53_std
#    action_dist_distance_1_53_n
#    action_dist_distance_1_54_mean
#    action_dist_distance_1_54_std
#    action_dist_distance_1_54_n
#    action_dist_distance_1_55_mean
#    action_dist_distance_1_55_std
#    action_dist_distance_1_55_n
#    action_dist_distance_1_56_mean
#    action_dist_distance_1_56_std
#    action_dist_distance_1_56_n
#    action_dist_distance_1_57_mean
#    action_dist_distance_1_57_std
#    action_dist_distance_1_57_n
#    action_dist_distance_1_58_mean
#    action_dist_distance_1_58_std
#    action_dist_distance_1_58_n
#    action_dist_distance_1_59_mean
#    action_dist_distance_1_59_std
#    action_dist_distance_1_59_n
#    action_dist_distance_1_60_mean
#    action_dist_distance_1_60_std
#    action_dist_distance_1_60_n
#    action_dist_distance_1_61_mean
#    action_dist_distance_1_61_std
#    action_dist_distance_1_61_n
#    action_dist_distance_1_62_mean
#    action_dist_distance_1_62_std
#    action_dist_distance_1_62_n
#    action_dist_distance_1_63_mean
#    action_dist_distance_1_63_std
#    action_dist_distance_1_63_n
#    action_dist_distance_1_64_mean
#    action_dist_distance_1_64_std
#    action_dist_distance_1_64_n
#    action_dist_distance_1_65_mean
#    action_dist_distance_1_65_std
#    action_dist_distance_1_65_n
#    action_dist_distance_1_66_mean
#    action_dist_distance_1_66_std
#    action_dist_distance_1_66_n
#    action_dist_distance_1_67_mean
#    action_dist_distance_1_67_std
#    action_dist_distance_1_67_n
#    action_dist_distance_1_68_mean
#    action_dist_distance_1_68_std
#    action_dist_distance_1_68_n
#    action_dist_distance_1_69_mean
#    action_dist_distance_1_69_std
#    action_dist_distance_1_69_n
#    action_dist_distance_1_70_mean
#    action_dist_distance_1_70_std
#    action_dist_distance_1_70_n
#    action_dist_distance_1_71_mean
#    action_dist_distance_1_71_std
#    action_dist_distance_1_71_n
#    action_dist_distance_1_72_mean
#    action_dist_distance_1_72_std
#    action_dist_distance_1_72_n
#    action_dist_distance_1_73_mean
#    action_dist_distance_1_73_std
#    action_dist_distance_1_73_n
#    action_dist_distance_1_74_mean
#    action_dist_distance_1_74_std
#    action_dist_distance_1_74_n
#    action_dist_distance_1_75_mean
#    action_dist_distance_1_75_std
#    action_dist_distance_1_75_n
#    action_dist_distance_1_76_mean
#    action_dist_distance_1_76_std
#    action_dist_distance_1_76_n
#    action_dist_distance_1_77_mean
#    action_dist_distance_1_77_std
#    action_dist_distance_1_77_n
#    action_dist_distance_1_78_mean
#    action_dist_distance_1_78_std
#    action_dist_distance_1_78_n
#    action_dist_distance_1_79_mean
#    action_dist_distance_1_79_std
#    action_dist_distance_1_79_n
#    action_dist_distance_1_80_mean
#    action_dist_distance_1_80_std
#    action_dist_distance_1_80_n
#    action_dist_distance_1_81_mean
#    action_dist_distance_1_81_std
#    action_dist_distance_1_81_n
#    action_dist_distance_1_82_mean
#    action_dist_distance_1_82_std
#    action_dist_distance_1_82_n
#    action_dist_distance_1_83_mean
#    action_dist_distance_1_83_std
#    action_dist_distance_1_83_n
#    action_dist_distance_1_84_mean
#    action_dist_distance_1_84_std
#    action_dist_distance_1_84_n
#    action_dist_distance_1_85_mean
#    action_dist_distance_1_85_std
#    action_dist_distance_1_85_n
#    action_dist_distance_1_86_mean
#    action_dist_distance_1_86_std
#    action_dist_distance_1_86_n
#    action_dist_distance_1_87_mean
#    action_dist_distance_1_87_std
#    action_dist_distance_1_87_n
#    action_dist_distance_1_88_mean
#    action_dist_distance_1_88_std
#    action_dist_distance_1_88_n
#    action_dist_distance_1_89_mean
#    action_dist_distance_1_89_std
#    action_dist_distance_1_89_n
#    action_dist_distance_1_90_mean
#    action_dist_distance_1_90_std
#    action_dist_distance_1_90_n
#    action_dist_distance_1_91_mean
#    action_dist_distance_1_91_std
#    action_dist_distance_1_91_n
#    action_dist_distance_1_92_mean
#    action_dist_distance_1_92_std
#    action_dist_distance_1_92_n
#    action_dist_distance_1_93_mean
#    action_dist_distance_1_93_std
#    action_dist_distance_1_93_n
#    action_dist_distance_1_94_mean
#    action_dist_distance_1_94_std
#    action_dist_distance_1_94_n
#    action_dist_distance_1_95_mean
#    action_dist_distance_1_95_std
#    action_dist_distance_1_95_n
#    action_dist_distance_1_96_mean
#    action_dist_distance_1_96_std
#    action_dist_distance_1_96_n
#    action_dist_distance_1_97_mean
#    action_dist_distance_1_97_std
#    action_dist_distance_1_97_n
#    action_dist_distance_1_98_mean
#    action_dist_distance_1_98_std
#    action_dist_distance_1_98_n
#    action_dist_distance_1_99_mean
#    action_dist_distance_1_99_std
#    action_dist_distance_1_99_n
#    bayes_accuracy_0_mean
#    bayes_accuracy_0_std
#    bayes_accuracy_0_n
#    bayes_accuracy_1_mean
#    bayes_accuracy_1_std
#    bayes_accuracy_1_n
#    bayes_accuracy_0_0_mean
#    bayes_accuracy_0_0_std
#    bayes_accuracy_0_0_n
#    bayes_accuracy_0_1_mean
#    bayes_accuracy_0_1_std
#    bayes_accuracy_0_1_n
#    bayes_accuracy_0_2_mean
#    bayes_accuracy_0_2_std
#    bayes_accuracy_0_2_n
#    bayes_accuracy_0_3_mean
#    bayes_accuracy_0_3_std
#    bayes_accuracy_0_3_n
#    bayes_accuracy_0_4_mean
#    bayes_accuracy_0_4_std
#    bayes_accuracy_0_4_n
#    bayes_accuracy_0_5_mean
#    bayes_accuracy_0_5_std
#    bayes_accuracy_0_5_n
#    bayes_accuracy_0_6_mean
#    bayes_accuracy_0_6_std
#    bayes_accuracy_0_6_n
#    bayes_accuracy_0_7_mean
#    bayes_accuracy_0_7_std
#    bayes_accuracy_0_7_n
#    bayes_accuracy_0_8_mean
#    bayes_accuracy_0_8_std
#    bayes_accuracy_0_8_n
#    bayes_accuracy_0_9_mean
#    bayes_accuracy_0_9_std
#    bayes_accuracy_0_9_n
#    bayes_accuracy_0_10_mean
#    bayes_accuracy_0_10_std
#    bayes_accuracy_0_10_n
#    bayes_accuracy_0_11_mean
#    bayes_accuracy_0_11_std
#    bayes_accuracy_0_11_n
#    bayes_accuracy_0_12_mean
#    bayes_accuracy_0_12_std
#    bayes_accuracy_0_12_n
#    bayes_accuracy_0_13_mean
#    bayes_accuracy_0_13_std
#    bayes_accuracy_0_13_n
#    bayes_accuracy_0_14_mean
#    bayes_accuracy_0_14_std
#    bayes_accuracy_0_14_n
#    bayes_accuracy_0_15_mean
#    bayes_accuracy_0_15_std
#    bayes_accuracy_0_15_n
#    bayes_accuracy_0_16_mean
#    bayes_accuracy_0_16_std
#    bayes_accuracy_0_16_n
#    bayes_accuracy_0_17_mean
#    bayes_accuracy_0_17_std
#    bayes_accuracy_0_17_n
#    bayes_accuracy_0_18_mean
#    bayes_accuracy_0_18_std
#    bayes_accuracy_0_18_n
#    bayes_accuracy_0_19_mean
#    bayes_accuracy_0_19_std
#    bayes_accuracy_0_19_n
#    bayes_accuracy_0_20_mean
#    bayes_accuracy_0_20_std
#    bayes_accuracy_0_20_n
#    bayes_accuracy_0_21_mean
#    bayes_accuracy_0_21_std
#    bayes_accuracy_0_21_n
#    bayes_accuracy_0_22_mean
#    bayes_accuracy_0_22_std
#    bayes_accuracy_0_22_n
#    bayes_accuracy_0_23_mean
#    bayes_accuracy_0_23_std
#    bayes_accuracy_0_23_n
#    bayes_accuracy_0_24_mean
#    bayes_accuracy_0_24_std
#    bayes_accuracy_0_24_n
#    bayes_accuracy_0_25_mean
#    bayes_accuracy_0_25_std
#    bayes_accuracy_0_25_n
#    bayes_accuracy_0_26_mean
#    bayes_accuracy_0_26_std
#    bayes_accuracy_0_26_n
#    bayes_accuracy_0_27_mean
#    bayes_accuracy_0_27_std
#    bayes_accuracy_0_27_n
#    bayes_accuracy_0_28_mean
#    bayes_accuracy_0_28_std
#    bayes_accuracy_0_28_n
#    bayes_accuracy_0_29_mean
#    bayes_accuracy_0_29_std
#    bayes_accuracy_0_29_n
#    bayes_accuracy_0_30_mean
#    bayes_accuracy_0_30_std
#    bayes_accuracy_0_30_n
#    bayes_accuracy_0_31_mean
#    bayes_accuracy_0_31_std
#    bayes_accuracy_0_31_n
#    bayes_accuracy_0_32_mean
#    bayes_accuracy_0_32_std
#    bayes_accuracy_0_32_n
#    bayes_accuracy_0_33_mean
#    bayes_accuracy_0_33_std
#    bayes_accuracy_0_33_n
#    bayes_accuracy_0_34_mean
#    bayes_accuracy_0_34_std
#    bayes_accuracy_0_34_n
#    bayes_accuracy_0_35_mean
#    bayes_accuracy_0_35_std
#    bayes_accuracy_0_35_n
#    bayes_accuracy_0_36_mean
#    bayes_accuracy_0_36_std
#    bayes_accuracy_0_36_n
#    bayes_accuracy_0_37_mean
#    bayes_accuracy_0_37_std
#    bayes_accuracy_0_37_n
#    bayes_accuracy_0_38_mean
#    bayes_accuracy_0_38_std
#    bayes_accuracy_0_38_n
#    bayes_accuracy_0_39_mean
#    bayes_accuracy_0_39_std
#    bayes_accuracy_0_39_n
#    bayes_accuracy_0_40_mean
#    bayes_accuracy_0_40_std
#    bayes_accuracy_0_40_n
#    bayes_accuracy_0_41_mean
#    bayes_accuracy_0_41_std
#    bayes_accuracy_0_41_n
#    bayes_accuracy_0_42_mean
#    bayes_accuracy_0_42_std
#    bayes_accuracy_0_42_n
#    bayes_accuracy_0_43_mean
#    bayes_accuracy_0_43_std
#    bayes_accuracy_0_43_n
#    bayes_accuracy_0_44_mean
#    bayes_accuracy_0_44_std
#    bayes_accuracy_0_44_n
#    bayes_accuracy_0_45_mean
#    bayes_accuracy_0_45_std
#    bayes_accuracy_0_45_n
#    bayes_accuracy_0_46_mean
#    bayes_accuracy_0_46_std
#    bayes_accuracy_0_46_n
#    bayes_accuracy_0_47_mean
#    bayes_accuracy_0_47_std
#    bayes_accuracy_0_47_n
#    bayes_accuracy_0_48_mean
#    bayes_accuracy_0_48_std
#    bayes_accuracy_0_48_n
#    bayes_accuracy_0_49_mean
#    bayes_accuracy_0_49_std
#    bayes_accuracy_0_49_n
#    bayes_accuracy_0_50_mean
#    bayes_accuracy_0_50_std
#    bayes_accuracy_0_50_n
#    bayes_accuracy_0_51_mean
#    bayes_accuracy_0_51_std
#    bayes_accuracy_0_51_n
#    bayes_accuracy_0_52_mean
#    bayes_accuracy_0_52_std
#    bayes_accuracy_0_52_n
#    bayes_accuracy_0_53_mean
#    bayes_accuracy_0_53_std
#    bayes_accuracy_0_53_n
#    bayes_accuracy_0_54_mean
#    bayes_accuracy_0_54_std
#    bayes_accuracy_0_54_n
#    bayes_accuracy_0_55_mean
#    bayes_accuracy_0_55_std
#    bayes_accuracy_0_55_n
#    bayes_accuracy_0_56_mean
#    bayes_accuracy_0_56_std
#    bayes_accuracy_0_56_n
#    bayes_accuracy_0_57_mean
#    bayes_accuracy_0_57_std
#    bayes_accuracy_0_57_n
#    bayes_accuracy_0_58_mean
#    bayes_accuracy_0_58_std
#    bayes_accuracy_0_58_n
#    bayes_accuracy_0_59_mean
#    bayes_accuracy_0_59_std
#    bayes_accuracy_0_59_n
#    bayes_accuracy_0_60_mean
#    bayes_accuracy_0_60_std
#    bayes_accuracy_0_60_n
#    bayes_accuracy_0_61_mean
#    bayes_accuracy_0_61_std
#    bayes_accuracy_0_61_n
#    bayes_accuracy_0_62_mean
#    bayes_accuracy_0_62_std
#    bayes_accuracy_0_62_n
#    bayes_accuracy_0_63_mean
#    bayes_accuracy_0_63_std
#    bayes_accuracy_0_63_n
#    bayes_accuracy_0_64_mean
#    bayes_accuracy_0_64_std
#    bayes_accuracy_0_64_n
#    bayes_accuracy_0_65_mean
#    bayes_accuracy_0_65_std
#    bayes_accuracy_0_65_n
#    bayes_accuracy_0_66_mean
#    bayes_accuracy_0_66_std
#    bayes_accuracy_0_66_n
#    bayes_accuracy_0_67_mean
#    bayes_accuracy_0_67_std
#    bayes_accuracy_0_67_n
#    bayes_accuracy_0_68_mean
#    bayes_accuracy_0_68_std
#    bayes_accuracy_0_68_n
#    bayes_accuracy_0_69_mean
#    bayes_accuracy_0_69_std
#    bayes_accuracy_0_69_n
#    bayes_accuracy_0_70_mean
#    bayes_accuracy_0_70_std
#    bayes_accuracy_0_70_n
#    bayes_accuracy_0_71_mean
#    bayes_accuracy_0_71_std
#    bayes_accuracy_0_71_n
#    bayes_accuracy_0_72_mean
#    bayes_accuracy_0_72_std
#    bayes_accuracy_0_72_n
#    bayes_accuracy_0_73_mean
#    bayes_accuracy_0_73_std
#    bayes_accuracy_0_73_n
#    bayes_accuracy_0_74_mean
#    bayes_accuracy_0_74_std
#    bayes_accuracy_0_74_n
#    bayes_accuracy_0_75_mean
#    bayes_accuracy_0_75_std
#    bayes_accuracy_0_75_n
#    bayes_accuracy_0_76_mean
#    bayes_accuracy_0_76_std
#    bayes_accuracy_0_76_n
#    bayes_accuracy_0_77_mean
#    bayes_accuracy_0_77_std
#    bayes_accuracy_0_77_n
#    bayes_accuracy_0_78_mean
#    bayes_accuracy_0_78_std
#    bayes_accuracy_0_78_n
#    bayes_accuracy_0_79_mean
#    bayes_accuracy_0_79_std
#    bayes_accuracy_0_79_n
#    bayes_accuracy_0_80_mean
#    bayes_accuracy_0_80_std
#    bayes_accuracy_0_80_n
#    bayes_accuracy_0_81_mean
#    bayes_accuracy_0_81_std
#    bayes_accuracy_0_81_n
#    bayes_accuracy_0_82_mean
#    bayes_accuracy_0_82_std
#    bayes_accuracy_0_82_n
#    bayes_accuracy_0_83_mean
#    bayes_accuracy_0_83_std
#    bayes_accuracy_0_83_n
#    bayes_accuracy_0_84_mean
#    bayes_accuracy_0_84_std
#    bayes_accuracy_0_84_n
#    bayes_accuracy_0_85_mean
#    bayes_accuracy_0_85_std
#    bayes_accuracy_0_85_n
#    bayes_accuracy_0_86_mean
#    bayes_accuracy_0_86_std
#    bayes_accuracy_0_86_n
#    bayes_accuracy_0_87_mean
#    bayes_accuracy_0_87_std
#    bayes_accuracy_0_87_n
#    bayes_accuracy_0_88_mean
#    bayes_accuracy_0_88_std
#    bayes_accuracy_0_88_n
#    bayes_accuracy_0_89_mean
#    bayes_accuracy_0_89_std
#    bayes_accuracy_0_89_n
#    bayes_accuracy_0_90_mean
#    bayes_accuracy_0_90_std
#    bayes_accuracy_0_90_n
#    bayes_accuracy_0_91_mean
#    bayes_accuracy_0_91_std
#    bayes_accuracy_0_91_n
#    bayes_accuracy_0_92_mean
#    bayes_accuracy_0_92_std
#    bayes_accuracy_0_92_n
#    bayes_accuracy_0_93_mean
#    bayes_accuracy_0_93_std
#    bayes_accuracy_0_93_n
#    bayes_accuracy_0_94_mean
#    bayes_accuracy_0_94_std
#    bayes_accuracy_0_94_n
#    bayes_accuracy_0_95_mean
#    bayes_accuracy_0_95_std
#    bayes_accuracy_0_95_n
#    bayes_accuracy_0_96_mean
#    bayes_accuracy_0_96_std
#    bayes_accuracy_0_96_n
#    bayes_accuracy_0_97_mean
#    bayes_accuracy_0_97_std
#    bayes_accuracy_0_97_n
#    bayes_accuracy_0_98_mean
#    bayes_accuracy_0_98_std
#    bayes_accuracy_0_98_n
#    bayes_accuracy_0_99_mean
#    bayes_accuracy_0_99_std
#    bayes_accuracy_0_99_n
#    bayes_accuracy_1_0_mean
#    bayes_accuracy_1_0_std
#    bayes_accuracy_1_0_n
#    bayes_accuracy_1_1_mean
#    bayes_accuracy_1_1_std
#    bayes_accuracy_1_1_n
#    bayes_accuracy_1_2_mean
#    bayes_accuracy_1_2_std
#    bayes_accuracy_1_2_n
#    bayes_accuracy_1_3_mean
#    bayes_accuracy_1_3_std
#    bayes_accuracy_1_3_n
#    bayes_accuracy_1_4_mean
#    bayes_accuracy_1_4_std
#    bayes_accuracy_1_4_n
#    bayes_accuracy_1_5_mean
#    bayes_accuracy_1_5_std
#    bayes_accuracy_1_5_n
#    bayes_accuracy_1_6_mean
#    bayes_accuracy_1_6_std
#    bayes_accuracy_1_6_n
#    bayes_accuracy_1_7_mean
#    bayes_accuracy_1_7_std
#    bayes_accuracy_1_7_n
#    bayes_accuracy_1_8_mean
#    bayes_accuracy_1_8_std
#    bayes_accuracy_1_8_n
#    bayes_accuracy_1_9_mean
#    bayes_accuracy_1_9_std
#    bayes_accuracy_1_9_n
#    bayes_accuracy_1_10_mean
#    bayes_accuracy_1_10_std
#    bayes_accuracy_1_10_n
#    bayes_accuracy_1_11_mean
#    bayes_accuracy_1_11_std
#    bayes_accuracy_1_11_n
#    bayes_accuracy_1_12_mean
#    bayes_accuracy_1_12_std
#    bayes_accuracy_1_12_n
#    bayes_accuracy_1_13_mean
#    bayes_accuracy_1_13_std
#    bayes_accuracy_1_13_n
#    bayes_accuracy_1_14_mean
#    bayes_accuracy_1_14_std
#    bayes_accuracy_1_14_n
#    bayes_accuracy_1_15_mean
#    bayes_accuracy_1_15_std
#    bayes_accuracy_1_15_n
#    bayes_accuracy_1_16_mean
#    bayes_accuracy_1_16_std
#    bayes_accuracy_1_16_n
#    bayes_accuracy_1_17_mean
#    bayes_accuracy_1_17_std
#    bayes_accuracy_1_17_n
#    bayes_accuracy_1_18_mean
#    bayes_accuracy_1_18_std
#    bayes_accuracy_1_18_n
#    bayes_accuracy_1_19_mean
#    bayes_accuracy_1_19_std
#    bayes_accuracy_1_19_n
#    bayes_accuracy_1_20_mean
#    bayes_accuracy_1_20_std
#    bayes_accuracy_1_20_n
#    bayes_accuracy_1_21_mean
#    bayes_accuracy_1_21_std
#    bayes_accuracy_1_21_n
#    bayes_accuracy_1_22_mean
#    bayes_accuracy_1_22_std
#    bayes_accuracy_1_22_n
#    bayes_accuracy_1_23_mean
#    bayes_accuracy_1_23_std
#    bayes_accuracy_1_23_n
#    bayes_accuracy_1_24_mean
#    bayes_accuracy_1_24_std
#    bayes_accuracy_1_24_n
#    bayes_accuracy_1_25_mean
#    bayes_accuracy_1_25_std
#    bayes_accuracy_1_25_n
#    bayes_accuracy_1_26_mean
#    bayes_accuracy_1_26_std
#    bayes_accuracy_1_26_n
#    bayes_accuracy_1_27_mean
#    bayes_accuracy_1_27_std
#    bayes_accuracy_1_27_n
#    bayes_accuracy_1_28_mean
#    bayes_accuracy_1_28_std
#    bayes_accuracy_1_28_n
#    bayes_accuracy_1_29_mean
#    bayes_accuracy_1_29_std
#    bayes_accuracy_1_29_n
#    bayes_accuracy_1_30_mean
#    bayes_accuracy_1_30_std
#    bayes_accuracy_1_30_n
#    bayes_accuracy_1_31_mean
#    bayes_accuracy_1_31_std
#    bayes_accuracy_1_31_n
#    bayes_accuracy_1_32_mean
#    bayes_accuracy_1_32_std
#    bayes_accuracy_1_32_n
#    bayes_accuracy_1_33_mean
#    bayes_accuracy_1_33_std
#    bayes_accuracy_1_33_n
#    bayes_accuracy_1_34_mean
#    bayes_accuracy_1_34_std
#    bayes_accuracy_1_34_n
#    bayes_accuracy_1_35_mean
#    bayes_accuracy_1_35_std
#    bayes_accuracy_1_35_n
#    bayes_accuracy_1_36_mean
#    bayes_accuracy_1_36_std
#    bayes_accuracy_1_36_n
#    bayes_accuracy_1_37_mean
#    bayes_accuracy_1_37_std
#    bayes_accuracy_1_37_n
#    bayes_accuracy_1_38_mean
#    bayes_accuracy_1_38_std
#    bayes_accuracy_1_38_n
#    bayes_accuracy_1_39_mean
#    bayes_accuracy_1_39_std
#    bayes_accuracy_1_39_n
#    bayes_accuracy_1_40_mean
#    bayes_accuracy_1_40_std
#    bayes_accuracy_1_40_n
#    bayes_accuracy_1_41_mean
#    bayes_accuracy_1_41_std
#    bayes_accuracy_1_41_n
#    bayes_accuracy_1_42_mean
#    bayes_accuracy_1_42_std
#    bayes_accuracy_1_42_n
#    bayes_accuracy_1_43_mean
#    bayes_accuracy_1_43_std
#    bayes_accuracy_1_43_n
#    bayes_accuracy_1_44_mean
#    bayes_accuracy_1_44_std
#    bayes_accuracy_1_44_n
#    bayes_accuracy_1_45_mean
#    bayes_accuracy_1_45_std
#    bayes_accuracy_1_45_n
#    bayes_accuracy_1_46_mean
#    bayes_accuracy_1_46_std
#    bayes_accuracy_1_46_n
#    bayes_accuracy_1_47_mean
#    bayes_accuracy_1_47_std
#    bayes_accuracy_1_47_n
#    bayes_accuracy_1_48_mean
#    bayes_accuracy_1_48_std
#    bayes_accuracy_1_48_n
#    bayes_accuracy_1_49_mean
#    bayes_accuracy_1_49_std
#    bayes_accuracy_1_49_n
#    bayes_accuracy_1_50_mean
#    bayes_accuracy_1_50_std
#    bayes_accuracy_1_50_n
#    bayes_accuracy_1_51_mean
#    bayes_accuracy_1_51_std
#    bayes_accuracy_1_51_n
#    bayes_accuracy_1_52_mean
#    bayes_accuracy_1_52_std
#    bayes_accuracy_1_52_n
#    bayes_accuracy_1_53_mean
#    bayes_accuracy_1_53_std
#    bayes_accuracy_1_53_n
#    bayes_accuracy_1_54_mean
#    bayes_accuracy_1_54_std
#    bayes_accuracy_1_54_n
#    bayes_accuracy_1_55_mean
#    bayes_accuracy_1_55_std
#    bayes_accuracy_1_55_n
#    bayes_accuracy_1_56_mean
#    bayes_accuracy_1_56_std
#    bayes_accuracy_1_56_n
#    bayes_accuracy_1_57_mean
#    bayes_accuracy_1_57_std
#    bayes_accuracy_1_57_n
#    bayes_accuracy_1_58_mean
#    bayes_accuracy_1_58_std
#    bayes_accuracy_1_58_n
#    bayes_accuracy_1_59_mean
#    bayes_accuracy_1_59_std
#    bayes_accuracy_1_59_n
#    bayes_accuracy_1_60_mean
#    bayes_accuracy_1_60_std
#    bayes_accuracy_1_60_n
#    bayes_accuracy_1_61_mean
#    bayes_accuracy_1_61_std
#    bayes_accuracy_1_61_n
#    bayes_accuracy_1_62_mean
#    bayes_accuracy_1_62_std
#    bayes_accuracy_1_62_n
#    bayes_accuracy_1_63_mean
#    bayes_accuracy_1_63_std
#    bayes_accuracy_1_63_n
#    bayes_accuracy_1_64_mean
#    bayes_accuracy_1_64_std
#    bayes_accuracy_1_64_n
#    bayes_accuracy_1_65_mean
#    bayes_accuracy_1_65_std
#    bayes_accuracy_1_65_n
#    bayes_accuracy_1_66_mean
#    bayes_accuracy_1_66_std
#    bayes_accuracy_1_66_n
#    bayes_accuracy_1_67_mean
#    bayes_accuracy_1_67_std
#    bayes_accuracy_1_67_n
#    bayes_accuracy_1_68_mean
#    bayes_accuracy_1_68_std
#    bayes_accuracy_1_68_n
#    bayes_accuracy_1_69_mean
#    bayes_accuracy_1_69_std
#    bayes_accuracy_1_69_n
#    bayes_accuracy_1_70_mean
#    bayes_accuracy_1_70_std
#    bayes_accuracy_1_70_n
#    bayes_accuracy_1_71_mean
#    bayes_accuracy_1_71_std
#    bayes_accuracy_1_71_n
#    bayes_accuracy_1_72_mean
#    bayes_accuracy_1_72_std
#    bayes_accuracy_1_72_n
#    bayes_accuracy_1_73_mean
#    bayes_accuracy_1_73_std
#    bayes_accuracy_1_73_n
#    bayes_accuracy_1_74_mean
#    bayes_accuracy_1_74_std
#    bayes_accuracy_1_74_n
#    bayes_accuracy_1_75_mean
#    bayes_accuracy_1_75_std
#    bayes_accuracy_1_75_n
#    bayes_accuracy_1_76_mean
#    bayes_accuracy_1_76_std
#    bayes_accuracy_1_76_n
#    bayes_accuracy_1_77_mean
#    bayes_accuracy_1_77_std
#    bayes_accuracy_1_77_n
#    bayes_accuracy_1_78_mean
#    bayes_accuracy_1_78_std
#    bayes_accuracy_1_78_n
#    bayes_accuracy_1_79_mean
#    bayes_accuracy_1_79_std
#    bayes_accuracy_1_79_n
#    bayes_accuracy_1_80_mean
#    bayes_accuracy_1_80_std
#    bayes_accuracy_1_80_n
#    bayes_accuracy_1_81_mean
#    bayes_accuracy_1_81_std
#    bayes_accuracy_1_81_n
#    bayes_accuracy_1_82_mean
#    bayes_accuracy_1_82_std
#    bayes_accuracy_1_82_n
#    bayes_accuracy_1_83_mean
#    bayes_accuracy_1_83_std
#    bayes_accuracy_1_83_n
#    bayes_accuracy_1_84_mean
#    bayes_accuracy_1_84_std
#    bayes_accuracy_1_84_n
#    bayes_accuracy_1_85_mean
#    bayes_accuracy_1_85_std
#    bayes_accuracy_1_85_n
#    bayes_accuracy_1_86_mean
#    bayes_accuracy_1_86_std
#    bayes_accuracy_1_86_n
#    bayes_accuracy_1_87_mean
#    bayes_accuracy_1_87_std
#    bayes_accuracy_1_87_n
#    bayes_accuracy_1_88_mean
#    bayes_accuracy_1_88_std
#    bayes_accuracy_1_88_n
#    bayes_accuracy_1_89_mean
#    bayes_accuracy_1_89_std
#    bayes_accuracy_1_89_n
#    bayes_accuracy_1_90_mean
#    bayes_accuracy_1_90_std
#    bayes_accuracy_1_90_n
#    bayes_accuracy_1_91_mean
#    bayes_accuracy_1_91_std
#    bayes_accuracy_1_91_n
#    bayes_accuracy_1_92_mean
#    bayes_accuracy_1_92_std
#    bayes_accuracy_1_92_n
#    bayes_accuracy_1_93_mean
#    bayes_accuracy_1_93_std
#    bayes_accuracy_1_93_n
#    bayes_accuracy_1_94_mean
#    bayes_accuracy_1_94_std
#    bayes_accuracy_1_94_n
#    bayes_accuracy_1_95_mean
#    bayes_accuracy_1_95_std
#    bayes_accuracy_1_95_n
#    bayes_accuracy_1_96_mean
#    bayes_accuracy_1_96_std
#    bayes_accuracy_1_96_n
#    bayes_accuracy_1_97_mean
#    bayes_accuracy_1_97_std
#    bayes_accuracy_1_97_n
#    bayes_accuracy_1_98_mean
#    bayes_accuracy_1_98_std
#    bayes_accuracy_1_98_n
#    bayes_accuracy_1_99_mean
#    bayes_accuracy_1_99_std
#    bayes_accuracy_1_99_n
#    search_time_CI
#    update_time_CI
#    reinvigoration_time_CI
#    evaluation_time_CI
#    policy_calls_CI
#    inference_time_CI
#    search_depth_CI
#    min_value_CI
#    max_value_CI
#    episode_return_CI
#    episode_discounted_return_CI
#    episode_steps_CI
#    episode_time_CI
#    action_dist_distance_0_CI
#    action_dist_distance_1_CI
#    action_dist_distance_0_0_CI
#    action_dist_distance_0_1_CI
#    action_dist_distance_0_2_CI
#    action_dist_distance_0_3_CI
#    action_dist_distance_0_4_CI
#    action_dist_distance_0_5_CI
#    action_dist_distance_0_6_CI
#    action_dist_distance_0_7_CI
#    action_dist_distance_0_8_CI
#    action_dist_distance_0_9_CI
#    action_dist_distance_0_10_CI
#    action_dist_distance_0_11_CI
#    action_dist_distance_0_12_CI
#    action_dist_distance_0_13_CI
#    action_dist_distance_0_14_CI
#    action_dist_distance_0_15_CI
#    action_dist_distance_0_16_CI
#    action_dist_distance_0_17_CI
#    action_dist_distance_0_18_CI
#    action_dist_distance_0_19_CI
#    action_dist_distance_0_20_CI
#    action_dist_distance_0_21_CI
#    action_dist_distance_0_22_CI
#    action_dist_distance_0_23_CI
#    action_dist_distance_0_24_CI
#    action_dist_distance_0_25_CI
#    action_dist_distance_0_26_CI
#    action_dist_distance_0_27_CI
#    action_dist_distance_0_28_CI
#    action_dist_distance_0_29_CI
#    action_dist_distance_0_30_CI
#    action_dist_distance_0_31_CI
#    action_dist_distance_0_32_CI
#    action_dist_distance_0_33_CI
#    action_dist_distance_0_34_CI
#    action_dist_distance_0_35_CI
#    action_dist_distance_0_36_CI
#    action_dist_distance_0_37_CI
#    action_dist_distance_0_38_CI
#    action_dist_distance_0_39_CI
#    action_dist_distance_0_40_CI
#    action_dist_distance_0_41_CI
#    action_dist_distance_0_42_CI
#    action_dist_distance_0_43_CI
#    action_dist_distance_0_44_CI
#    action_dist_distance_0_45_CI
#    action_dist_distance_0_46_CI
#    action_dist_distance_0_47_CI
#    action_dist_distance_0_48_CI
#    action_dist_distance_0_49_CI
#    action_dist_distance_0_50_CI
#    action_dist_distance_0_51_CI
#    action_dist_distance_0_52_CI
#    action_dist_distance_0_53_CI
#    action_dist_distance_0_54_CI
#    action_dist_distance_0_55_CI
#    action_dist_distance_0_56_CI
#    action_dist_distance_0_57_CI
#    action_dist_distance_0_58_CI
#    action_dist_distance_0_59_CI
#    action_dist_distance_0_60_CI
#    action_dist_distance_0_61_CI
#    action_dist_distance_0_62_CI
#    action_dist_distance_0_63_CI
#    action_dist_distance_0_64_CI
#    action_dist_distance_0_65_CI
#    action_dist_distance_0_66_CI
#    action_dist_distance_0_67_CI
#    action_dist_distance_0_68_CI
#    action_dist_distance_0_69_CI
#    action_dist_distance_0_70_CI
#    action_dist_distance_0_71_CI
#    action_dist_distance_0_72_CI
#    action_dist_distance_0_73_CI
#    action_dist_distance_0_74_CI
#    action_dist_distance_0_75_CI
#    action_dist_distance_0_76_CI
#    action_dist_distance_0_77_CI
#    action_dist_distance_0_78_CI
#    action_dist_distance_0_79_CI
#    action_dist_distance_0_80_CI
#    action_dist_distance_0_81_CI
#    action_dist_distance_0_82_CI
#    action_dist_distance_0_83_CI
#    action_dist_distance_0_84_CI
#    action_dist_distance_0_85_CI
#    action_dist_distance_0_86_CI
#    action_dist_distance_0_87_CI
#    action_dist_distance_0_88_CI
#    action_dist_distance_0_89_CI
#    action_dist_distance_0_90_CI
#    action_dist_distance_0_91_CI
#    action_dist_distance_0_92_CI
#    action_dist_distance_0_93_CI
#    action_dist_distance_0_94_CI
#    action_dist_distance_0_95_CI
#    action_dist_distance_0_96_CI
#    action_dist_distance_0_97_CI
#    action_dist_distance_0_98_CI
#    action_dist_distance_0_99_CI
#    action_dist_distance_1_0_CI
#    action_dist_distance_1_1_CI
#    action_dist_distance_1_2_CI
#    action_dist_distance_1_3_CI
#    action_dist_distance_1_4_CI
#    action_dist_distance_1_5_CI
#    action_dist_distance_1_6_CI
#    action_dist_distance_1_7_CI
#    action_dist_distance_1_8_CI
#    action_dist_distance_1_9_CI
#    action_dist_distance_1_10_CI
#    action_dist_distance_1_11_CI
#    action_dist_distance_1_12_CI
#    action_dist_distance_1_13_CI
#    action_dist_distance_1_14_CI
#    action_dist_distance_1_15_CI
#    action_dist_distance_1_16_CI
#    action_dist_distance_1_17_CI
#    action_dist_distance_1_18_CI
#    action_dist_distance_1_19_CI
#    action_dist_distance_1_20_CI
#    action_dist_distance_1_21_CI
#    action_dist_distance_1_22_CI
#    action_dist_distance_1_23_CI
#    action_dist_distance_1_24_CI
#    action_dist_distance_1_25_CI
#    action_dist_distance_1_26_CI
#    action_dist_distance_1_27_CI
#    action_dist_distance_1_28_CI
#    action_dist_distance_1_29_CI
#    action_dist_distance_1_30_CI
#    action_dist_distance_1_31_CI
#    action_dist_distance_1_32_CI
#    action_dist_distance_1_33_CI
#    action_dist_distance_1_34_CI
#    action_dist_distance_1_35_CI
#    action_dist_distance_1_36_CI
#    action_dist_distance_1_37_CI
#    action_dist_distance_1_38_CI
#    action_dist_distance_1_39_CI
#    action_dist_distance_1_40_CI
#    action_dist_distance_1_41_CI
#    action_dist_distance_1_42_CI
#    action_dist_distance_1_43_CI
#    action_dist_distance_1_44_CI
#    action_dist_distance_1_45_CI
#    action_dist_distance_1_46_CI
#    action_dist_distance_1_47_CI
#    action_dist_distance_1_48_CI
#    action_dist_distance_1_49_CI
#    action_dist_distance_1_50_CI
#    action_dist_distance_1_51_CI
#    action_dist_distance_1_52_CI
#    action_dist_distance_1_53_CI
#    action_dist_distance_1_54_CI
#    action_dist_distance_1_55_CI
#    action_dist_distance_1_56_CI
#    action_dist_distance_1_57_CI
#    action_dist_distance_1_58_CI
#    action_dist_distance_1_59_CI
#    action_dist_distance_1_60_CI
#    action_dist_distance_1_61_CI
#    action_dist_distance_1_62_CI
#    action_dist_distance_1_63_CI
#    action_dist_distance_1_64_CI
#    action_dist_distance_1_65_CI
#    action_dist_distance_1_66_CI
#    action_dist_distance_1_67_CI
#    action_dist_distance_1_68_CI
#    action_dist_distance_1_69_CI
#    action_dist_distance_1_70_CI
#    action_dist_distance_1_71_CI
#    action_dist_distance_1_72_CI
#    action_dist_distance_1_73_CI
#    action_dist_distance_1_74_CI
#    action_dist_distance_1_75_CI
#    action_dist_distance_1_76_CI
#    action_dist_distance_1_77_CI
#    action_dist_distance_1_78_CI
#    action_dist_distance_1_79_CI
#    action_dist_distance_1_80_CI
#    action_dist_distance_1_81_CI
#    action_dist_distance_1_82_CI
#    action_dist_distance_1_83_CI
#    action_dist_distance_1_84_CI
#    action_dist_distance_1_85_CI
#    action_dist_distance_1_86_CI
#    action_dist_distance_1_87_CI
#    action_dist_distance_1_88_CI
#    action_dist_distance_1_89_CI
#    action_dist_distance_1_90_CI
#    action_dist_distance_1_91_CI
#    action_dist_distance_1_92_CI
#    action_dist_distance_1_93_CI
#    action_dist_distance_1_94_CI
#    action_dist_distance_1_95_CI
#    action_dist_distance_1_96_CI
#    action_dist_distance_1_97_CI
#    action_dist_distance_1_98_CI
#    action_dist_distance_1_99_CI
#    bayes_accuracy_0_CI
#    bayes_accuracy_1_CI
#    bayes_accuracy_0_0_CI
#    bayes_accuracy_0_1_CI
#    bayes_accuracy_0_2_CI
#    bayes_accuracy_0_3_CI
#    bayes_accuracy_0_4_CI
#    bayes_accuracy_0_5_CI
#    bayes_accuracy_0_6_CI
#    bayes_accuracy_0_7_CI
#    bayes_accuracy_0_8_CI
#    bayes_accuracy_0_9_CI
#    bayes_accuracy_0_10_CI
#    bayes_accuracy_0_11_CI
#    bayes_accuracy_0_12_CI
#    bayes_accuracy_0_13_CI
#    bayes_accuracy_0_14_CI
#    bayes_accuracy_0_15_CI
#    bayes_accuracy_0_16_CI
#    bayes_accuracy_0_17_CI
#    bayes_accuracy_0_18_CI
#    bayes_accuracy_0_19_CI
#    bayes_accuracy_0_20_CI
#    bayes_accuracy_0_21_CI
#    bayes_accuracy_0_22_CI
#    bayes_accuracy_0_23_CI
#    bayes_accuracy_0_24_CI
#    bayes_accuracy_0_25_CI
#    bayes_accuracy_0_26_CI
#    bayes_accuracy_0_27_CI
#    bayes_accuracy_0_28_CI
#    bayes_accuracy_0_29_CI
#    bayes_accuracy_0_30_CI
#    bayes_accuracy_0_31_CI
#    bayes_accuracy_0_32_CI
#    bayes_accuracy_0_33_CI
#    bayes_accuracy_0_34_CI
#    bayes_accuracy_0_35_CI
#    bayes_accuracy_0_36_CI
#    bayes_accuracy_0_37_CI
#    bayes_accuracy_0_38_CI
#    bayes_accuracy_0_39_CI
#    bayes_accuracy_0_40_CI
#    bayes_accuracy_0_41_CI
#    bayes_accuracy_0_42_CI
#    bayes_accuracy_0_43_CI
#    bayes_accuracy_0_44_CI
#    bayes_accuracy_0_45_CI
#    bayes_accuracy_0_46_CI
#    bayes_accuracy_0_47_CI
#    bayes_accuracy_0_48_CI
#    bayes_accuracy_0_49_CI
#    bayes_accuracy_0_50_CI
#    bayes_accuracy_0_51_CI
#    bayes_accuracy_0_52_CI
#    bayes_accuracy_0_53_CI
#    bayes_accuracy_0_54_CI
#    bayes_accuracy_0_55_CI
#    bayes_accuracy_0_56_CI
#    bayes_accuracy_0_57_CI
#    bayes_accuracy_0_58_CI
#    bayes_accuracy_0_59_CI
#    bayes_accuracy_0_60_CI
#    bayes_accuracy_0_61_CI
#    bayes_accuracy_0_62_CI
#    bayes_accuracy_0_63_CI
#    bayes_accuracy_0_64_CI
#    bayes_accuracy_0_65_CI
#    bayes_accuracy_0_66_CI
#    bayes_accuracy_0_67_CI
#    bayes_accuracy_0_68_CI
#    bayes_accuracy_0_69_CI
#    bayes_accuracy_0_70_CI
#    bayes_accuracy_0_71_CI
#    bayes_accuracy_0_72_CI
#    bayes_accuracy_0_73_CI
#    bayes_accuracy_0_74_CI
#    bayes_accuracy_0_75_CI
#    bayes_accuracy_0_76_CI
#    bayes_accuracy_0_77_CI
#    bayes_accuracy_0_78_CI
#    bayes_accuracy_0_79_CI
#    bayes_accuracy_0_80_CI
#    bayes_accuracy_0_81_CI
#    bayes_accuracy_0_82_CI
#    bayes_accuracy_0_83_CI
#    bayes_accuracy_0_84_CI
#    bayes_accuracy_0_85_CI
#    bayes_accuracy_0_86_CI
#    bayes_accuracy_0_87_CI
#    bayes_accuracy_0_88_CI
#    bayes_accuracy_0_89_CI
#    bayes_accuracy_0_90_CI
#    bayes_accuracy_0_91_CI
#    bayes_accuracy_0_92_CI
#    bayes_accuracy_0_93_CI
#    bayes_accuracy_0_94_CI
#    bayes_accuracy_0_95_CI
#    bayes_accuracy_0_96_CI
#    bayes_accuracy_0_97_CI
#    bayes_accuracy_0_98_CI
#    bayes_accuracy_0_99_CI
#    bayes_accuracy_1_0_CI
#    bayes_accuracy_1_1_CI
#    bayes_accuracy_1_2_CI
#    bayes_accuracy_1_3_CI
#    bayes_accuracy_1_4_CI
#    bayes_accuracy_1_5_CI
#    bayes_accuracy_1_6_CI
#    bayes_accuracy_1_7_CI
#    bayes_accuracy_1_8_CI
#    bayes_accuracy_1_9_CI
#    bayes_accuracy_1_10_CI
#    bayes_accuracy_1_11_CI
#    bayes_accuracy_1_12_CI
#    bayes_accuracy_1_13_CI
#    bayes_accuracy_1_14_CI
#    bayes_accuracy_1_15_CI
#    bayes_accuracy_1_16_CI
#    bayes_accuracy_1_17_CI
#    bayes_accuracy_1_18_CI
#    bayes_accuracy_1_19_CI
#    bayes_accuracy_1_20_CI
#    bayes_accuracy_1_21_CI
#    bayes_accuracy_1_22_CI
#    bayes_accuracy_1_23_CI
#    bayes_accuracy_1_24_CI
#    bayes_accuracy_1_25_CI
#    bayes_accuracy_1_26_CI
#    bayes_accuracy_1_27_CI
#    bayes_accuracy_1_28_CI
#    bayes_accuracy_1_29_CI
#    bayes_accuracy_1_30_CI
#    bayes_accuracy_1_31_CI
#    bayes_accuracy_1_32_CI
#    bayes_accuracy_1_33_CI
#    bayes_accuracy_1_34_CI
#    bayes_accuracy_1_35_CI
#    bayes_accuracy_1_36_CI
#    bayes_accuracy_1_37_CI
#    bayes_accuracy_1_38_CI
#    bayes_accuracy_1_39_CI
#    bayes_accuracy_1_40_CI
#    bayes_accuracy_1_41_CI
#    bayes_accuracy_1_42_CI
#    bayes_accuracy_1_43_CI
#    bayes_accuracy_1_44_CI
#    bayes_accuracy_1_45_CI
#    bayes_accuracy_1_46_CI
#    bayes_accuracy_1_47_CI
#    bayes_accuracy_1_48_CI
#    bayes_accuracy_1_49_CI
#    bayes_accuracy_1_50_CI
#    bayes_accuracy_1_51_CI
#    bayes_accuracy_1_52_CI
#    bayes_accuracy_1_53_CI
#    bayes_accuracy_1_54_CI
#    bayes_accuracy_1_55_CI
#    bayes_accuracy_1_56_CI
#    bayes_accuracy_1_57_CI
#    bayes_accuracy_1_58_CI
#    bayes_accuracy_1_59_CI
#    bayes_accuracy_1_60_CI
#    bayes_accuracy_1_61_CI
#    bayes_accuracy_1_62_CI
#    bayes_accuracy_1_63_CI
#    bayes_accuracy_1_64_CI
#    bayes_accuracy_1_65_CI
#    bayes_accuracy_1_66_CI
#    bayes_accuracy_1_67_CI
#    bayes_accuracy_1_68_CI
#    bayes_accuracy_1_69_CI
#    bayes_accuracy_1_70_CI
#    bayes_accuracy_1_71_CI
#    bayes_accuracy_1_72_CI
#    bayes_accuracy_1_73_CI
#    bayes_accuracy_1_74_CI
#    bayes_accuracy_1_75_CI
#    bayes_accuracy_1_76_CI
#    bayes_accuracy_1_77_CI
#    bayes_accuracy_1_78_CI
#    bayes_accuracy_1_79_CI
#    bayes_accuracy_1_80_CI
#    bayes_accuracy_1_81_CI
#    bayes_accuracy_1_82_CI
#    bayes_accuracy_1_83_CI
#    bayes_accuracy_1_84_CI
#    bayes_accuracy_1_85_CI
#    bayes_accuracy_1_86_CI
#    bayes_accuracy_1_87_CI
#    bayes_accuracy_1_88_CI
#    bayes_accuracy_1_89_CI
#    bayes_accuracy_1_90_CI
#    bayes_accuracy_1_91_CI
#    bayes_accuracy_1_92_CI
#    bayes_accuracy_1_93_CI
#    bayes_accuracy_1_94_CI
#    bayes_accuracy_1_95_CI
#    bayes_accuracy_1_96_CI
#    bayes_accuracy_1_97_CI
#    bayes_accuracy_1_98_CI
#    bayes_accuracy_1_99_CI
#    prop_LOSS
#    prop_DRAW
#    prop_WIN
#    prop_NA

# %% [markdown]
# ## Combine data

# %%
# First need to update exp_ids of one dataframe so there are no duplicate exp_ids
df1 = baposgmcp_df
df2 = policy_br_df

df1_max_exp_id = df1["exp_id"].max()
if df2["exp_id"].min() <= df1_max_exp_id:
    df2["exp_id"] += df1_max_exp_id+1

combined_df = pd.concat([df1, df2]).reset_index(drop = True)


def add_alg_id(row):
    pi_id = row["policy_id"]
    if pi_id.startswith("klr"):
        return "fixed"
    tokens = pi_id.split("_")
    alg_id = "_".join([
        t for t in tokens 
        if all(
            s not in t for s in [
                "actionselection", "numsims", "truncated", "greedy", "softmax", "uniform", "piklr", "i0", "i1"
            ]
        )
    ])
    return alg_id


def add_meta_pi(row):
    pi_id = row["policy_id"]
    for meta_pi in ["greedy", "softmax", "uniform"]:
        if meta_pi in pi_id:
            return meta_pi
    return "NA"


combined_df["alg_id"] = combined_df.apply(add_alg_id, axis=1)
combined_df["meta_pi"] = combined_df.apply(add_meta_pi, axis=1)

policy_ids = combined_df["policy_id"].unique().tolist()
policy_ids.sort()
print("Policies")
print("--------")
for pi_id in policy_ids:
    print("  ", pi_id)
    
alg_ids = combined_df["alg_id"].unique().tolist()
alg_ids.sort()
print("\nAlg IDs")
print("-------")
for n in alg_ids:
    print("  ", n)
    
print("\nMeta Pis:")
print("---------")
print(combined_df["meta_pi"].unique().tolist())

print("\nColumns")
print("-------")
for c in baposgmcp_df.columns:
    print("  ", c)
# Out:
# Policies
# --------
#    POMetaRollout_greedy_i0_numsims1000_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i0_numsims100_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i0_numsims10_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i0_numsims500_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i0_numsims50_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i1_numsims1000_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i1_numsims100_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i1_numsims10_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i1_numsims500_actionselectionpucb_truncatedTrue
#    POMetaRollout_greedy_i1_numsims50_actionselectionpucb_truncatedTrue
#    POMeta_greedy_i0_numsims10
#    POMeta_greedy_i0_numsims100
#    POMeta_greedy_i0_numsims1000
#    POMeta_greedy_i0_numsims50
#    POMeta_greedy_i0_numsims500
#    POMeta_greedy_i1_numsims10
#    POMeta_greedy_i1_numsims100
#    POMeta_greedy_i1_numsims1000
#    POMeta_greedy_i1_numsims50
#    POMeta_greedy_i1_numsims500
#    baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp-random_i0_numsims1000_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i0_numsims100_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i0_numsims10_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i0_numsims500_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i0_numsims50_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i1_numsims1000_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i1_numsims100_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i1_numsims10_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i1_numsims500_actionselectionpucb_truncatedFalse
#    baposgmcp-random_i1_numsims50_actionselectionpucb_truncatedFalse
#    baposgmcp_greedy_i0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i1_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i1_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i1_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i1_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_greedy_i1_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i1_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i1_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i1_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i1_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_softmax_i1_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i0_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i0_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i0_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i0_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i0_numsims50_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i1_numsims1000_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i1_numsims100_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i1_numsims10_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i1_numsims500_actionselectionpucb_truncatedTrue
#    baposgmcp_uniform_i1_numsims50_actionselectionpucb_truncatedTrue
#    full-knowledge-br_i0
#    full-knowledge-br_i1
#    klr_k0_seed0_i0-v0
#    klr_k0_seed0_i1-v0
#    klr_k1_seed0_i0-v0
#    klr_k1_seed0_i1-v0
#    klr_k2_seed0_i0-v0
#    klr_k2_seed0_i1-v0
#    klr_k3_seed0_i0-v0
#    klr_k3_seed0_i1-v0
#    klr_k4_seed0_i0-v0
#    klr_k4_seed0_i1-v0
#    metabaseline_greedy_i0
#    metabaseline_greedy_i1
#
# Alg IDs
# -------
#    POMeta
#    POMetaRollout
#    baposgmcp
#    baposgmcp-fixed
#    baposgmcp-random
#    fixed
#    full-knowledge-br
#    metabaseline
#
# Meta Pis:
# ---------
# ['greedy', 'NA', 'softmax', 'uniform']
#
# Columns
# -------
#    policy_id
#    coplayer_policy_id
#    exp_id
#    exp_seed
#    agent_id
#    env_id
#    time_limit
#    episode_step_limit
#    discount
#    c_init
#    c_base
#    truncated
#    action_selection
#    dirichlet_alpha
#    root_exploration_fraction
#    known_bounds
#    extra_particles_prop
#    step_limit
#    epsilon
#    other_policy_dist
#    meta_policy_dict
#    num_sims
#    num_episodes
#    fixed_policy_id
#    num_WIN
#    num_LOSS
#    num_DRAW
#    num_NA
#    search_time_mean
#    search_time_std
#    search_time_min
#    search_time_max
#    update_time_mean
#    update_time_std
#    update_time_min
#    update_time_max
#    reinvigoration_time_mean
#    reinvigoration_time_std
#    reinvigoration_time_min
#    reinvigoration_time_max
#    evaluation_time_mean
#    evaluation_time_std
#    evaluation_time_min
#    evaluation_time_max
#    policy_calls_mean
#    policy_calls_std
#    policy_calls_min
#    policy_calls_max
#    inference_time_mean
#    inference_time_std
#    inference_time_min
#    inference_time_max
#    search_depth_mean
#    search_depth_std
#    search_depth_min
#    search_depth_max
#    min_value_mean
#    min_value_std
#    min_value_min
#    min_value_max
#    max_value_mean
#    max_value_std
#    max_value_min
#    max_value_max
#    episode_return_mean
#    episode_return_std
#    episode_return_min
#    episode_return_max
#    episode_discounted_return_mean
#    episode_discounted_return_std
#    episode_discounted_return_min
#    episode_discounted_return_max
#    episode_steps_mean
#    episode_steps_std
#    episode_steps_min
#    episode_steps_max
#    episode_time_mean
#    episode_time_std
#    episode_time_min
#    episode_time_max
#    action_dist_distance_0_mean
#    action_dist_distance_0_std
#    action_dist_distance_0_n
#    action_dist_distance_1_mean
#    action_dist_distance_1_std
#    action_dist_distance_1_n
#    action_dist_distance_0_0_mean
#    action_dist_distance_0_0_std
#    action_dist_distance_0_0_n
#    action_dist_distance_0_1_mean
#    action_dist_distance_0_1_std
#    action_dist_distance_0_1_n
#    action_dist_distance_0_2_mean
#    action_dist_distance_0_2_std
#    action_dist_distance_0_2_n
#    action_dist_distance_0_3_mean
#    action_dist_distance_0_3_std
#    action_dist_distance_0_3_n
#    action_dist_distance_0_4_mean
#    action_dist_distance_0_4_std
#    action_dist_distance_0_4_n
#    action_dist_distance_0_5_mean
#    action_dist_distance_0_5_std
#    action_dist_distance_0_5_n
#    action_dist_distance_0_6_mean
#    action_dist_distance_0_6_std
#    action_dist_distance_0_6_n
#    action_dist_distance_0_7_mean
#    action_dist_distance_0_7_std
#    action_dist_distance_0_7_n
#    action_dist_distance_0_8_mean
#    action_dist_distance_0_8_std
#    action_dist_distance_0_8_n
#    action_dist_distance_0_9_mean
#    action_dist_distance_0_9_std
#    action_dist_distance_0_9_n
#    action_dist_distance_0_10_mean
#    action_dist_distance_0_10_std
#    action_dist_distance_0_10_n
#    action_dist_distance_0_11_mean
#    action_dist_distance_0_11_std
#    action_dist_distance_0_11_n
#    action_dist_distance_0_12_mean
#    action_dist_distance_0_12_std
#    action_dist_distance_0_12_n
#    action_dist_distance_0_13_mean
#    action_dist_distance_0_13_std
#    action_dist_distance_0_13_n
#    action_dist_distance_0_14_mean
#    action_dist_distance_0_14_std
#    action_dist_distance_0_14_n
#    action_dist_distance_0_15_mean
#    action_dist_distance_0_15_std
#    action_dist_distance_0_15_n
#    action_dist_distance_0_16_mean
#    action_dist_distance_0_16_std
#    action_dist_distance_0_16_n
#    action_dist_distance_0_17_mean
#    action_dist_distance_0_17_std
#    action_dist_distance_0_17_n
#    action_dist_distance_0_18_mean
#    action_dist_distance_0_18_std
#    action_dist_distance_0_18_n
#    action_dist_distance_0_19_mean
#    action_dist_distance_0_19_std
#    action_dist_distance_0_19_n
#    action_dist_distance_0_20_mean
#    action_dist_distance_0_20_std
#    action_dist_distance_0_20_n
#    action_dist_distance_0_21_mean
#    action_dist_distance_0_21_std
#    action_dist_distance_0_21_n
#    action_dist_distance_0_22_mean
#    action_dist_distance_0_22_std
#    action_dist_distance_0_22_n
#    action_dist_distance_0_23_mean
#    action_dist_distance_0_23_std
#    action_dist_distance_0_23_n
#    action_dist_distance_0_24_mean
#    action_dist_distance_0_24_std
#    action_dist_distance_0_24_n
#    action_dist_distance_0_25_mean
#    action_dist_distance_0_25_std
#    action_dist_distance_0_25_n
#    action_dist_distance_0_26_mean
#    action_dist_distance_0_26_std
#    action_dist_distance_0_26_n
#    action_dist_distance_0_27_mean
#    action_dist_distance_0_27_std
#    action_dist_distance_0_27_n
#    action_dist_distance_0_28_mean
#    action_dist_distance_0_28_std
#    action_dist_distance_0_28_n
#    action_dist_distance_0_29_mean
#    action_dist_distance_0_29_std
#    action_dist_distance_0_29_n
#    action_dist_distance_0_30_mean
#    action_dist_distance_0_30_std
#    action_dist_distance_0_30_n
#    action_dist_distance_0_31_mean
#    action_dist_distance_0_31_std
#    action_dist_distance_0_31_n
#    action_dist_distance_0_32_mean
#    action_dist_distance_0_32_std
#    action_dist_distance_0_32_n
#    action_dist_distance_0_33_mean
#    action_dist_distance_0_33_std
#    action_dist_distance_0_33_n
#    action_dist_distance_0_34_mean
#    action_dist_distance_0_34_std
#    action_dist_distance_0_34_n
#    action_dist_distance_0_35_mean
#    action_dist_distance_0_35_std
#    action_dist_distance_0_35_n
#    action_dist_distance_0_36_mean
#    action_dist_distance_0_36_std
#    action_dist_distance_0_36_n
#    action_dist_distance_0_37_mean
#    action_dist_distance_0_37_std
#    action_dist_distance_0_37_n
#    action_dist_distance_0_38_mean
#    action_dist_distance_0_38_std
#    action_dist_distance_0_38_n
#    action_dist_distance_0_39_mean
#    action_dist_distance_0_39_std
#    action_dist_distance_0_39_n
#    action_dist_distance_0_40_mean
#    action_dist_distance_0_40_std
#    action_dist_distance_0_40_n
#    action_dist_distance_0_41_mean
#    action_dist_distance_0_41_std
#    action_dist_distance_0_41_n
#    action_dist_distance_0_42_mean
#    action_dist_distance_0_42_std
#    action_dist_distance_0_42_n
#    action_dist_distance_0_43_mean
#    action_dist_distance_0_43_std
#    action_dist_distance_0_43_n
#    action_dist_distance_0_44_mean
#    action_dist_distance_0_44_std
#    action_dist_distance_0_44_n
#    action_dist_distance_0_45_mean
#    action_dist_distance_0_45_std
#    action_dist_distance_0_45_n
#    action_dist_distance_0_46_mean
#    action_dist_distance_0_46_std
#    action_dist_distance_0_46_n
#    action_dist_distance_0_47_mean
#    action_dist_distance_0_47_std
#    action_dist_distance_0_47_n
#    action_dist_distance_0_48_mean
#    action_dist_distance_0_48_std
#    action_dist_distance_0_48_n
#    action_dist_distance_0_49_mean
#    action_dist_distance_0_49_std
#    action_dist_distance_0_49_n
#    action_dist_distance_0_50_mean
#    action_dist_distance_0_50_std
#    action_dist_distance_0_50_n
#    action_dist_distance_0_51_mean
#    action_dist_distance_0_51_std
#    action_dist_distance_0_51_n
#    action_dist_distance_0_52_mean
#    action_dist_distance_0_52_std
#    action_dist_distance_0_52_n
#    action_dist_distance_0_53_mean
#    action_dist_distance_0_53_std
#    action_dist_distance_0_53_n
#    action_dist_distance_0_54_mean
#    action_dist_distance_0_54_std
#    action_dist_distance_0_54_n
#    action_dist_distance_0_55_mean
#    action_dist_distance_0_55_std
#    action_dist_distance_0_55_n
#    action_dist_distance_0_56_mean
#    action_dist_distance_0_56_std
#    action_dist_distance_0_56_n
#    action_dist_distance_0_57_mean
#    action_dist_distance_0_57_std
#    action_dist_distance_0_57_n
#    action_dist_distance_0_58_mean
#    action_dist_distance_0_58_std
#    action_dist_distance_0_58_n
#    action_dist_distance_0_59_mean
#    action_dist_distance_0_59_std
#    action_dist_distance_0_59_n
#    action_dist_distance_0_60_mean
#    action_dist_distance_0_60_std
#    action_dist_distance_0_60_n
#    action_dist_distance_0_61_mean
#    action_dist_distance_0_61_std
#    action_dist_distance_0_61_n
#    action_dist_distance_0_62_mean
#    action_dist_distance_0_62_std
#    action_dist_distance_0_62_n
#    action_dist_distance_0_63_mean
#    action_dist_distance_0_63_std
#    action_dist_distance_0_63_n
#    action_dist_distance_0_64_mean
#    action_dist_distance_0_64_std
#    action_dist_distance_0_64_n
#    action_dist_distance_0_65_mean
#    action_dist_distance_0_65_std
#    action_dist_distance_0_65_n
#    action_dist_distance_0_66_mean
#    action_dist_distance_0_66_std
#    action_dist_distance_0_66_n
#    action_dist_distance_0_67_mean
#    action_dist_distance_0_67_std
#    action_dist_distance_0_67_n
#    action_dist_distance_0_68_mean
#    action_dist_distance_0_68_std
#    action_dist_distance_0_68_n
#    action_dist_distance_0_69_mean
#    action_dist_distance_0_69_std
#    action_dist_distance_0_69_n
#    action_dist_distance_0_70_mean
#    action_dist_distance_0_70_std
#    action_dist_distance_0_70_n
#    action_dist_distance_0_71_mean
#    action_dist_distance_0_71_std
#    action_dist_distance_0_71_n
#    action_dist_distance_0_72_mean
#    action_dist_distance_0_72_std
#    action_dist_distance_0_72_n
#    action_dist_distance_0_73_mean
#    action_dist_distance_0_73_std
#    action_dist_distance_0_73_n
#    action_dist_distance_0_74_mean
#    action_dist_distance_0_74_std
#    action_dist_distance_0_74_n
#    action_dist_distance_0_75_mean
#    action_dist_distance_0_75_std
#    action_dist_distance_0_75_n
#    action_dist_distance_0_76_mean
#    action_dist_distance_0_76_std
#    action_dist_distance_0_76_n
#    action_dist_distance_0_77_mean
#    action_dist_distance_0_77_std
#    action_dist_distance_0_77_n
#    action_dist_distance_0_78_mean
#    action_dist_distance_0_78_std
#    action_dist_distance_0_78_n
#    action_dist_distance_0_79_mean
#    action_dist_distance_0_79_std
#    action_dist_distance_0_79_n
#    action_dist_distance_0_80_mean
#    action_dist_distance_0_80_std
#    action_dist_distance_0_80_n
#    action_dist_distance_0_81_mean
#    action_dist_distance_0_81_std
#    action_dist_distance_0_81_n
#    action_dist_distance_0_82_mean
#    action_dist_distance_0_82_std
#    action_dist_distance_0_82_n
#    action_dist_distance_0_83_mean
#    action_dist_distance_0_83_std
#    action_dist_distance_0_83_n
#    action_dist_distance_0_84_mean
#    action_dist_distance_0_84_std
#    action_dist_distance_0_84_n
#    action_dist_distance_0_85_mean
#    action_dist_distance_0_85_std
#    action_dist_distance_0_85_n
#    action_dist_distance_0_86_mean
#    action_dist_distance_0_86_std
#    action_dist_distance_0_86_n
#    action_dist_distance_0_87_mean
#    action_dist_distance_0_87_std
#    action_dist_distance_0_87_n
#    action_dist_distance_0_88_mean
#    action_dist_distance_0_88_std
#    action_dist_distance_0_88_n
#    action_dist_distance_0_89_mean
#    action_dist_distance_0_89_std
#    action_dist_distance_0_89_n
#    action_dist_distance_0_90_mean
#    action_dist_distance_0_90_std
#    action_dist_distance_0_90_n
#    action_dist_distance_0_91_mean
#    action_dist_distance_0_91_std
#    action_dist_distance_0_91_n
#    action_dist_distance_0_92_mean
#    action_dist_distance_0_92_std
#    action_dist_distance_0_92_n
#    action_dist_distance_0_93_mean
#    action_dist_distance_0_93_std
#    action_dist_distance_0_93_n
#    action_dist_distance_0_94_mean
#    action_dist_distance_0_94_std
#    action_dist_distance_0_94_n
#    action_dist_distance_0_95_mean
#    action_dist_distance_0_95_std
#    action_dist_distance_0_95_n
#    action_dist_distance_0_96_mean
#    action_dist_distance_0_96_std
#    action_dist_distance_0_96_n
#    action_dist_distance_0_97_mean
#    action_dist_distance_0_97_std
#    action_dist_distance_0_97_n
#    action_dist_distance_0_98_mean
#    action_dist_distance_0_98_std
#    action_dist_distance_0_98_n
#    action_dist_distance_0_99_mean
#    action_dist_distance_0_99_std
#    action_dist_distance_0_99_n
#    action_dist_distance_1_0_mean
#    action_dist_distance_1_0_std
#    action_dist_distance_1_0_n
#    action_dist_distance_1_1_mean
#    action_dist_distance_1_1_std
#    action_dist_distance_1_1_n
#    action_dist_distance_1_2_mean
#    action_dist_distance_1_2_std
#    action_dist_distance_1_2_n
#    action_dist_distance_1_3_mean
#    action_dist_distance_1_3_std
#    action_dist_distance_1_3_n
#    action_dist_distance_1_4_mean
#    action_dist_distance_1_4_std
#    action_dist_distance_1_4_n
#    action_dist_distance_1_5_mean
#    action_dist_distance_1_5_std
#    action_dist_distance_1_5_n
#    action_dist_distance_1_6_mean
#    action_dist_distance_1_6_std
#    action_dist_distance_1_6_n
#    action_dist_distance_1_7_mean
#    action_dist_distance_1_7_std
#    action_dist_distance_1_7_n
#    action_dist_distance_1_8_mean
#    action_dist_distance_1_8_std
#    action_dist_distance_1_8_n
#    action_dist_distance_1_9_mean
#    action_dist_distance_1_9_std
#    action_dist_distance_1_9_n
#    action_dist_distance_1_10_mean
#    action_dist_distance_1_10_std
#    action_dist_distance_1_10_n
#    action_dist_distance_1_11_mean
#    action_dist_distance_1_11_std
#    action_dist_distance_1_11_n
#    action_dist_distance_1_12_mean
#    action_dist_distance_1_12_std
#    action_dist_distance_1_12_n
#    action_dist_distance_1_13_mean
#    action_dist_distance_1_13_std
#    action_dist_distance_1_13_n
#    action_dist_distance_1_14_mean
#    action_dist_distance_1_14_std
#    action_dist_distance_1_14_n
#    action_dist_distance_1_15_mean
#    action_dist_distance_1_15_std
#    action_dist_distance_1_15_n
#    action_dist_distance_1_16_mean
#    action_dist_distance_1_16_std
#    action_dist_distance_1_16_n
#    action_dist_distance_1_17_mean
#    action_dist_distance_1_17_std
#    action_dist_distance_1_17_n
#    action_dist_distance_1_18_mean
#    action_dist_distance_1_18_std
#    action_dist_distance_1_18_n
#    action_dist_distance_1_19_mean
#    action_dist_distance_1_19_std
#    action_dist_distance_1_19_n
#    action_dist_distance_1_20_mean
#    action_dist_distance_1_20_std
#    action_dist_distance_1_20_n
#    action_dist_distance_1_21_mean
#    action_dist_distance_1_21_std
#    action_dist_distance_1_21_n
#    action_dist_distance_1_22_mean
#    action_dist_distance_1_22_std
#    action_dist_distance_1_22_n
#    action_dist_distance_1_23_mean
#    action_dist_distance_1_23_std
#    action_dist_distance_1_23_n
#    action_dist_distance_1_24_mean
#    action_dist_distance_1_24_std
#    action_dist_distance_1_24_n
#    action_dist_distance_1_25_mean
#    action_dist_distance_1_25_std
#    action_dist_distance_1_25_n
#    action_dist_distance_1_26_mean
#    action_dist_distance_1_26_std
#    action_dist_distance_1_26_n
#    action_dist_distance_1_27_mean
#    action_dist_distance_1_27_std
#    action_dist_distance_1_27_n
#    action_dist_distance_1_28_mean
#    action_dist_distance_1_28_std
#    action_dist_distance_1_28_n
#    action_dist_distance_1_29_mean
#    action_dist_distance_1_29_std
#    action_dist_distance_1_29_n
#    action_dist_distance_1_30_mean
#    action_dist_distance_1_30_std
#    action_dist_distance_1_30_n
#    action_dist_distance_1_31_mean
#    action_dist_distance_1_31_std
#    action_dist_distance_1_31_n
#    action_dist_distance_1_32_mean
#    action_dist_distance_1_32_std
#    action_dist_distance_1_32_n
#    action_dist_distance_1_33_mean
#    action_dist_distance_1_33_std
#    action_dist_distance_1_33_n
#    action_dist_distance_1_34_mean
#    action_dist_distance_1_34_std
#    action_dist_distance_1_34_n
#    action_dist_distance_1_35_mean
#    action_dist_distance_1_35_std
#    action_dist_distance_1_35_n
#    action_dist_distance_1_36_mean
#    action_dist_distance_1_36_std
#    action_dist_distance_1_36_n
#    action_dist_distance_1_37_mean
#    action_dist_distance_1_37_std
#    action_dist_distance_1_37_n
#    action_dist_distance_1_38_mean
#    action_dist_distance_1_38_std
#    action_dist_distance_1_38_n
#    action_dist_distance_1_39_mean
#    action_dist_distance_1_39_std
#    action_dist_distance_1_39_n
#    action_dist_distance_1_40_mean
#    action_dist_distance_1_40_std
#    action_dist_distance_1_40_n
#    action_dist_distance_1_41_mean
#    action_dist_distance_1_41_std
#    action_dist_distance_1_41_n
#    action_dist_distance_1_42_mean
#    action_dist_distance_1_42_std
#    action_dist_distance_1_42_n
#    action_dist_distance_1_43_mean
#    action_dist_distance_1_43_std
#    action_dist_distance_1_43_n
#    action_dist_distance_1_44_mean
#    action_dist_distance_1_44_std
#    action_dist_distance_1_44_n
#    action_dist_distance_1_45_mean
#    action_dist_distance_1_45_std
#    action_dist_distance_1_45_n
#    action_dist_distance_1_46_mean
#    action_dist_distance_1_46_std
#    action_dist_distance_1_46_n
#    action_dist_distance_1_47_mean
#    action_dist_distance_1_47_std
#    action_dist_distance_1_47_n
#    action_dist_distance_1_48_mean
#    action_dist_distance_1_48_std
#    action_dist_distance_1_48_n
#    action_dist_distance_1_49_mean
#    action_dist_distance_1_49_std
#    action_dist_distance_1_49_n
#    action_dist_distance_1_50_mean
#    action_dist_distance_1_50_std
#    action_dist_distance_1_50_n
#    action_dist_distance_1_51_mean
#    action_dist_distance_1_51_std
#    action_dist_distance_1_51_n
#    action_dist_distance_1_52_mean
#    action_dist_distance_1_52_std
#    action_dist_distance_1_52_n
#    action_dist_distance_1_53_mean
#    action_dist_distance_1_53_std
#    action_dist_distance_1_53_n
#    action_dist_distance_1_54_mean
#    action_dist_distance_1_54_std
#    action_dist_distance_1_54_n
#    action_dist_distance_1_55_mean
#    action_dist_distance_1_55_std
#    action_dist_distance_1_55_n
#    action_dist_distance_1_56_mean
#    action_dist_distance_1_56_std
#    action_dist_distance_1_56_n
#    action_dist_distance_1_57_mean
#    action_dist_distance_1_57_std
#    action_dist_distance_1_57_n
#    action_dist_distance_1_58_mean
#    action_dist_distance_1_58_std
#    action_dist_distance_1_58_n
#    action_dist_distance_1_59_mean
#    action_dist_distance_1_59_std
#    action_dist_distance_1_59_n
#    action_dist_distance_1_60_mean
#    action_dist_distance_1_60_std
#    action_dist_distance_1_60_n
#    action_dist_distance_1_61_mean
#    action_dist_distance_1_61_std
#    action_dist_distance_1_61_n
#    action_dist_distance_1_62_mean
#    action_dist_distance_1_62_std
#    action_dist_distance_1_62_n
#    action_dist_distance_1_63_mean
#    action_dist_distance_1_63_std
#    action_dist_distance_1_63_n
#    action_dist_distance_1_64_mean
#    action_dist_distance_1_64_std
#    action_dist_distance_1_64_n
#    action_dist_distance_1_65_mean
#    action_dist_distance_1_65_std
#    action_dist_distance_1_65_n
#    action_dist_distance_1_66_mean
#    action_dist_distance_1_66_std
#    action_dist_distance_1_66_n
#    action_dist_distance_1_67_mean
#    action_dist_distance_1_67_std
#    action_dist_distance_1_67_n
#    action_dist_distance_1_68_mean
#    action_dist_distance_1_68_std
#    action_dist_distance_1_68_n
#    action_dist_distance_1_69_mean
#    action_dist_distance_1_69_std
#    action_dist_distance_1_69_n
#    action_dist_distance_1_70_mean
#    action_dist_distance_1_70_std
#    action_dist_distance_1_70_n
#    action_dist_distance_1_71_mean
#    action_dist_distance_1_71_std
#    action_dist_distance_1_71_n
#    action_dist_distance_1_72_mean
#    action_dist_distance_1_72_std
#    action_dist_distance_1_72_n
#    action_dist_distance_1_73_mean
#    action_dist_distance_1_73_std
#    action_dist_distance_1_73_n
#    action_dist_distance_1_74_mean
#    action_dist_distance_1_74_std
#    action_dist_distance_1_74_n
#    action_dist_distance_1_75_mean
#    action_dist_distance_1_75_std
#    action_dist_distance_1_75_n
#    action_dist_distance_1_76_mean
#    action_dist_distance_1_76_std
#    action_dist_distance_1_76_n
#    action_dist_distance_1_77_mean
#    action_dist_distance_1_77_std
#    action_dist_distance_1_77_n
#    action_dist_distance_1_78_mean
#    action_dist_distance_1_78_std
#    action_dist_distance_1_78_n
#    action_dist_distance_1_79_mean
#    action_dist_distance_1_79_std
#    action_dist_distance_1_79_n
#    action_dist_distance_1_80_mean
#    action_dist_distance_1_80_std
#    action_dist_distance_1_80_n
#    action_dist_distance_1_81_mean
#    action_dist_distance_1_81_std
#    action_dist_distance_1_81_n
#    action_dist_distance_1_82_mean
#    action_dist_distance_1_82_std
#    action_dist_distance_1_82_n
#    action_dist_distance_1_83_mean
#    action_dist_distance_1_83_std
#    action_dist_distance_1_83_n
#    action_dist_distance_1_84_mean
#    action_dist_distance_1_84_std
#    action_dist_distance_1_84_n
#    action_dist_distance_1_85_mean
#    action_dist_distance_1_85_std
#    action_dist_distance_1_85_n
#    action_dist_distance_1_86_mean
#    action_dist_distance_1_86_std
#    action_dist_distance_1_86_n
#    action_dist_distance_1_87_mean
#    action_dist_distance_1_87_std
#    action_dist_distance_1_87_n
#    action_dist_distance_1_88_mean
#    action_dist_distance_1_88_std
#    action_dist_distance_1_88_n
#    action_dist_distance_1_89_mean
#    action_dist_distance_1_89_std
#    action_dist_distance_1_89_n
#    action_dist_distance_1_90_mean
#    action_dist_distance_1_90_std
#    action_dist_distance_1_90_n
#    action_dist_distance_1_91_mean
#    action_dist_distance_1_91_std
#    action_dist_distance_1_91_n
#    action_dist_distance_1_92_mean
#    action_dist_distance_1_92_std
#    action_dist_distance_1_92_n
#    action_dist_distance_1_93_mean
#    action_dist_distance_1_93_std
#    action_dist_distance_1_93_n
#    action_dist_distance_1_94_mean
#    action_dist_distance_1_94_std
#    action_dist_distance_1_94_n
#    action_dist_distance_1_95_mean
#    action_dist_distance_1_95_std
#    action_dist_distance_1_95_n
#    action_dist_distance_1_96_mean
#    action_dist_distance_1_96_std
#    action_dist_distance_1_96_n
#    action_dist_distance_1_97_mean
#    action_dist_distance_1_97_std
#    action_dist_distance_1_97_n
#    action_dist_distance_1_98_mean
#    action_dist_distance_1_98_std
#    action_dist_distance_1_98_n
#    action_dist_distance_1_99_mean
#    action_dist_distance_1_99_std
#    action_dist_distance_1_99_n
#    bayes_accuracy_0_mean
#    bayes_accuracy_0_std
#    bayes_accuracy_0_n
#    bayes_accuracy_1_mean
#    bayes_accuracy_1_std
#    bayes_accuracy_1_n
#    bayes_accuracy_0_0_mean
#    bayes_accuracy_0_0_std
#    bayes_accuracy_0_0_n
#    bayes_accuracy_0_1_mean
#    bayes_accuracy_0_1_std
#    bayes_accuracy_0_1_n
#    bayes_accuracy_0_2_mean
#    bayes_accuracy_0_2_std
#    bayes_accuracy_0_2_n
#    bayes_accuracy_0_3_mean
#    bayes_accuracy_0_3_std
#    bayes_accuracy_0_3_n
#    bayes_accuracy_0_4_mean
#    bayes_accuracy_0_4_std
#    bayes_accuracy_0_4_n
#    bayes_accuracy_0_5_mean
#    bayes_accuracy_0_5_std
#    bayes_accuracy_0_5_n
#    bayes_accuracy_0_6_mean
#    bayes_accuracy_0_6_std
#    bayes_accuracy_0_6_n
#    bayes_accuracy_0_7_mean
#    bayes_accuracy_0_7_std
#    bayes_accuracy_0_7_n
#    bayes_accuracy_0_8_mean
#    bayes_accuracy_0_8_std
#    bayes_accuracy_0_8_n
#    bayes_accuracy_0_9_mean
#    bayes_accuracy_0_9_std
#    bayes_accuracy_0_9_n
#    bayes_accuracy_0_10_mean
#    bayes_accuracy_0_10_std
#    bayes_accuracy_0_10_n
#    bayes_accuracy_0_11_mean
#    bayes_accuracy_0_11_std
#    bayes_accuracy_0_11_n
#    bayes_accuracy_0_12_mean
#    bayes_accuracy_0_12_std
#    bayes_accuracy_0_12_n
#    bayes_accuracy_0_13_mean
#    bayes_accuracy_0_13_std
#    bayes_accuracy_0_13_n
#    bayes_accuracy_0_14_mean
#    bayes_accuracy_0_14_std
#    bayes_accuracy_0_14_n
#    bayes_accuracy_0_15_mean
#    bayes_accuracy_0_15_std
#    bayes_accuracy_0_15_n
#    bayes_accuracy_0_16_mean
#    bayes_accuracy_0_16_std
#    bayes_accuracy_0_16_n
#    bayes_accuracy_0_17_mean
#    bayes_accuracy_0_17_std
#    bayes_accuracy_0_17_n
#    bayes_accuracy_0_18_mean
#    bayes_accuracy_0_18_std
#    bayes_accuracy_0_18_n
#    bayes_accuracy_0_19_mean
#    bayes_accuracy_0_19_std
#    bayes_accuracy_0_19_n
#    bayes_accuracy_0_20_mean
#    bayes_accuracy_0_20_std
#    bayes_accuracy_0_20_n
#    bayes_accuracy_0_21_mean
#    bayes_accuracy_0_21_std
#    bayes_accuracy_0_21_n
#    bayes_accuracy_0_22_mean
#    bayes_accuracy_0_22_std
#    bayes_accuracy_0_22_n
#    bayes_accuracy_0_23_mean
#    bayes_accuracy_0_23_std
#    bayes_accuracy_0_23_n
#    bayes_accuracy_0_24_mean
#    bayes_accuracy_0_24_std
#    bayes_accuracy_0_24_n
#    bayes_accuracy_0_25_mean
#    bayes_accuracy_0_25_std
#    bayes_accuracy_0_25_n
#    bayes_accuracy_0_26_mean
#    bayes_accuracy_0_26_std
#    bayes_accuracy_0_26_n
#    bayes_accuracy_0_27_mean
#    bayes_accuracy_0_27_std
#    bayes_accuracy_0_27_n
#    bayes_accuracy_0_28_mean
#    bayes_accuracy_0_28_std
#    bayes_accuracy_0_28_n
#    bayes_accuracy_0_29_mean
#    bayes_accuracy_0_29_std
#    bayes_accuracy_0_29_n
#    bayes_accuracy_0_30_mean
#    bayes_accuracy_0_30_std
#    bayes_accuracy_0_30_n
#    bayes_accuracy_0_31_mean
#    bayes_accuracy_0_31_std
#    bayes_accuracy_0_31_n
#    bayes_accuracy_0_32_mean
#    bayes_accuracy_0_32_std
#    bayes_accuracy_0_32_n
#    bayes_accuracy_0_33_mean
#    bayes_accuracy_0_33_std
#    bayes_accuracy_0_33_n
#    bayes_accuracy_0_34_mean
#    bayes_accuracy_0_34_std
#    bayes_accuracy_0_34_n
#    bayes_accuracy_0_35_mean
#    bayes_accuracy_0_35_std
#    bayes_accuracy_0_35_n
#    bayes_accuracy_0_36_mean
#    bayes_accuracy_0_36_std
#    bayes_accuracy_0_36_n
#    bayes_accuracy_0_37_mean
#    bayes_accuracy_0_37_std
#    bayes_accuracy_0_37_n
#    bayes_accuracy_0_38_mean
#    bayes_accuracy_0_38_std
#    bayes_accuracy_0_38_n
#    bayes_accuracy_0_39_mean
#    bayes_accuracy_0_39_std
#    bayes_accuracy_0_39_n
#    bayes_accuracy_0_40_mean
#    bayes_accuracy_0_40_std
#    bayes_accuracy_0_40_n
#    bayes_accuracy_0_41_mean
#    bayes_accuracy_0_41_std
#    bayes_accuracy_0_41_n
#    bayes_accuracy_0_42_mean
#    bayes_accuracy_0_42_std
#    bayes_accuracy_0_42_n
#    bayes_accuracy_0_43_mean
#    bayes_accuracy_0_43_std
#    bayes_accuracy_0_43_n
#    bayes_accuracy_0_44_mean
#    bayes_accuracy_0_44_std
#    bayes_accuracy_0_44_n
#    bayes_accuracy_0_45_mean
#    bayes_accuracy_0_45_std
#    bayes_accuracy_0_45_n
#    bayes_accuracy_0_46_mean
#    bayes_accuracy_0_46_std
#    bayes_accuracy_0_46_n
#    bayes_accuracy_0_47_mean
#    bayes_accuracy_0_47_std
#    bayes_accuracy_0_47_n
#    bayes_accuracy_0_48_mean
#    bayes_accuracy_0_48_std
#    bayes_accuracy_0_48_n
#    bayes_accuracy_0_49_mean
#    bayes_accuracy_0_49_std
#    bayes_accuracy_0_49_n
#    bayes_accuracy_0_50_mean
#    bayes_accuracy_0_50_std
#    bayes_accuracy_0_50_n
#    bayes_accuracy_0_51_mean
#    bayes_accuracy_0_51_std
#    bayes_accuracy_0_51_n
#    bayes_accuracy_0_52_mean
#    bayes_accuracy_0_52_std
#    bayes_accuracy_0_52_n
#    bayes_accuracy_0_53_mean
#    bayes_accuracy_0_53_std
#    bayes_accuracy_0_53_n
#    bayes_accuracy_0_54_mean
#    bayes_accuracy_0_54_std
#    bayes_accuracy_0_54_n
#    bayes_accuracy_0_55_mean
#    bayes_accuracy_0_55_std
#    bayes_accuracy_0_55_n
#    bayes_accuracy_0_56_mean
#    bayes_accuracy_0_56_std
#    bayes_accuracy_0_56_n
#    bayes_accuracy_0_57_mean
#    bayes_accuracy_0_57_std
#    bayes_accuracy_0_57_n
#    bayes_accuracy_0_58_mean
#    bayes_accuracy_0_58_std
#    bayes_accuracy_0_58_n
#    bayes_accuracy_0_59_mean
#    bayes_accuracy_0_59_std
#    bayes_accuracy_0_59_n
#    bayes_accuracy_0_60_mean
#    bayes_accuracy_0_60_std
#    bayes_accuracy_0_60_n
#    bayes_accuracy_0_61_mean
#    bayes_accuracy_0_61_std
#    bayes_accuracy_0_61_n
#    bayes_accuracy_0_62_mean
#    bayes_accuracy_0_62_std
#    bayes_accuracy_0_62_n
#    bayes_accuracy_0_63_mean
#    bayes_accuracy_0_63_std
#    bayes_accuracy_0_63_n
#    bayes_accuracy_0_64_mean
#    bayes_accuracy_0_64_std
#    bayes_accuracy_0_64_n
#    bayes_accuracy_0_65_mean
#    bayes_accuracy_0_65_std
#    bayes_accuracy_0_65_n
#    bayes_accuracy_0_66_mean
#    bayes_accuracy_0_66_std
#    bayes_accuracy_0_66_n
#    bayes_accuracy_0_67_mean
#    bayes_accuracy_0_67_std
#    bayes_accuracy_0_67_n
#    bayes_accuracy_0_68_mean
#    bayes_accuracy_0_68_std
#    bayes_accuracy_0_68_n
#    bayes_accuracy_0_69_mean
#    bayes_accuracy_0_69_std
#    bayes_accuracy_0_69_n
#    bayes_accuracy_0_70_mean
#    bayes_accuracy_0_70_std
#    bayes_accuracy_0_70_n
#    bayes_accuracy_0_71_mean
#    bayes_accuracy_0_71_std
#    bayes_accuracy_0_71_n
#    bayes_accuracy_0_72_mean
#    bayes_accuracy_0_72_std
#    bayes_accuracy_0_72_n
#    bayes_accuracy_0_73_mean
#    bayes_accuracy_0_73_std
#    bayes_accuracy_0_73_n
#    bayes_accuracy_0_74_mean
#    bayes_accuracy_0_74_std
#    bayes_accuracy_0_74_n
#    bayes_accuracy_0_75_mean
#    bayes_accuracy_0_75_std
#    bayes_accuracy_0_75_n
#    bayes_accuracy_0_76_mean
#    bayes_accuracy_0_76_std
#    bayes_accuracy_0_76_n
#    bayes_accuracy_0_77_mean
#    bayes_accuracy_0_77_std
#    bayes_accuracy_0_77_n
#    bayes_accuracy_0_78_mean
#    bayes_accuracy_0_78_std
#    bayes_accuracy_0_78_n
#    bayes_accuracy_0_79_mean
#    bayes_accuracy_0_79_std
#    bayes_accuracy_0_79_n
#    bayes_accuracy_0_80_mean
#    bayes_accuracy_0_80_std
#    bayes_accuracy_0_80_n
#    bayes_accuracy_0_81_mean
#    bayes_accuracy_0_81_std
#    bayes_accuracy_0_81_n
#    bayes_accuracy_0_82_mean
#    bayes_accuracy_0_82_std
#    bayes_accuracy_0_82_n
#    bayes_accuracy_0_83_mean
#    bayes_accuracy_0_83_std
#    bayes_accuracy_0_83_n
#    bayes_accuracy_0_84_mean
#    bayes_accuracy_0_84_std
#    bayes_accuracy_0_84_n
#    bayes_accuracy_0_85_mean
#    bayes_accuracy_0_85_std
#    bayes_accuracy_0_85_n
#    bayes_accuracy_0_86_mean
#    bayes_accuracy_0_86_std
#    bayes_accuracy_0_86_n
#    bayes_accuracy_0_87_mean
#    bayes_accuracy_0_87_std
#    bayes_accuracy_0_87_n
#    bayes_accuracy_0_88_mean
#    bayes_accuracy_0_88_std
#    bayes_accuracy_0_88_n
#    bayes_accuracy_0_89_mean
#    bayes_accuracy_0_89_std
#    bayes_accuracy_0_89_n
#    bayes_accuracy_0_90_mean
#    bayes_accuracy_0_90_std
#    bayes_accuracy_0_90_n
#    bayes_accuracy_0_91_mean
#    bayes_accuracy_0_91_std
#    bayes_accuracy_0_91_n
#    bayes_accuracy_0_92_mean
#    bayes_accuracy_0_92_std
#    bayes_accuracy_0_92_n
#    bayes_accuracy_0_93_mean
#    bayes_accuracy_0_93_std
#    bayes_accuracy_0_93_n
#    bayes_accuracy_0_94_mean
#    bayes_accuracy_0_94_std
#    bayes_accuracy_0_94_n
#    bayes_accuracy_0_95_mean
#    bayes_accuracy_0_95_std
#    bayes_accuracy_0_95_n
#    bayes_accuracy_0_96_mean
#    bayes_accuracy_0_96_std
#    bayes_accuracy_0_96_n
#    bayes_accuracy_0_97_mean
#    bayes_accuracy_0_97_std
#    bayes_accuracy_0_97_n
#    bayes_accuracy_0_98_mean
#    bayes_accuracy_0_98_std
#    bayes_accuracy_0_98_n
#    bayes_accuracy_0_99_mean
#    bayes_accuracy_0_99_std
#    bayes_accuracy_0_99_n
#    bayes_accuracy_1_0_mean
#    bayes_accuracy_1_0_std
#    bayes_accuracy_1_0_n
#    bayes_accuracy_1_1_mean
#    bayes_accuracy_1_1_std
#    bayes_accuracy_1_1_n
#    bayes_accuracy_1_2_mean
#    bayes_accuracy_1_2_std
#    bayes_accuracy_1_2_n
#    bayes_accuracy_1_3_mean
#    bayes_accuracy_1_3_std
#    bayes_accuracy_1_3_n
#    bayes_accuracy_1_4_mean
#    bayes_accuracy_1_4_std
#    bayes_accuracy_1_4_n
#    bayes_accuracy_1_5_mean
#    bayes_accuracy_1_5_std
#    bayes_accuracy_1_5_n
#    bayes_accuracy_1_6_mean
#    bayes_accuracy_1_6_std
#    bayes_accuracy_1_6_n
#    bayes_accuracy_1_7_mean
#    bayes_accuracy_1_7_std
#    bayes_accuracy_1_7_n
#    bayes_accuracy_1_8_mean
#    bayes_accuracy_1_8_std
#    bayes_accuracy_1_8_n
#    bayes_accuracy_1_9_mean
#    bayes_accuracy_1_9_std
#    bayes_accuracy_1_9_n
#    bayes_accuracy_1_10_mean
#    bayes_accuracy_1_10_std
#    bayes_accuracy_1_10_n
#    bayes_accuracy_1_11_mean
#    bayes_accuracy_1_11_std
#    bayes_accuracy_1_11_n
#    bayes_accuracy_1_12_mean
#    bayes_accuracy_1_12_std
#    bayes_accuracy_1_12_n
#    bayes_accuracy_1_13_mean
#    bayes_accuracy_1_13_std
#    bayes_accuracy_1_13_n
#    bayes_accuracy_1_14_mean
#    bayes_accuracy_1_14_std
#    bayes_accuracy_1_14_n
#    bayes_accuracy_1_15_mean
#    bayes_accuracy_1_15_std
#    bayes_accuracy_1_15_n
#    bayes_accuracy_1_16_mean
#    bayes_accuracy_1_16_std
#    bayes_accuracy_1_16_n
#    bayes_accuracy_1_17_mean
#    bayes_accuracy_1_17_std
#    bayes_accuracy_1_17_n
#    bayes_accuracy_1_18_mean
#    bayes_accuracy_1_18_std
#    bayes_accuracy_1_18_n
#    bayes_accuracy_1_19_mean
#    bayes_accuracy_1_19_std
#    bayes_accuracy_1_19_n
#    bayes_accuracy_1_20_mean
#    bayes_accuracy_1_20_std
#    bayes_accuracy_1_20_n
#    bayes_accuracy_1_21_mean
#    bayes_accuracy_1_21_std
#    bayes_accuracy_1_21_n
#    bayes_accuracy_1_22_mean
#    bayes_accuracy_1_22_std
#    bayes_accuracy_1_22_n
#    bayes_accuracy_1_23_mean
#    bayes_accuracy_1_23_std
#    bayes_accuracy_1_23_n
#    bayes_accuracy_1_24_mean
#    bayes_accuracy_1_24_std
#    bayes_accuracy_1_24_n
#    bayes_accuracy_1_25_mean
#    bayes_accuracy_1_25_std
#    bayes_accuracy_1_25_n
#    bayes_accuracy_1_26_mean
#    bayes_accuracy_1_26_std
#    bayes_accuracy_1_26_n
#    bayes_accuracy_1_27_mean
#    bayes_accuracy_1_27_std
#    bayes_accuracy_1_27_n
#    bayes_accuracy_1_28_mean
#    bayes_accuracy_1_28_std
#    bayes_accuracy_1_28_n
#    bayes_accuracy_1_29_mean
#    bayes_accuracy_1_29_std
#    bayes_accuracy_1_29_n
#    bayes_accuracy_1_30_mean
#    bayes_accuracy_1_30_std
#    bayes_accuracy_1_30_n
#    bayes_accuracy_1_31_mean
#    bayes_accuracy_1_31_std
#    bayes_accuracy_1_31_n
#    bayes_accuracy_1_32_mean
#    bayes_accuracy_1_32_std
#    bayes_accuracy_1_32_n
#    bayes_accuracy_1_33_mean
#    bayes_accuracy_1_33_std
#    bayes_accuracy_1_33_n
#    bayes_accuracy_1_34_mean
#    bayes_accuracy_1_34_std
#    bayes_accuracy_1_34_n
#    bayes_accuracy_1_35_mean
#    bayes_accuracy_1_35_std
#    bayes_accuracy_1_35_n
#    bayes_accuracy_1_36_mean
#    bayes_accuracy_1_36_std
#    bayes_accuracy_1_36_n
#    bayes_accuracy_1_37_mean
#    bayes_accuracy_1_37_std
#    bayes_accuracy_1_37_n
#    bayes_accuracy_1_38_mean
#    bayes_accuracy_1_38_std
#    bayes_accuracy_1_38_n
#    bayes_accuracy_1_39_mean
#    bayes_accuracy_1_39_std
#    bayes_accuracy_1_39_n
#    bayes_accuracy_1_40_mean
#    bayes_accuracy_1_40_std
#    bayes_accuracy_1_40_n
#    bayes_accuracy_1_41_mean
#    bayes_accuracy_1_41_std
#    bayes_accuracy_1_41_n
#    bayes_accuracy_1_42_mean
#    bayes_accuracy_1_42_std
#    bayes_accuracy_1_42_n
#    bayes_accuracy_1_43_mean
#    bayes_accuracy_1_43_std
#    bayes_accuracy_1_43_n
#    bayes_accuracy_1_44_mean
#    bayes_accuracy_1_44_std
#    bayes_accuracy_1_44_n
#    bayes_accuracy_1_45_mean
#    bayes_accuracy_1_45_std
#    bayes_accuracy_1_45_n
#    bayes_accuracy_1_46_mean
#    bayes_accuracy_1_46_std
#    bayes_accuracy_1_46_n
#    bayes_accuracy_1_47_mean
#    bayes_accuracy_1_47_std
#    bayes_accuracy_1_47_n
#    bayes_accuracy_1_48_mean
#    bayes_accuracy_1_48_std
#    bayes_accuracy_1_48_n
#    bayes_accuracy_1_49_mean
#    bayes_accuracy_1_49_std
#    bayes_accuracy_1_49_n
#    bayes_accuracy_1_50_mean
#    bayes_accuracy_1_50_std
#    bayes_accuracy_1_50_n
#    bayes_accuracy_1_51_mean
#    bayes_accuracy_1_51_std
#    bayes_accuracy_1_51_n
#    bayes_accuracy_1_52_mean
#    bayes_accuracy_1_52_std
#    bayes_accuracy_1_52_n
#    bayes_accuracy_1_53_mean
#    bayes_accuracy_1_53_std
#    bayes_accuracy_1_53_n
#    bayes_accuracy_1_54_mean
#    bayes_accuracy_1_54_std
#    bayes_accuracy_1_54_n
#    bayes_accuracy_1_55_mean
#    bayes_accuracy_1_55_std
#    bayes_accuracy_1_55_n
#    bayes_accuracy_1_56_mean
#    bayes_accuracy_1_56_std
#    bayes_accuracy_1_56_n
#    bayes_accuracy_1_57_mean
#    bayes_accuracy_1_57_std
#    bayes_accuracy_1_57_n
#    bayes_accuracy_1_58_mean
#    bayes_accuracy_1_58_std
#    bayes_accuracy_1_58_n
#    bayes_accuracy_1_59_mean
#    bayes_accuracy_1_59_std
#    bayes_accuracy_1_59_n
#    bayes_accuracy_1_60_mean
#    bayes_accuracy_1_60_std
#    bayes_accuracy_1_60_n
#    bayes_accuracy_1_61_mean
#    bayes_accuracy_1_61_std
#    bayes_accuracy_1_61_n
#    bayes_accuracy_1_62_mean
#    bayes_accuracy_1_62_std
#    bayes_accuracy_1_62_n
#    bayes_accuracy_1_63_mean
#    bayes_accuracy_1_63_std
#    bayes_accuracy_1_63_n
#    bayes_accuracy_1_64_mean
#    bayes_accuracy_1_64_std
#    bayes_accuracy_1_64_n
#    bayes_accuracy_1_65_mean
#    bayes_accuracy_1_65_std
#    bayes_accuracy_1_65_n
#    bayes_accuracy_1_66_mean
#    bayes_accuracy_1_66_std
#    bayes_accuracy_1_66_n
#    bayes_accuracy_1_67_mean
#    bayes_accuracy_1_67_std
#    bayes_accuracy_1_67_n
#    bayes_accuracy_1_68_mean
#    bayes_accuracy_1_68_std
#    bayes_accuracy_1_68_n
#    bayes_accuracy_1_69_mean
#    bayes_accuracy_1_69_std
#    bayes_accuracy_1_69_n
#    bayes_accuracy_1_70_mean
#    bayes_accuracy_1_70_std
#    bayes_accuracy_1_70_n
#    bayes_accuracy_1_71_mean
#    bayes_accuracy_1_71_std
#    bayes_accuracy_1_71_n
#    bayes_accuracy_1_72_mean
#    bayes_accuracy_1_72_std
#    bayes_accuracy_1_72_n
#    bayes_accuracy_1_73_mean
#    bayes_accuracy_1_73_std
#    bayes_accuracy_1_73_n
#    bayes_accuracy_1_74_mean
#    bayes_accuracy_1_74_std
#    bayes_accuracy_1_74_n
#    bayes_accuracy_1_75_mean
#    bayes_accuracy_1_75_std
#    bayes_accuracy_1_75_n
#    bayes_accuracy_1_76_mean
#    bayes_accuracy_1_76_std
#    bayes_accuracy_1_76_n
#    bayes_accuracy_1_77_mean
#    bayes_accuracy_1_77_std
#    bayes_accuracy_1_77_n
#    bayes_accuracy_1_78_mean
#    bayes_accuracy_1_78_std
#    bayes_accuracy_1_78_n
#    bayes_accuracy_1_79_mean
#    bayes_accuracy_1_79_std
#    bayes_accuracy_1_79_n
#    bayes_accuracy_1_80_mean
#    bayes_accuracy_1_80_std
#    bayes_accuracy_1_80_n
#    bayes_accuracy_1_81_mean
#    bayes_accuracy_1_81_std
#    bayes_accuracy_1_81_n
#    bayes_accuracy_1_82_mean
#    bayes_accuracy_1_82_std
#    bayes_accuracy_1_82_n
#    bayes_accuracy_1_83_mean
#    bayes_accuracy_1_83_std
#    bayes_accuracy_1_83_n
#    bayes_accuracy_1_84_mean
#    bayes_accuracy_1_84_std
#    bayes_accuracy_1_84_n
#    bayes_accuracy_1_85_mean
#    bayes_accuracy_1_85_std
#    bayes_accuracy_1_85_n
#    bayes_accuracy_1_86_mean
#    bayes_accuracy_1_86_std
#    bayes_accuracy_1_86_n
#    bayes_accuracy_1_87_mean
#    bayes_accuracy_1_87_std
#    bayes_accuracy_1_87_n
#    bayes_accuracy_1_88_mean
#    bayes_accuracy_1_88_std
#    bayes_accuracy_1_88_n
#    bayes_accuracy_1_89_mean
#    bayes_accuracy_1_89_std
#    bayes_accuracy_1_89_n
#    bayes_accuracy_1_90_mean
#    bayes_accuracy_1_90_std
#    bayes_accuracy_1_90_n
#    bayes_accuracy_1_91_mean
#    bayes_accuracy_1_91_std
#    bayes_accuracy_1_91_n
#    bayes_accuracy_1_92_mean
#    bayes_accuracy_1_92_std
#    bayes_accuracy_1_92_n
#    bayes_accuracy_1_93_mean
#    bayes_accuracy_1_93_std
#    bayes_accuracy_1_93_n
#    bayes_accuracy_1_94_mean
#    bayes_accuracy_1_94_std
#    bayes_accuracy_1_94_n
#    bayes_accuracy_1_95_mean
#    bayes_accuracy_1_95_std
#    bayes_accuracy_1_95_n
#    bayes_accuracy_1_96_mean
#    bayes_accuracy_1_96_std
#    bayes_accuracy_1_96_n
#    bayes_accuracy_1_97_mean
#    bayes_accuracy_1_97_std
#    bayes_accuracy_1_97_n
#    bayes_accuracy_1_98_mean
#    bayes_accuracy_1_98_std
#    bayes_accuracy_1_98_n
#    bayes_accuracy_1_99_mean
#    bayes_accuracy_1_99_std
#    bayes_accuracy_1_99_n
#    search_time_CI
#    update_time_CI
#    reinvigoration_time_CI
#    evaluation_time_CI
#    policy_calls_CI
#    inference_time_CI
#    search_depth_CI
#    min_value_CI
#    max_value_CI
#    episode_return_CI
#    episode_discounted_return_CI
#    episode_steps_CI
#    episode_time_CI
#    action_dist_distance_0_CI
#    action_dist_distance_1_CI
#    action_dist_distance_0_0_CI
#    action_dist_distance_0_1_CI
#    action_dist_distance_0_2_CI
#    action_dist_distance_0_3_CI
#    action_dist_distance_0_4_CI
#    action_dist_distance_0_5_CI
#    action_dist_distance_0_6_CI
#    action_dist_distance_0_7_CI
#    action_dist_distance_0_8_CI
#    action_dist_distance_0_9_CI
#    action_dist_distance_0_10_CI
#    action_dist_distance_0_11_CI
#    action_dist_distance_0_12_CI
#    action_dist_distance_0_13_CI
#    action_dist_distance_0_14_CI
#    action_dist_distance_0_15_CI
#    action_dist_distance_0_16_CI
#    action_dist_distance_0_17_CI
#    action_dist_distance_0_18_CI
#    action_dist_distance_0_19_CI
#    action_dist_distance_0_20_CI
#    action_dist_distance_0_21_CI
#    action_dist_distance_0_22_CI
#    action_dist_distance_0_23_CI
#    action_dist_distance_0_24_CI
#    action_dist_distance_0_25_CI
#    action_dist_distance_0_26_CI
#    action_dist_distance_0_27_CI
#    action_dist_distance_0_28_CI
#    action_dist_distance_0_29_CI
#    action_dist_distance_0_30_CI
#    action_dist_distance_0_31_CI
#    action_dist_distance_0_32_CI
#    action_dist_distance_0_33_CI
#    action_dist_distance_0_34_CI
#    action_dist_distance_0_35_CI
#    action_dist_distance_0_36_CI
#    action_dist_distance_0_37_CI
#    action_dist_distance_0_38_CI
#    action_dist_distance_0_39_CI
#    action_dist_distance_0_40_CI
#    action_dist_distance_0_41_CI
#    action_dist_distance_0_42_CI
#    action_dist_distance_0_43_CI
#    action_dist_distance_0_44_CI
#    action_dist_distance_0_45_CI
#    action_dist_distance_0_46_CI
#    action_dist_distance_0_47_CI
#    action_dist_distance_0_48_CI
#    action_dist_distance_0_49_CI
#    action_dist_distance_0_50_CI
#    action_dist_distance_0_51_CI
#    action_dist_distance_0_52_CI
#    action_dist_distance_0_53_CI
#    action_dist_distance_0_54_CI
#    action_dist_distance_0_55_CI
#    action_dist_distance_0_56_CI
#    action_dist_distance_0_57_CI
#    action_dist_distance_0_58_CI
#    action_dist_distance_0_59_CI
#    action_dist_distance_0_60_CI
#    action_dist_distance_0_61_CI
#    action_dist_distance_0_62_CI
#    action_dist_distance_0_63_CI
#    action_dist_distance_0_64_CI
#    action_dist_distance_0_65_CI
#    action_dist_distance_0_66_CI
#    action_dist_distance_0_67_CI
#    action_dist_distance_0_68_CI
#    action_dist_distance_0_69_CI
#    action_dist_distance_0_70_CI
#    action_dist_distance_0_71_CI
#    action_dist_distance_0_72_CI
#    action_dist_distance_0_73_CI
#    action_dist_distance_0_74_CI
#    action_dist_distance_0_75_CI
#    action_dist_distance_0_76_CI
#    action_dist_distance_0_77_CI
#    action_dist_distance_0_78_CI
#    action_dist_distance_0_79_CI
#    action_dist_distance_0_80_CI
#    action_dist_distance_0_81_CI
#    action_dist_distance_0_82_CI
#    action_dist_distance_0_83_CI
#    action_dist_distance_0_84_CI
#    action_dist_distance_0_85_CI
#    action_dist_distance_0_86_CI
#    action_dist_distance_0_87_CI
#    action_dist_distance_0_88_CI
#    action_dist_distance_0_89_CI
#    action_dist_distance_0_90_CI
#    action_dist_distance_0_91_CI
#    action_dist_distance_0_92_CI
#    action_dist_distance_0_93_CI
#    action_dist_distance_0_94_CI
#    action_dist_distance_0_95_CI
#    action_dist_distance_0_96_CI
#    action_dist_distance_0_97_CI
#    action_dist_distance_0_98_CI
#    action_dist_distance_0_99_CI
#    action_dist_distance_1_0_CI
#    action_dist_distance_1_1_CI
#    action_dist_distance_1_2_CI
#    action_dist_distance_1_3_CI
#    action_dist_distance_1_4_CI
#    action_dist_distance_1_5_CI
#    action_dist_distance_1_6_CI
#    action_dist_distance_1_7_CI
#    action_dist_distance_1_8_CI
#    action_dist_distance_1_9_CI
#    action_dist_distance_1_10_CI
#    action_dist_distance_1_11_CI
#    action_dist_distance_1_12_CI
#    action_dist_distance_1_13_CI
#    action_dist_distance_1_14_CI
#    action_dist_distance_1_15_CI
#    action_dist_distance_1_16_CI
#    action_dist_distance_1_17_CI
#    action_dist_distance_1_18_CI
#    action_dist_distance_1_19_CI
#    action_dist_distance_1_20_CI
#    action_dist_distance_1_21_CI
#    action_dist_distance_1_22_CI
#    action_dist_distance_1_23_CI
#    action_dist_distance_1_24_CI
#    action_dist_distance_1_25_CI
#    action_dist_distance_1_26_CI
#    action_dist_distance_1_27_CI
#    action_dist_distance_1_28_CI
#    action_dist_distance_1_29_CI
#    action_dist_distance_1_30_CI
#    action_dist_distance_1_31_CI
#    action_dist_distance_1_32_CI
#    action_dist_distance_1_33_CI
#    action_dist_distance_1_34_CI
#    action_dist_distance_1_35_CI
#    action_dist_distance_1_36_CI
#    action_dist_distance_1_37_CI
#    action_dist_distance_1_38_CI
#    action_dist_distance_1_39_CI
#    action_dist_distance_1_40_CI
#    action_dist_distance_1_41_CI
#    action_dist_distance_1_42_CI
#    action_dist_distance_1_43_CI
#    action_dist_distance_1_44_CI
#    action_dist_distance_1_45_CI
#    action_dist_distance_1_46_CI
#    action_dist_distance_1_47_CI
#    action_dist_distance_1_48_CI
#    action_dist_distance_1_49_CI
#    action_dist_distance_1_50_CI
#    action_dist_distance_1_51_CI
#    action_dist_distance_1_52_CI
#    action_dist_distance_1_53_CI
#    action_dist_distance_1_54_CI
#    action_dist_distance_1_55_CI
#    action_dist_distance_1_56_CI
#    action_dist_distance_1_57_CI
#    action_dist_distance_1_58_CI
#    action_dist_distance_1_59_CI
#    action_dist_distance_1_60_CI
#    action_dist_distance_1_61_CI
#    action_dist_distance_1_62_CI
#    action_dist_distance_1_63_CI
#    action_dist_distance_1_64_CI
#    action_dist_distance_1_65_CI
#    action_dist_distance_1_66_CI
#    action_dist_distance_1_67_CI
#    action_dist_distance_1_68_CI
#    action_dist_distance_1_69_CI
#    action_dist_distance_1_70_CI
#    action_dist_distance_1_71_CI
#    action_dist_distance_1_72_CI
#    action_dist_distance_1_73_CI
#    action_dist_distance_1_74_CI
#    action_dist_distance_1_75_CI
#    action_dist_distance_1_76_CI
#    action_dist_distance_1_77_CI
#    action_dist_distance_1_78_CI
#    action_dist_distance_1_79_CI
#    action_dist_distance_1_80_CI
#    action_dist_distance_1_81_CI
#    action_dist_distance_1_82_CI
#    action_dist_distance_1_83_CI
#    action_dist_distance_1_84_CI
#    action_dist_distance_1_85_CI
#    action_dist_distance_1_86_CI
#    action_dist_distance_1_87_CI
#    action_dist_distance_1_88_CI
#    action_dist_distance_1_89_CI
#    action_dist_distance_1_90_CI
#    action_dist_distance_1_91_CI
#    action_dist_distance_1_92_CI
#    action_dist_distance_1_93_CI
#    action_dist_distance_1_94_CI
#    action_dist_distance_1_95_CI
#    action_dist_distance_1_96_CI
#    action_dist_distance_1_97_CI
#    action_dist_distance_1_98_CI
#    action_dist_distance_1_99_CI
#    bayes_accuracy_0_CI
#    bayes_accuracy_1_CI
#    bayes_accuracy_0_0_CI
#    bayes_accuracy_0_1_CI
#    bayes_accuracy_0_2_CI
#    bayes_accuracy_0_3_CI
#    bayes_accuracy_0_4_CI
#    bayes_accuracy_0_5_CI
#    bayes_accuracy_0_6_CI
#    bayes_accuracy_0_7_CI
#    bayes_accuracy_0_8_CI
#    bayes_accuracy_0_9_CI
#    bayes_accuracy_0_10_CI
#    bayes_accuracy_0_11_CI
#    bayes_accuracy_0_12_CI
#    bayes_accuracy_0_13_CI
#    bayes_accuracy_0_14_CI
#    bayes_accuracy_0_15_CI
#    bayes_accuracy_0_16_CI
#    bayes_accuracy_0_17_CI
#    bayes_accuracy_0_18_CI
#    bayes_accuracy_0_19_CI
#    bayes_accuracy_0_20_CI
#    bayes_accuracy_0_21_CI
#    bayes_accuracy_0_22_CI
#    bayes_accuracy_0_23_CI
#    bayes_accuracy_0_24_CI
#    bayes_accuracy_0_25_CI
#    bayes_accuracy_0_26_CI
#    bayes_accuracy_0_27_CI
#    bayes_accuracy_0_28_CI
#    bayes_accuracy_0_29_CI
#    bayes_accuracy_0_30_CI
#    bayes_accuracy_0_31_CI
#    bayes_accuracy_0_32_CI
#    bayes_accuracy_0_33_CI
#    bayes_accuracy_0_34_CI
#    bayes_accuracy_0_35_CI
#    bayes_accuracy_0_36_CI
#    bayes_accuracy_0_37_CI
#    bayes_accuracy_0_38_CI
#    bayes_accuracy_0_39_CI
#    bayes_accuracy_0_40_CI
#    bayes_accuracy_0_41_CI
#    bayes_accuracy_0_42_CI
#    bayes_accuracy_0_43_CI
#    bayes_accuracy_0_44_CI
#    bayes_accuracy_0_45_CI
#    bayes_accuracy_0_46_CI
#    bayes_accuracy_0_47_CI
#    bayes_accuracy_0_48_CI
#    bayes_accuracy_0_49_CI
#    bayes_accuracy_0_50_CI
#    bayes_accuracy_0_51_CI
#    bayes_accuracy_0_52_CI
#    bayes_accuracy_0_53_CI
#    bayes_accuracy_0_54_CI
#    bayes_accuracy_0_55_CI
#    bayes_accuracy_0_56_CI
#    bayes_accuracy_0_57_CI
#    bayes_accuracy_0_58_CI
#    bayes_accuracy_0_59_CI
#    bayes_accuracy_0_60_CI
#    bayes_accuracy_0_61_CI
#    bayes_accuracy_0_62_CI
#    bayes_accuracy_0_63_CI
#    bayes_accuracy_0_64_CI
#    bayes_accuracy_0_65_CI
#    bayes_accuracy_0_66_CI
#    bayes_accuracy_0_67_CI
#    bayes_accuracy_0_68_CI
#    bayes_accuracy_0_69_CI
#    bayes_accuracy_0_70_CI
#    bayes_accuracy_0_71_CI
#    bayes_accuracy_0_72_CI
#    bayes_accuracy_0_73_CI
#    bayes_accuracy_0_74_CI
#    bayes_accuracy_0_75_CI
#    bayes_accuracy_0_76_CI
#    bayes_accuracy_0_77_CI
#    bayes_accuracy_0_78_CI
#    bayes_accuracy_0_79_CI
#    bayes_accuracy_0_80_CI
#    bayes_accuracy_0_81_CI
#    bayes_accuracy_0_82_CI
#    bayes_accuracy_0_83_CI
#    bayes_accuracy_0_84_CI
#    bayes_accuracy_0_85_CI
#    bayes_accuracy_0_86_CI
#    bayes_accuracy_0_87_CI
#    bayes_accuracy_0_88_CI
#    bayes_accuracy_0_89_CI
#    bayes_accuracy_0_90_CI
#    bayes_accuracy_0_91_CI
#    bayes_accuracy_0_92_CI
#    bayes_accuracy_0_93_CI
#    bayes_accuracy_0_94_CI
#    bayes_accuracy_0_95_CI
#    bayes_accuracy_0_96_CI
#    bayes_accuracy_0_97_CI
#    bayes_accuracy_0_98_CI
#    bayes_accuracy_0_99_CI
#    bayes_accuracy_1_0_CI
#    bayes_accuracy_1_1_CI
#    bayes_accuracy_1_2_CI
#    bayes_accuracy_1_3_CI
#    bayes_accuracy_1_4_CI
#    bayes_accuracy_1_5_CI
#    bayes_accuracy_1_6_CI
#    bayes_accuracy_1_7_CI
#    bayes_accuracy_1_8_CI
#    bayes_accuracy_1_9_CI
#    bayes_accuracy_1_10_CI
#    bayes_accuracy_1_11_CI
#    bayes_accuracy_1_12_CI
#    bayes_accuracy_1_13_CI
#    bayes_accuracy_1_14_CI
#    bayes_accuracy_1_15_CI
#    bayes_accuracy_1_16_CI
#    bayes_accuracy_1_17_CI
#    bayes_accuracy_1_18_CI
#    bayes_accuracy_1_19_CI
#    bayes_accuracy_1_20_CI
#    bayes_accuracy_1_21_CI
#    bayes_accuracy_1_22_CI
#    bayes_accuracy_1_23_CI
#    bayes_accuracy_1_24_CI
#    bayes_accuracy_1_25_CI
#    bayes_accuracy_1_26_CI
#    bayes_accuracy_1_27_CI
#    bayes_accuracy_1_28_CI
#    bayes_accuracy_1_29_CI
#    bayes_accuracy_1_30_CI
#    bayes_accuracy_1_31_CI
#    bayes_accuracy_1_32_CI
#    bayes_accuracy_1_33_CI
#    bayes_accuracy_1_34_CI
#    bayes_accuracy_1_35_CI
#    bayes_accuracy_1_36_CI
#    bayes_accuracy_1_37_CI
#    bayes_accuracy_1_38_CI
#    bayes_accuracy_1_39_CI
#    bayes_accuracy_1_40_CI
#    bayes_accuracy_1_41_CI
#    bayes_accuracy_1_42_CI
#    bayes_accuracy_1_43_CI
#    bayes_accuracy_1_44_CI
#    bayes_accuracy_1_45_CI
#    bayes_accuracy_1_46_CI
#    bayes_accuracy_1_47_CI
#    bayes_accuracy_1_48_CI
#    bayes_accuracy_1_49_CI
#    bayes_accuracy_1_50_CI
#    bayes_accuracy_1_51_CI
#    bayes_accuracy_1_52_CI
#    bayes_accuracy_1_53_CI
#    bayes_accuracy_1_54_CI
#    bayes_accuracy_1_55_CI
#    bayes_accuracy_1_56_CI
#    bayes_accuracy_1_57_CI
#    bayes_accuracy_1_58_CI
#    bayes_accuracy_1_59_CI
#    bayes_accuracy_1_60_CI
#    bayes_accuracy_1_61_CI
#    bayes_accuracy_1_62_CI
#    bayes_accuracy_1_63_CI
#    bayes_accuracy_1_64_CI
#    bayes_accuracy_1_65_CI
#    bayes_accuracy_1_66_CI
#    bayes_accuracy_1_67_CI
#    bayes_accuracy_1_68_CI
#    bayes_accuracy_1_69_CI
#    bayes_accuracy_1_70_CI
#    bayes_accuracy_1_71_CI
#    bayes_accuracy_1_72_CI
#    bayes_accuracy_1_73_CI
#    bayes_accuracy_1_74_CI
#    bayes_accuracy_1_75_CI
#    bayes_accuracy_1_76_CI
#    bayes_accuracy_1_77_CI
#    bayes_accuracy_1_78_CI
#    bayes_accuracy_1_79_CI
#    bayes_accuracy_1_80_CI
#    bayes_accuracy_1_81_CI
#    bayes_accuracy_1_82_CI
#    bayes_accuracy_1_83_CI
#    bayes_accuracy_1_84_CI
#    bayes_accuracy_1_85_CI
#    bayes_accuracy_1_86_CI
#    bayes_accuracy_1_87_CI
#    bayes_accuracy_1_88_CI
#    bayes_accuracy_1_89_CI
#    bayes_accuracy_1_90_CI
#    bayes_accuracy_1_91_CI
#    bayes_accuracy_1_92_CI
#    bayes_accuracy_1_93_CI
#    bayes_accuracy_1_94_CI
#    bayes_accuracy_1_95_CI
#    bayes_accuracy_1_96_CI
#    bayes_accuracy_1_97_CI
#    bayes_accuracy_1_98_CI
#    bayes_accuracy_1_99_CI
#    prop_LOSS
#    prop_DRAW
#    prop_WIN
#    prop_NA

# %% [markdown]
# ## Pairwise performance
#
# Here we look at the performance of each policy against each other policy including BAPOSGMCP and baselines with different number of simulations, action selection, and meta-policies.

# %%
agent_0_df = combined_df[combined_df["agent_id"] == 0]
plot_utils.plot_pairwise_comparison(
    agent_0_df,
    y_key="episode_return_mean", 
    policy_key="policy_id",
    y_err_key="episode_return_CI",
    vrange=None, 
    figsize=(24, len(agent_0_df["policy_id"].unique())), 
    valfmt="{x:.2f}",
    coplayer_policies=list(policy_prior[1]),
    average_duplicates=True,
    duplicate_warning=False
)
# Out:
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# (<Figure size 1728x4464 with 2 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %%
agent_1_df = combined_df[combined_df["agent_id"] == 1]
plot_utils.plot_pairwise_comparison(
    agent_1_df,
    y_key="episode_return_mean", 
    policy_key="policy_id",
    y_err_key="episode_return_CI",
    vrange=None, 
    figsize=(24, len(agent_1_df["policy_id"].unique())), 
    valfmt="{x:.2f}",
    coplayer_policies=list(policy_prior[0]),
    average_duplicates=True,
    duplicate_warning=False
)
# Out:
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# (<Figure size 1728x4464 with 2 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %%
plot_utils.plot_pairwise_comparison(
    agent_0_df,
    y_key="num_episodes", 
    policy_key="policy_id",
    y_err_key=None,
    vrange=None, 
    figsize=(24, len(agent_0_df["policy_id"].unique())),  
    valfmt="{x:.0f}",
    coplayer_policies=list(policy_prior[1]),
    average_duplicates=True,
    duplicate_warning=False
)
# Out:
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# (<Figure size 1728x4464 with 1 Axes>, array([[<AxesSubplot:>]], dtype=object))

# %%
plot_utils.plot_pairwise_comparison(
    agent_1_df,
    y_key="num_episodes", 
    policy_key="policy_id",
    y_err_key=None,
    vrange=None, 
    figsize=(24, len(agent_1_df["policy_id"].unique())),  
    valfmt="{x:.0f}",
    coplayer_policies=list(policy_prior[0]),
    average_duplicates=True,
    duplicate_warning=False
)
# Out:
# /home/jonathon/code/ba-posgmcp/baposgmcp/plot/pairwise.py:39: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pw_values[row_policy_idx][col_policy_idx] = group.mean()[y_key]
# (<Figure size 1728x4464 with 1 Axes>, array([[<AxesSubplot:>]], dtype=object))

# %% [markdown]
# ## Policy Prior Performance
#
# Here we look at the expected performance against the policy prior of BAPOSGMCP.

# %%
exp_df = plot_utils.get_uniform_expected_df(
    combined_df, 
    coplayer_policies=coplayer_policy_ids,
    coplayer_policy_key="coplayer_policy_id"
)
# Out:
# Ungrouped size = 502
# Grouped size = 124

# %%
# Base plot kwargs
base_plot_kwargs = paper_utils.get_base_plot_kwargs()
return_plot_kwargs = copy.deepcopy(base_plot_kwargs)
return_plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Episode Return",
})

step_plot_kwargs = copy.deepcopy(return_plot_kwargs)
step_plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Episode Steps"
})

# %% [markdown]
# ### Action Selection
#
# NA since used `action_selection=PUCB` where applicable for PursuitEvasion exps.

# %%
exp_df["action_selection"].unique()
# Out:
# array(['pucb', None], dtype=object)

# %% [markdown]
# ### Comparison of truncation
#
# NA since used `truncated=True` where applicable for PursuitEvasion exps.

# %%
exp_df["truncated"].unique()
# Out:
# array([ True, False])

# %% [markdown]
# ### Comparison of the different Meta-Policies

# %%
meta_pi_label_map = {
    "greedy": r"$\sigma^{G}$",
    "softmax": r"$\sigma^{S}$",
    "uniform": r"$\sigma^{U}$",
}

meta_pi_df = exp_df[
    (exp_df["alg_id"].isin(["baposgmcp", "POMeta", "POMetaRollout", "metabaseline"]))
    # (exp_df["alg_id"].isin(["baposgmcp"]))
    & (exp_df["action_selection"].isin(["pucb", None]))
    # & (exp_df["truncated"].isin([True, 'True', None]))
]

meta_alg_ids = meta_pi_df["alg_id"].unique().tolist()
meta_alg_ids.sort()
print("Alg IDs")
print("-------")
for n in meta_alg_ids:
    print(n)
    
policy_ids = meta_pi_df["policy_id"].unique().tolist()
policy_ids.sort()
print("\nPolicy IDs")
print("----------")
for n in policy_ids:
    print(n)
# Out:
# Alg IDs
# -------
# POMeta
# POMetaRollout
# baposgmcp
# metabaseline
#
# Policy IDs
# ----------
# POMetaRollout_greedy_i0_numsims1000_actionselectionpucb_truncatedTrue
# POMetaRollout_greedy_i0_numsims100_actionselectionpucb_truncatedTrue
# POMetaRollout_greedy_i0_numsims10_actionselectionpucb_truncatedTrue
# POMetaRollout_greedy_i0_numsims500_actionselectionpucb_truncatedTrue
# POMetaRollout_greedy_i0_numsims50_actionselectionpucb_truncatedTrue
# POMetaRollout_greedy_i1_numsims1000_actionselectionpucb_truncatedTrue
# POMetaRollout_greedy_i1_numsims100_actionselectionpucb_truncatedTrue
# POMetaRollout_greedy_i1_numsims10_actionselectionpucb_truncatedTrue
# POMetaRollout_greedy_i1_numsims500_actionselectionpucb_truncatedTrue
# POMetaRollout_greedy_i1_numsims50_actionselectionpucb_truncatedTrue
# POMeta_greedy_i0_numsims10
# POMeta_greedy_i0_numsims100
# POMeta_greedy_i0_numsims1000
# POMeta_greedy_i0_numsims50
# POMeta_greedy_i0_numsims500
# POMeta_greedy_i1_numsims10
# POMeta_greedy_i1_numsims100
# POMeta_greedy_i1_numsims1000
# POMeta_greedy_i1_numsims50
# POMeta_greedy_i1_numsims500
# baposgmcp_greedy_i0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp_greedy_i0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp_greedy_i0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp_greedy_i0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp_greedy_i0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp_greedy_i1_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp_greedy_i1_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp_greedy_i1_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp_greedy_i1_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp_greedy_i1_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i1_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i1_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i1_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i1_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i1_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp_uniform_i0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp_uniform_i0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp_uniform_i0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp_uniform_i0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp_uniform_i0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp_uniform_i1_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp_uniform_i1_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp_uniform_i1_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp_uniform_i1_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp_uniform_i1_numsims50_actionselectionpucb_truncatedTrue
# metabaseline_greedy_i0
# metabaseline_greedy_i1

# %%
plot_kwargs = copy.deepcopy(return_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    # "ylim": (-1.0, 1.0),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "lower right",
    # "title": "Meta-Policy" 
})

for agent_id in [0, 1]:
    print(f"{agent_id=}")
    for alg_id in meta_alg_ids:
        print(f"{alg_id=}")
        fig, _ = plot_utils.paper.plot_multiple_meta_policy_vs_num_sims(
            meta_pi_df[(meta_pi_df["agent_id"] == agent_id) & (meta_pi_df["alg_id"] == alg_id)],
            y_key="episode_return_mean",
            y_err_key="episode_return_CI",
            meta_pi_label_map=meta_pi_label_map,
            alg_id_key="alg_id",
            set_title=False,
            **plot_kwargs
        )
        fig.savefig(osp.join(figure_dir, f"meta_pi_return_{alg_id}_i{agent_id}.png"))
    
del plot_kwargs
# Out:
# agent_id=0
# alg_id='POMeta'
# alg_id='POMetaRollout'
# alg_id='baposgmcp'
# alg_id='metabaseline'
# agent_id=1
# alg_id='POMeta'
# alg_id='POMetaRollout'
# alg_id='baposgmcp'
# alg_id='metabaseline'

# %%
plot_kwargs = copy.deepcopy(step_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylim": (0, 100),
})
plot_kwargs["legend_kwargs"].update({
    "loc": 'upper right',
    "title": "Meta-Policy",  
})
    
for agent_id in [0, 1]:
    print(f"{agent_id=}")
    for alg_id in meta_alg_ids:
        print(f"{alg_id=}")
        fig, _ = plot_utils.paper.plot_multiple_meta_policy_vs_num_sims(
            meta_pi_df[(meta_pi_df["agent_id"] == agent_id) & (meta_pi_df["alg_id"] == alg_id)],
            y_key="episode_steps_mean",
            y_err_key="episode_steps_CI",
            meta_pi_label_map=meta_pi_label_map,
            alg_id_key="alg_id",
            set_title=False,
            **plot_kwargs
        )
        fig.savefig(osp.join(figure_dir, f"meta_pi_steps_{alg_id}_i{agent_id}.png"))
    
del plot_kwargs
# Out:
# agent_id=0
# alg_id='POMeta'
# alg_id='POMetaRollout'
# alg_id='baposgmcp'
# alg_id='metabaseline'
# agent_id=1
# alg_id='POMeta'
# alg_id='POMetaRollout'
# alg_id='baposgmcp'
# alg_id='metabaseline'

# %% [markdown]
# ### Comparing Meta-Policy versus no meta-policy

# %%
# TODO May need to change BAPOSGMCP meta policy depending on results
# BAPOSGMCP Meta-Policy
# 0: Best = uniform (but only marginally at lower #sims (i.e. 100))
#           Performance is roughly equal between all meta Pis at higher sims >=500
# 1: Best = clearly softmax > greedy > uniform
#
# Hence I use softmax for remainder of analysis

meta_vs_no_pi_label_map = {
    0: {
        # "baposgmcp_uniform": r"$\sigma^{U}$",
        "baposgmcp_softmax": r"$\sigma^{S}$",
        "baposgmcp-random_i0": "Random",
        "baposgmcp-fixed_i0_piklrk0seed0i0-v0": "K0_0",
        "baposgmcp-fixed_i0_piklrk1seed0i0-v0": "K1_0",
        "baposgmcp-fixed_i0_piklrk2seed0i0-v0": "K2_0",
        "baposgmcp-fixed_i0_piklrk3seed0i0-v0": "K3_0",
    },
    1: {
        # "baposgmcp_uniform": r"$\sigma^{U}$",
        "baposgmcp_softmax": r"$\sigma^{S}$",
        "baposgmcp-random_i1": "Random",
        "baposgmcp-fixed_i1_piklrk0seed0i1-v0": "K0_1",
        "baposgmcp-fixed_i1_piklrk1seed0i1-v0": "K1_1",
        "baposgmcp-fixed_i1_piklrk2seed0i1-v0": "K2_1",
        "baposgmcp-fixed_i1_piklrk3seed0i1-v0": "K3_1",
    }
}

# Use DF containing only policies with PUCB action_selection or NA
meta_vs_no_meta_df = exp_df[
    (exp_df["alg_id"].isin(["baposgmcp", "baposgmcp-fixed", "baposgmcp-random"]))
    & (exp_df["action_selection"].isin(["pucb"]))
    & (exp_df["meta_pi"].isin(["softmax", "NA"]))
    & (
        (exp_df["alg_id"] == "baposgmcp-random") | (exp_df["truncated"].isin([True, 'True', None]))
    )
]

meta_vs_no_meta_alg_ids = meta_vs_no_meta_df["alg_id"].unique().tolist()
meta_vs_no_meta_alg_ids.sort()
print("Alg IDs")
print("-------")
for n in meta_vs_no_meta_alg_ids:
    print(n)
    
policy_ids = meta_vs_no_meta_df["policy_id"].unique().tolist()
policy_ids.sort()
print("\nPolicy IDs")
print("----------")
for n in policy_ids:
    print(n)
    
fixed_policy_ids = meta_vs_no_meta_df["fixed_policy_id"].unique().tolist()
print("\nFixed Policy IDs")
print("----------------")
for n in fixed_policy_ids:
    print(n)
# Out:
# Alg IDs
# -------
# baposgmcp
# baposgmcp-fixed
# baposgmcp-random
#
# Policy IDs
# ----------
# baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk0seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk1seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk2seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk3seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i0_piklrk4seed0i0-v0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk0seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk1seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk2seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk3seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp-fixed_i1_piklrk4seed0i1-v0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp-random_i0_numsims1000_actionselectionpucb_truncatedFalse
# baposgmcp-random_i0_numsims100_actionselectionpucb_truncatedFalse
# baposgmcp-random_i0_numsims10_actionselectionpucb_truncatedFalse
# baposgmcp-random_i0_numsims500_actionselectionpucb_truncatedFalse
# baposgmcp-random_i0_numsims50_actionselectionpucb_truncatedFalse
# baposgmcp-random_i1_numsims1000_actionselectionpucb_truncatedFalse
# baposgmcp-random_i1_numsims100_actionselectionpucb_truncatedFalse
# baposgmcp-random_i1_numsims10_actionselectionpucb_truncatedFalse
# baposgmcp-random_i1_numsims500_actionselectionpucb_truncatedFalse
# baposgmcp-random_i1_numsims50_actionselectionpucb_truncatedFalse
# baposgmcp_softmax_i0_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i0_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i0_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i0_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i0_numsims50_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i1_numsims1000_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i1_numsims100_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i1_numsims10_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i1_numsims500_actionselectionpucb_truncatedTrue
# baposgmcp_softmax_i1_numsims50_actionselectionpucb_truncatedTrue
#
# Fixed Policy IDs
# ----------------
# PursuitEvasion16x16-v0/klr_k0_seed0_i0-v0
# PursuitEvasion16x16-v0/klr_k1_seed0_i0-v0
# PursuitEvasion16x16-v0/klr_k2_seed0_i0-v0
# PursuitEvasion16x16-v0/klr_k3_seed0_i0-v0
# PursuitEvasion16x16-v0/klr_k4_seed0_i0-v0
# PursuitEvasion16x16-v0/klr_k0_seed0_i1-v0
# PursuitEvasion16x16-v0/klr_k1_seed0_i1-v0
# PursuitEvasion16x16-v0/klr_k2_seed0_i1-v0
# PursuitEvasion16x16-v0/klr_k3_seed0_i1-v0
# PursuitEvasion16x16-v0/klr_k4_seed0_i1-v0
# random-v0
# None

# %%
plot_kwargs = copy.deepcopy(return_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylim": (-0.5, 1.0),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "lower right",
    # "title": "Policy",
    "ncol": 2
})

for agent_id in [0, 1]:
    print(f"{agent_id=}")
    fig, _ = plot_utils.paper.plot_multiple_performance_vs_num_sims(
        meta_vs_no_meta_df[meta_vs_no_meta_df["agent_id"] == agent_id],
        y_key="episode_return_mean",
        y_err_key="episode_return_CI",
        policy_prefixes=[list(meta_vs_no_pi_label_map[agent_id])],
        pi_label_map=meta_vs_no_pi_label_map[agent_id],
        **plot_kwargs,
    )

    fig.savefig(osp.join(figure_dir, f"meta_vs_fixed_return_i{agent_id}.png"))
    
del plot_kwargs
# Out:
# agent_id=0
# agent_id=1

# %%
meta_vs_no_best_and_worst_pi_label_map = {
    0: {
        # "baposgmcp_uniform": r"$\sigma^{U}$",
        "baposgmcp_softmax": r"$\sigma^{S}$",
        "baposgmcp-random_i0": "Random",
        "baposgmcp-fixed_i0_piklrk0seed0i0-v0": "Worst",
        #"baposgmcp-fixed_i0_piklrk1seed0i0-v0": "K1_0",
        "baposgmcp-fixed_i0_piklrk2seed0i0-v0": "Best",
        # "baposgmcp-fixed_i0_piklrk3seed0i0-v0": "K3_0",
    },
    1: {
        # "baposgmcp_uniform": r"$\sigma^{U}$",
        "baposgmcp_softmax": r"$\sigma^{S}$",
        "baposgmcp-random_i1": "Random",
        "baposgmcp-fixed_i1_piklrk0seed0i1-v0": "Worst",
        # "baposgmcp-fixed_i1_piklrk1seed0i1-v0": "K1_1",
        "baposgmcp-fixed_i1_piklrk2seed0i1-v0": "Best",
        # "baposgmcp-fixed_i1_piklrk3seed0i1-v0": "K3_1",
    }
}

plot_kwargs = copy.deepcopy(return_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylim": (-0.5, 1.0),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "lower right",
    # "title": "Policy" 
})

for agent_id in [0, 1]:
    print(f"{agent_id=}")
    fig, _ = plot_utils.paper.plot_multiple_performance_vs_num_sims(
        meta_vs_no_meta_df[meta_vs_no_meta_df["agent_id"] == agent_id],
        y_key="episode_return_mean",
        y_err_key="episode_return_CI",
        policy_prefixes=[list(meta_vs_no_best_and_worst_pi_label_map[agent_id])],
        pi_label_map=meta_vs_no_best_and_worst_pi_label_map[agent_id],
        **plot_kwargs,
    )

    fig.savefig(osp.join(figure_dir, f"meta_vs_fixed_return_best_and_worst_i{agent_id}.png"))
    
del plot_kwargs
# Out:
# agent_id=0
# agent_id=1

# %%
plot_kwargs = copy.deepcopy(step_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylim": (0, 100),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "upper right",
    "title": "Policy" 
})

for agent_id in [0, 1]:
    print(f"{agent_id=}")
    fig, _ = plot_utils.paper.plot_multiple_performance_vs_num_sims(
        meta_vs_no_meta_df[meta_vs_no_meta_df["agent_id"] == agent_id],
        y_key="episode_steps_mean",
        y_err_key="episode_steps_CI",
        policy_prefixes=[list(meta_vs_no_pi_label_map[agent_id])],
        pi_label_map=meta_vs_no_pi_label_map[agent_id],
        **plot_kwargs,
    )

    fig.savefig(osp.join(figure_dir, f"meta_vs_fixed_steps_i{agent_id}.png"))
    
del plot_kwargs
# Out:
# agent_id=0
# agent_id=1

# %% [markdown]
# ## Comparing BAPOSGMCP versus baselines

# %%
perf_df = exp_df[
    (exp_df["alg_id"].isin(["baposgmcp", "POMeta", "POMetaRollout", "metabaseline", "full-knowledge-br"]))
    & (exp_df["action_selection"].isin(["pucb", None]))
    # & (exp_df["truncated"].isin([True, 'True', None]))
]

policy_prefixes_to_plot = [
    # "baposgmcp_uniform",
    "baposgmcp_softmax",
    "POMeta_greedy",
    "POMetaRollout_greedy",
    "metabaseline_greedy",
    "full-knowledge-br"
]

baseline_pi_label_map = {
    # "baposgmcp_uniform": "BAPOSGMCP",
    "baposgmcp_softmax": "BAPOSGMCP",
    "baposgmcp-random": "BAPOSGMCP Random",
    "POMeta_greedy": "POMeta", 
    "POMetaRollout_greedy": "POMetaRollout", 
    "metabaseline_greedy": "Meta-Policy",
    "full-knowledge-br": "Best-Response"
}

# %%
plot_kwargs = copy.deepcopy(return_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylim": (-1.0, 1.0),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "lower right",
})

for agent_id in [0, 1]:
    print(f"{agent_id=}")
    fig, _ = plot_utils.paper.plot_multiple_performance_vs_num_sims(
        perf_df[perf_df["agent_id"] == agent_id],
        y_key="episode_return_mean",
        y_err_key="episode_return_CI",
        policy_prefixes=[policy_prefixes_to_plot],
        pi_label_map=baseline_pi_label_map,
        **plot_kwargs,
    )

    fig.savefig(osp.join(figure_dir, f"baselines_return_i{agent_id}.png"))
    
del plot_kwargs
# Out:
# agent_id=0
# agent_id=1

# %% [markdown]
# ## Looking at Belief accuracy by steps
#
# - action_dist_distance
# - bayes_accuracy

# %%
belief_df = exp_df[
    (exp_df["action_selection"].isin(['pucb', None]))
    & (exp_df["alg_id"].isin(["baposgmcp", "POMeta", "POMetaRollout"]))
    # & (exp_df["truncated"].isin([True]))
]

belief_alg_ids = belief_df["alg_id"].unique().tolist()
belief_alg_ids.sort()
print("Alg IDs")
print("-------")
for n in belief_alg_ids:
    print(n)

# group over meta-policy values
belief_group_keys = ["alg_id", "num_sims"]
belief_agg_dict = plot_utils.get_uniform_expected_agg_map(exp_df)
for k in belief_group_keys:
    if k in belief_agg_dict:
        belief_agg_dict.pop(k)
        
gb = belief_df.groupby(belief_group_keys)
gb_agg = gb.agg(**belief_agg_dict)
belief_gb_df = gb_agg.reset_index()

belief_gb_df.sort_values(by=["num_sims"], inplace=True)

print("Ungrouped size =", len(belief_df))
print("Grouped size =", len(belief_gb_df))
print(belief_gb_df)
# Out:
# Alg IDs
# -------
# POMeta
# POMetaRollout
# baposgmcp
# Ungrouped size = 50
# Grouped size = 15
#            alg_id  num_sims  exp_id  exp_seed  coplayer_policy_id  agent_id  \
# 0          POMeta        10      64         0  klr_k0_seed0_i1-v0         0
# 5   POMetaRollout        10      84         0  klr_k0_seed0_i1-v0         0
# 10      baposgmcp        10       0         0  klr_k0_seed0_i1-v0         0
# 1          POMeta        50      68         0  klr_k0_seed0_i1-v0         0
# 6   POMetaRollout        50      88         0  klr_k0_seed0_i1-v0         0
# 11      baposgmcp        50       4         0  klr_k0_seed0_i1-v0         0
# 2          POMeta       100      72         0  klr_k0_seed0_i1-v0         0
# 7   POMetaRollout       100      92         0  klr_k0_seed0_i1-v0         0
# 12      baposgmcp       100       8         0  klr_k0_seed0_i1-v0         0
# 3          POMeta       500      76         0  klr_k0_seed0_i1-v0         0
# 8   POMetaRollout       500      96         0  klr_k0_seed0_i1-v0         0
# 13      baposgmcp       500      12         0  klr_k0_seed0_i1-v0         0
# 4          POMeta      1000      80         0  klr_k0_seed0_i1-v0         0
# 9   POMetaRollout      1000     100         0  klr_k0_seed0_i1-v0         0
# 14      baposgmcp      1000      16         0  klr_k0_seed0_i1-v0         0
#
#                     env_id time_limit  episode_step_limit discount  ...  \
# 0   PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 5   PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 10  PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 1   PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 6   PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 11  PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 2   PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 7   PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 12  PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 3   PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 8   PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 13  PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 4   PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 9   PursuitEvasion16x16-v0      43200               100.0     0.99  ...
# 14  PursuitEvasion16x16-v0      43200               100.0     0.99  ...
#
#    bayes_accuracy_1_94_CI bayes_accuracy_1_95_CI  bayes_accuracy_1_96_CI  \
# 0                0.223423               0.224863                0.223162
# 5                0.203416               0.203991                0.203991
# 10               0.319213               0.319213                0.319213
# 1                0.181016               0.178714                0.178411
# 6                0.155415               0.154578                0.153379
# 11               0.240367               0.244881                0.243609
# 2                0.220765               0.219476                0.217787
# 7                0.174136               0.174810                0.174655
# 12               0.169429               0.170537                0.170090
# 3                0.106834               0.104932                0.100803
# 8                0.093536               0.093091                0.093070
# 13               0.211839               0.212366                0.209185
# 4                0.177957               0.181544                0.182710
# 9                0.081292               0.081200                0.081059
# 14               0.236831               0.241130                0.230553
#
#    bayes_accuracy_1_97_CI bayes_accuracy_1_98_CI bayes_accuracy_1_99_CI  \
# 0                0.223162               0.223162               0.222494
# 5                0.205637               0.205637               0.206841
# 10               0.320657               0.322288               0.322288
# 1                0.183673               0.181585               0.182273
# 6                0.153187               0.154126               0.156367
# 11               0.253343               0.247654               0.252257
# 2                0.221576               0.224386               0.221233
# 7                0.173551               0.174319               0.174711
# 12               0.177496               0.174670               0.170368
# 3                0.107184               0.107713               0.114050
# 8                0.092862               0.094744               0.095060
# 13               0.213259               0.212970               0.202737
# 4                0.183090               0.182148               0.184199
# 9                0.081106               0.081412               0.081785
# 14               0.230198               0.230247               0.231892
#
#    prop_LOSS prop_DRAW  prop_WIN   prop_NA
# 0   0.501500       0.0  0.429000  0.069500
# 5   0.429750       0.0  0.493250  0.077000
# 10  0.369000       0.0  0.574667  0.056333
# 1   0.495750       0.0  0.427750  0.076500
# 6   0.360250       0.0  0.574750  0.065000
# 11  0.257833       0.0  0.700083  0.042083
# 2   0.512250       0.0  0.417500  0.070250
# 7   0.331750       0.0  0.604500  0.063750
# 12  0.219667       0.0  0.748333  0.032000
# 3   0.503750       0.0  0.423750  0.072500
# 8   0.299500       0.0  0.611500  0.089000
# 13  0.118521       0.0  0.850950  0.030530
# 4   0.510000       0.0  0.423000  0.067000
# 9   0.304000       0.0  0.576750  0.119250
# 14  0.096980       0.0  0.867550  0.035470
#
# [15 rows x 1715 columns]

# %%
belief_plot_kwargs = copy.deepcopy(base_plot_kwargs)
belief_plot_kwargs["subplot_kwargs"].update({
    "xlabel": "Step",
})
belief_plot_kwargs["legend_kwargs"].update({
    "loc": "upper left",
    # "title": "Num. Sims." 
})

# %%
plot_kwargs = copy.deepcopy(belief_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Belief Probability",
    "ylim": (0.05, 1.05),
})
plot_kwargs["legend_kwargs"].update({
    "loc": "upper left",
})

for alg_id in belief_alg_ids:
    print(f"{alg_id=}")
    alg_df = belief_gb_df[belief_gb_df["alg_id"] == alg_id]
    for (i, j) in [(0, 1), (1, 0)]:
        print(f"agent_id={i}")
        fig, _ = plot_utils.paper.plot_multiple_belief_stats(
            alg_df,
            y_key_prefix="bayes_accuracy",
            step_limit=50,
            other_agent_id=j,
            y_suffix="mean",
            y_err_suffix="CI",
            alg_id_key="alg_id",
            **plot_kwargs
        )

        fig.savefig(osp.join(figure_dir, f"bayes_accuracy_{alg_id}_{i}.png"))
    
del plot_kwargs
# Out:
# alg_id='POMeta'
# agent_id=0
# agent_id=1
# alg_id='POMetaRollout'
# agent_id=0
# agent_id=1
# alg_id='baposgmcp'
# agent_id=0
# agent_id=1

# %%
plot_kwargs = copy.deepcopy(belief_plot_kwargs)
plot_kwargs["subplot_kwargs"].update({
    "ylabel": "Mean Wasserstein Distance",
    "ylim": (-0.02, 1.7),
})

plot_kwargs["legend_kwargs"].update({
    "loc": "upper right",
})

for alg_id in belief_alg_ids:
    print(f"{alg_id=}")
    alg_df = belief_gb_df[belief_gb_df["alg_id"] == alg_id]
    for (i, j) in [(0, 1), (1, 0)]:
        print(f"agent_id={i}")
        fig, _ = plot_utils.paper.plot_multiple_belief_stats(
            alg_df,
            y_key_prefix="action_dist_distance",
            step_limit=40,
            other_agent_id=j,
            y_suffix="mean",
            y_err_suffix="CI",
            alg_id_key="alg_id",
            **plot_kwargs
        )

        fig.savefig(osp.join(figure_dir, f"action_dist_{alg_id}_{i}.png"))

    
del plot_kwargs
# Out:
# alg_id='POMeta'
# agent_id=0
# agent_id=1
# alg_id='POMetaRollout'
# agent_id=0
# agent_id=1
# alg_id='baposgmcp'
# agent_id=0
# agent_id=1

# %% [markdown]
# # Old stuff
#
# Below has not been updated.

# %% [markdown]
# ## Looking at time
#
#    - search_time
#    - update_time
#    - reinvigoration_time
#    - policy_calls
#    - inference_time
#    - search_depth

# %%
plot_utils.get_and_plot_expected_values_by_num_sims(
    combined_df,
    y_key="episode_steps_mean",
    y_err_key="episode_steps_CI",
    policy_key="policy_id",
    policy_prior=policy_prior,
    policies_with_sims=policies_with_sims,
    policies_without_sims=policies_without_sims
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
#       1 plot_utils.get_and_plot_expected_values_by_num_sims(
#       2     combined_df,
#       3     y_key="episode_steps_mean",
#       4     y_err_key="episode_steps_CI",
#       5     policy_key="policy_id",
#       6     policy_prior=policy_prior,
# ----> 7     policies_with_sims=policies_with_sims,
#       8     policies_without_sims=policies_without_sims
#       9 )
#
# NameError: name 'policies_with_sims' is not defined

# %%
plot_utils.get_and_plot_expected_values_by_num_sims(
    combined_df,
    y_key="search_time_mean",
    y_err_key="search_time_CI",
    policy_key="policy_id",
    policy_prior=policy_prior,
    policies_with_sims=policies_with_times,
    policies_without_sims=[]
)

# %%
plot_utils.get_and_plot_expected_values_by_num_sims(
    combined_df,
    y_key="evaluation_time_mean",
    y_err_key="evaluation_time_CI",
    policy_key="policy_id",
    policy_prior=policy_prior,
    policies_with_sims=policies_with_times,
    policies_without_sims=[]
)

# %%
plot_utils.get_and_plot_expected_values_by_num_sims(
    combined_df,
    y_key="update_time_mean",
    y_err_key="update_time_CI",
    policy_key="policy_id",
    policy_prior=policy_prior,
    policies_with_sims=policies_with_times,
    policies_without_sims=[]
)

# %%
plot_utils.get_and_plot_expected_values_by_num_sims(
    combined_df,
    y_key="reinvigoration_time_mean",
    y_err_key="reinvigoration_time_CI",
    policy_key="policy_id",
    policy_prior=policy_prior,
    policies_with_sims=policies_with_times,
    policies_without_sims=[]
)

# %%
plot_utils.get_and_plot_expected_values_by_num_sims(
    combined_df,
    y_key="inference_time_mean",
    y_err_key="inference_time_CI",
    policy_key="policy_id",
    policy_prior=policy_prior,
    policies_with_sims=policies_with_times,
    policies_without_sims=[]
)

# %%
plot_utils.get_and_plot_expected_values_by_num_sims(
    combined_df,
    y_key="search_depth_mean",
    y_err_key="search_depth_CI",
    policy_key="policy_id",
    policy_prior=policy_prior,
    policies_with_sims=policies_with_times,
    policies_without_sims=[]
)

# %% [markdown]
# ## Looking at Belief accuracy by steps
#
# - action_dist_distance
# - bayes_accuracy

# %%
policy_ids_by_alg = [
    ["baposgmcp_greedy_10", "baposgmcp_greedy_50", "baposgmcp_greedy_100", "baposgmcp_greedy_500", "baposgmcp_greedy_1000", "baposgmcp_greedy_2500"],
    ["baposgmcp_softmax_10", "baposgmcp_softmax_50", "baposgmcp_softmax_100", "baposgmcp_softmax_500", "baposgmcp_softmax_1000", "baposgmcp_softmax_2500"],
    ["baposgmcp_uniform_10", "baposgmcp_uniform_50", "baposgmcp_uniform_100", "baposgmcp_uniform_500", "baposgmcp_uniform_1000", "baposgmcp_uniform_2500"]
]

# %%
plot_utils.plot_expected_belief_stat_by_step(
    combined_df,
    y_key_prefix="bayes_accuracy",
    policy_ids=policy_ids_by_alg,
    policy_prior=policy_prior,
    step_limit=50,
    other_agent_id=1,
    policy_key="policy_id",
    coplayer_policy_key="coplayer_policy_id",
    y_suffix="mean",
    y_err_suffix="CI",
    figsize=(18, 9)
)

# %%
plot_utils.plot_expected_belief_stat_by_step(
    combined_df,
    y_key_prefix="action_dist_distance",
    policy_ids=policy_ids_by_alg,
    policy_prior=policy_prior,
    step_limit=50,
    other_agent_id=1,
    policy_key="policy_id",
    coplayer_policy_key="coplayer_policy_id",
    y_suffix="mean",
    y_err_suffix="CI",
    figsize=(18, 9)
)
